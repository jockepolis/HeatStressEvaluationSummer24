# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy.optimize import curve_fit, OptimizeWarning
from tqdm import tqdm
import warnings
from scipy.stats import zscore
from statsmodels.tsa.stattools import acf, pacf

sns.set_theme()
sns.set_context("notebook")
# %load_ext autoreload
# %autoreload 2

# %%
dtype_dict = {
    'FarmName_Pseudo': 'str',
    'SE_Number': 'str',
    'AnimalNumber': 'Int64',          
    'StartDate': 'str',
    'StartTime': 'str',
    'DateTime': 'str',
    'LactationNumber': 'Int64',       
    'DaysInMilk': 'Int64', 
    'YearSeason': 'str',           
    'TotalYield': 'float',
    'DateTime': 'str',
    'BreedName': 'str',
    'Age': 'Int64',
    'Mother': 'str',
    'Father': 'str',
    'CullDecisionDate': 'str',
    'Temperature': 'float',
    'RelativeHumidity': 'float',      
    'THI_adj': 'float',
    'HW': 'Int64',                    
    'cum_HW': 'Int64',                
    'Temp15Threshold': 'Int64'        
}


# Load the CSV with specified dtypes
data = pd.read_csv('../Data/MergedData/CleanedYieldData.csv', dtype=dtype_dict)

# Convert date and time columns back to datetime and time objects
data['DateTime'] = pd.to_datetime(data['DateTime'], errors='coerce')
data['StartTime'] = pd.to_datetime(data['StartTime'], format='%H:%M:%S', errors='coerce').dt.time
data['StartDate'] = pd.to_datetime(data['StartDate'], errors='coerce')
data['CullDecisionDate'] = pd.to_datetime(data['CullDecisionDate'], errors='coerce')
data['DateTime'] = pd.to_datetime(data['DateTime'], errors='coerce')
data.head()
# Out:
#   FarmName_Pseudo         SE_Number  AnimalNumber  StartDate StartTime  \
# 0        a624fb9a  SE-064c0cec-1189          5189 2022-01-01  06:25:00
# 1        a624fb9a  SE-064c0cec-1189          5189 2022-01-01  16:41:00
# 2        a624fb9a  SE-064c0cec-1189          5189 2022-01-02  15:29:00
# 3        a624fb9a  SE-064c0cec-1189          5189 2022-01-02  03:31:00
# 4        a624fb9a  SE-064c0cec-1189          5189 2022-01-02  22:44:00
#
#    LactationNumber  DaysInMilk  TotalYield            DateTime YearSeason  \
# 0                7         191       13.90 2022-01-01 06:25:00     2022-1
# 1                7         191       16.87 2022-01-01 16:41:00     2022-1
# 2                7         192       20.41 2022-01-02 15:29:00     2022-1
# 3                7         192       16.28 2022-01-02 03:31:00     2022-1
# 4                7         192       11.53 2022-01-02 22:44:00     2022-1
#
#    ... Mother Father CullDecisionDate Temperature  RelativeHumidity  \
# 0  ...    NaN    NaN       2022-12-20   -3.025000          0.930917
# 1  ...    NaN    NaN       2022-12-20   -3.025000          0.930917
# 2  ...    NaN    NaN       2022-12-20   -0.279167          0.990542
# 3  ...    NaN    NaN       2022-12-20   -0.279167          0.990542
# 4  ...    NaN    NaN       2022-12-20   -0.279167          0.990542
#
#      THI_adj  HW  cum_HW  Temp15Threshold   Age
# 0  28.012944   0       0                0  3095
# 1  28.012944   0       0                0  3095
# 2  32.898193   0       0                0  3096
# 3  32.898193   0       0                0  3096
# 4  32.898193   0       0                0  3096
#
# [5 rows x 21 columns]

# %%
# Define the THI threshold
THI_THRESHOLD = 63

# Calculate the daily heat load based on the THI threshold
data['HeatLoad'] = data['THI_adj'].apply(lambda x: x - THI_THRESHOLD if x > THI_THRESHOLD else -(THI_THRESHOLD - x))

# Initialize the cumulative heat load column
data['CumulativeHeatLoad'] = 0

# Iterate through the data to calculate cumulative heat load correctly
for i in range(1, len(data)):
    previous_cumulative = data.at[i-1, 'CumulativeHeatLoad']
    current_heat_load = data.at[i, 'HeatLoad']
    if previous_cumulative + current_heat_load > 0:
        data.at[i, 'CumulativeHeatLoad'] = previous_cumulative + current_heat_load
    else:
        data.at[i, 'CumulativeHeatLoad'] = 0

data.head(-5)
# Out:
# /var/folders/n0/fphw_xw93vv749r_ntt01qd80000gn/T/ipykernel_37467/2932683876.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.7078608333333349' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.at[i, 'CumulativeHeatLoad'] = previous_cumulative + current_heat_load
#         FarmName_Pseudo           SE_Number  AnimalNumber  StartDate  \
# 0              a624fb9a    SE-064c0cec-1189          5189 2022-01-01
# 1              a624fb9a    SE-064c0cec-1189          5189 2022-01-01
# 2              a624fb9a    SE-064c0cec-1189          5189 2022-01-02
# 3              a624fb9a    SE-064c0cec-1189          5189 2022-01-02
# 4              a624fb9a    SE-064c0cec-1189          5189 2022-01-02
# ...                 ...                 ...           ...        ...
# 1364930        f454e660  SE-fcdf259d-0044-0          1044 2023-06-07
# 1364931        f454e660  SE-fcdf259d-0044-0          1044 2023-06-07
# 1364932        f454e660  SE-fcdf259d-0044-0          1044 2023-06-08
# 1364933        f454e660  SE-fcdf259d-0044-0          1044 2023-06-08
# 1364934        f454e660  SE-fcdf259d-0044-0          1044 2023-06-09
#
#         StartTime  LactationNumber  DaysInMilk  TotalYield  \
# 0        06:25:00                7         191       13.90
# 1        16:41:00                7         191       16.87
# 2        15:29:00                7         192       20.41
# 3        03:31:00                7         192       16.28
# 4        22:44:00                7         192       11.53
# ...           ...              ...         ...         ...
# 1364930  00:51:00               10         351        5.63
# 1364931  11:17:00               10         351        3.34
# 1364932  17:01:00               10         352        6.96
# 1364933  02:23:00               10         352        8.18
# 1364934  13:08:00               10         353        7.47
#
#                    DateTime YearSeason  ... CullDecisionDate Temperature  \
# 0       2022-01-01 06:25:00     2022-1  ...       2022-12-20   -3.025000
# 1       2022-01-01 16:41:00     2022-1  ...       2022-12-20   -3.025000
# 2       2022-01-02 15:29:00     2022-1  ...       2022-12-20   -0.279167
# 3       2022-01-02 03:31:00     2022-1  ...       2022-12-20   -0.279167
# 4       2022-01-02 22:44:00     2022-1  ...       2022-12-20   -0.279167
# ...                     ...        ...  ...              ...         ...
# 1364930 2023-06-07 00:51:00     2023-3  ...              NaT   15.645833
# 1364931 2023-06-07 11:17:00     2023-3  ...              NaT   15.645833
# 1364932 2023-06-08 17:01:00     2023-3  ...              NaT   15.570833
# 1364933 2023-06-08 02:23:00     2023-3  ...              NaT   15.570833
# 1364934 2023-06-09 13:08:00     2023-3  ...              NaT   13.254167
#
#         RelativeHumidity    THI_adj  HW  cum_HW  Temp15Threshold   Age  \
# 0               0.930917  28.012944   0       0                0  3095
# 1               0.930917  28.012944   0       0                0  3095
# 2               0.990542  32.898193   0       0                0  3096
# 3               0.990542  32.898193   0       0                0  3096
# 4               0.990542  32.898193   0       0                0  3096
# ...                  ...        ...  ..     ...              ...   ...
# 1364930         0.731917  61.559237   0       0                1  4154
# 1364931         0.731917  61.559237   0       0                1  4154
# 1364932         0.601708  59.383267   0       0                1  4155
# 1364933         0.601708  59.383267   0       0                1  4155
# 1364934         0.518083  54.534255   0       0                1  4156
#
#           HeatLoad  CumulativeHeatLoad
# 0       -34.987056                 0.0
# 1       -34.987056                 0.0
# 2       -30.101807                 0.0
# 3       -30.101807                 0.0
# 4       -30.101807                 0.0
# ...            ...                 ...
# 1364930  -1.440763                 0.0
# 1364931  -1.440763                 0.0
# 1364932  -3.616733                 0.0
# 1364933  -3.616733                 0.0
# 1364934  -8.465745                 0.0
#
# [1364935 rows x 23 columns]

# %%
# When CumulativeHeatLoad is greater than 5, it indicates that the cow is under heat stress
data['HeatStress'] = (data['CumulativeHeatLoad'] > 5).astype(int)
data.head(-5)
# Out:
#         FarmName_Pseudo           SE_Number  AnimalNumber  StartDate  \
# 0              a624fb9a    SE-064c0cec-1189          5189 2022-01-01
# 1              a624fb9a    SE-064c0cec-1189          5189 2022-01-01
# 2              a624fb9a    SE-064c0cec-1189          5189 2022-01-02
# 3              a624fb9a    SE-064c0cec-1189          5189 2022-01-02
# 4              a624fb9a    SE-064c0cec-1189          5189 2022-01-02
# ...                 ...                 ...           ...        ...
# 1364930        f454e660  SE-fcdf259d-0044-0          1044 2023-06-07
# 1364931        f454e660  SE-fcdf259d-0044-0          1044 2023-06-07
# 1364932        f454e660  SE-fcdf259d-0044-0          1044 2023-06-08
# 1364933        f454e660  SE-fcdf259d-0044-0          1044 2023-06-08
# 1364934        f454e660  SE-fcdf259d-0044-0          1044 2023-06-09
#
#         StartTime  LactationNumber  DaysInMilk  TotalYield  \
# 0        06:25:00                7         191       13.90
# 1        16:41:00                7         191       16.87
# 2        15:29:00                7         192       20.41
# 3        03:31:00                7         192       16.28
# 4        22:44:00                7         192       11.53
# ...           ...              ...         ...         ...
# 1364930  00:51:00               10         351        5.63
# 1364931  11:17:00               10         351        3.34
# 1364932  17:01:00               10         352        6.96
# 1364933  02:23:00               10         352        8.18
# 1364934  13:08:00               10         353        7.47
#
#                    DateTime YearSeason  ... Temperature RelativeHumidity  \
# 0       2022-01-01 06:25:00     2022-1  ...   -3.025000         0.930917
# 1       2022-01-01 16:41:00     2022-1  ...   -3.025000         0.930917
# 2       2022-01-02 15:29:00     2022-1  ...   -0.279167         0.990542
# 3       2022-01-02 03:31:00     2022-1  ...   -0.279167         0.990542
# 4       2022-01-02 22:44:00     2022-1  ...   -0.279167         0.990542
# ...                     ...        ...  ...         ...              ...
# 1364930 2023-06-07 00:51:00     2023-3  ...   15.645833         0.731917
# 1364931 2023-06-07 11:17:00     2023-3  ...   15.645833         0.731917
# 1364932 2023-06-08 17:01:00     2023-3  ...   15.570833         0.601708
# 1364933 2023-06-08 02:23:00     2023-3  ...   15.570833         0.601708
# 1364934 2023-06-09 13:08:00     2023-3  ...   13.254167         0.518083
#
#            THI_adj HW  cum_HW  Temp15Threshold   Age   HeatLoad  \
# 0        28.012944  0       0                0  3095 -34.987056
# 1        28.012944  0       0                0  3095 -34.987056
# 2        32.898193  0       0                0  3096 -30.101807
# 3        32.898193  0       0                0  3096 -30.101807
# 4        32.898193  0       0                0  3096 -30.101807
# ...            ... ..     ...              ...   ...        ...
# 1364930  61.559237  0       0                1  4154  -1.440763
# 1364931  61.559237  0       0                1  4154  -1.440763
# 1364932  59.383267  0       0                1  4155  -3.616733
# 1364933  59.383267  0       0                1  4155  -3.616733
# 1364934  54.534255  0       0                1  4156  -8.465745
#
#          CumulativeHeatLoad  HeatStress
# 0                       0.0           0
# 1                       0.0           0
# 2                       0.0           0
# 3                       0.0           0
# 4                       0.0           0
# ...                     ...         ...
# 1364930                 0.0           0
# 1364931                 0.0           0
# 1364932                 0.0           0
# 1364933                 0.0           0
# 1364934                 0.0           0
#
# [1364935 rows x 24 columns]

# %%
# Calculate the DailyYield for each cow each day
data['DailyYield'] = data.groupby(['SE_Number', 'StartDate'])['TotalYield'].transform('sum')

# Sort the data by AnimalNumber and StartDate
data.sort_values(['AnimalNumber', 'StartDate'], inplace=True)

# Calculate the previous day's total yield for each cow
data['PreviousDailyYield'] = data.groupby('AnimalNumber')['DailyYield'].shift(1)

# Calculate the daily yield change for each cow
data['DailyYieldChange'] = data['DailyYield'] - data['PreviousDailyYield']

# Group and aggregate data
data = data.groupby(['SE_Number', 'FarmName_Pseudo', 'StartDate']).agg({
    'DailyYield': 'first',
    'PreviousDailyYield': 'first',
    'DailyYieldChange': 'first',
    'HW': 'max',
    'Temperature': 'mean',
    'THI_adj': 'mean',
    'DaysInMilk': 'first',
    'YearSeason': 'first',
    'cum_HW': 'max',
    'Temp15Threshold': 'max',
    'Age': 'first',
    'BreedName': 'first',
    'LactationNumber': 'first',
    'HeatLoad': 'max',
    'CumulativeHeatLoad': 'max',
    'HeatStress': 'max'
}).reset_index()

# Renaming and formatting
data.rename(columns={
    'Temperature': 'MeanTemperature',
    'THI_adj': 'MeanTHI_adj',
    'StartDate': 'Date'
}, inplace=True)
data['Date'] = pd.to_datetime(data['Date'])

# Display the first few rows of the transformed data
data.head()
# Out:
#           SE_Number FarmName_Pseudo       Date  DailyYield  \
# 0  SE-064c0cec-1189        a624fb9a 2022-01-01       30.77
# 1  SE-064c0cec-1189        a624fb9a 2022-01-02       48.22
# 2  SE-064c0cec-1189        a624fb9a 2022-01-03       30.53
# 3  SE-064c0cec-1189        a624fb9a 2022-01-04       42.26
# 4  SE-064c0cec-1189        a624fb9a 2022-01-05       38.49
#
#    PreviousDailyYield  DailyYieldChange  HW  MeanTemperature  MeanTHI_adj  \
# 0               30.77              0.00   0        -3.025000    28.012944
# 1               30.77             17.45   0        -0.279167    32.898193
# 2               48.22            -17.69   0         2.033333    36.760487
# 3               30.53             11.73   0         0.066667    31.939524
# 4               42.26             -3.77   0        -3.700000    26.498206
#
#    DaysInMilk YearSeason  cum_HW  Temp15Threshold   Age BreedName  \
# 0         191     2022-1       0                0  3095    02 SLB
# 1         192     2022-1       0                0  3096    02 SLB
# 2         193     2022-1       0                0  3097    02 SLB
# 3         194     2022-1       0                0  3098    02 SLB
# 4         195     2022-1       0                0  3099    02 SLB
#
#    LactationNumber   HeatLoad  CumulativeHeatLoad  HeatStress
# 0                7 -34.987056                 0.0           0
# 1                7 -30.101807                 0.0           0
# 2                7 -26.239513                 0.0           0
# 3                7 -31.060476                 0.0           0
# 4                7 -36.501794                 0.0           0

# %%
# Check if DailyYield is centered around approx the same for each farm
print("Mean of DailyYield:", data.groupby('FarmName_Pseudo')['DailyYield'].mean())
print("Standard Deviation of DailyYield:", data.groupby('FarmName_Pseudo')['DailyYield'].std())
# Out:
# Mean of DailyYield: FarmName_Pseudo
# 5c06d92d    37.389675
# 752efd72    31.151716
# a624fb9a    33.413694
# f454e660    30.485127
# Name: DailyYield, dtype: float64
# Standard Deviation of DailyYield: FarmName_Pseudo
# 5c06d92d     9.960240
# 752efd72     7.799288
# a624fb9a    11.050811
# f454e660    11.833056
# Name: DailyYield, dtype: float64

# %% [markdown]
# ## Wilmink Lactation Curve
# $$
# Y(t) = a + bt + c \exp(-dt)
# $$
# - \(Y(t)\): Milk yield at time \(t\) post-calving, so t = DaysInMilk
# - \(a\): Intercept, representing baseline milk yield
# - \(b\): Linear increase rate of milk yield over time
# - \(c\): Initial exponential increase in milk yield
# - \(d\): Rate at which the exponential increase declines over time
#
# The Wilmink model captures the lactation curve by considering both linear and exponential components, providing a flexible representation of milk production dynamics over the lactation period.

# %%
# Define the Wilmink Lactation Curve function
def wilmink_lactation_curve(dim, a, b, c, d):
    dim = np.array(dim, dtype=float)
    return a + b * dim + c * np.exp(-d * dim)

# Function to detect and remove outliers
def remove_outliers(group, threshold=3.5):
    mean = np.mean(group['DailyYield'])
    std_dev = np.std(group['DailyYield'])
    return group[(group['DailyYield'] > mean - threshold * std_dev) & (group['DailyYield'] < mean + threshold * std_dev)]

# Function to smooth the data using a rolling average
def smooth_data(group, window=5):
    group = group.copy()
    group['DailyYield'] = group['DailyYield'].rolling(window, min_periods=1).mean()
    return group

# Function to fit the Wilmink Lactation Curve to the dataset
def fit_wilmink_lactation_curve(dataset):
    # Initialize the 'ExpectedYield' column to NaN
    dataset['ExpectedYield'] = np.nan
    params_dict = {}
    
    valid_indices = []

    # Group the dataset by 'SE_Number' and 'LactationNumber' and fit the curve for each segment
    for (animal_number, lactation_number), group in tqdm(dataset.groupby(['SE_Number', 'LactationNumber']), unit=" Segments"):
        # Prepare the data for fitting
        group = remove_outliers(group, threshold=3.5)  # Remove outliers with threshold 4
        group = smooth_data(group)  # Smooth the data
        x_data = group['DaysInMilk'].values
        y_data = group['DailyYield'].values
        
        # Ensure there are no NaN or infinite values in the data
        if not np.isfinite(x_data).all() or not np.isfinite(y_data).all():
            print(f"Non-finite values found for cow {animal_number}, lactation {lactation_number}, skipping.")
            continue
        
        # Ensure there are enough data points to fit the curve
        if len(x_data) < 10 or len(y_data) < 10:
            print(f"Insufficient data points for cow {animal_number}, lactation {lactation_number}, skipping.")
            continue

        valid_indices.extend(group.index)
        
        # Fit the model
        try:
            # Initial parameter guesses
            initial_guesses = [np.mean(y_data), 0, np.mean(y_data) / 2, 0.1]
            # Bounds on the parameters to prevent overflow
            bounds = ([-np.inf, -np.inf, -np.inf, 0], [np.inf, np.inf, np.inf, np.inf])
            
            with warnings.catch_warnings():
                warnings.filterwarnings('error', category=OptimizeWarning)
                try:
                    popt, pcov = curve_fit(
                        wilmink_lactation_curve, x_data, y_data,
                        p0=initial_guesses, bounds=bounds, maxfev=30000
                    )
                    
                    # Store the parameters in the dictionary
                    params_dict[(animal_number, lactation_number)] = {'a': popt[0], 'b': popt[1], 'c': popt[2], 'd': popt[3]}
                    
                    # Predict the expected yield using the fitted model
                    dataset.loc[group.index, 'ExpectedYield'] = wilmink_lactation_curve(group['DaysInMilk'], *popt)
                    
                    # Normalize the DailyYield
                    dataset.loc[group.index, 'NormalizedDailyYield'] = group['DailyYield'] / dataset.loc[group.index, 'ExpectedYield']
                    
                    # Calculate the daily yield change and normalize it
                    dataset.loc[group.index, 'PreviousDailyYield'] = group['DailyYield'].shift(1)
                    dataset.loc[group.index, 'DailyYieldChange'] = group['DailyYield'] - dataset.loc[group.index, 'PreviousDailyYield']
                    dataset.loc[group.index, 'NormalizedDailyYieldChange'] = dataset.loc[group.index, 'DailyYieldChange'] / dataset.loc[group.index, 'ExpectedYield']
                
                except OptimizeWarning:
                    print(f"OptimizeWarning for cow {animal_number}, lactation {lactation_number}, skipping.")
            
        except RuntimeError as e:
            print(f"Curve fit failed for cow {animal_number}, lactation {lactation_number}: {e}")
        except ValueError as e:
            print(f"Value error for cow {animal_number}, lactation {lactation_number}: {e}")
    
    # Keep only valid indices
    dataset = dataset.loc[valid_indices].reset_index(drop=True)
    
    # Fill any NaN values in the newly created columns with 0
    dataset['ExpectedYield'] = dataset['ExpectedYield'].fillna(0)
    dataset['NormalizedDailyYield'] = dataset['NormalizedDailyYield'].fillna(0)
    dataset['PreviousDailyYield'] = dataset['PreviousDailyYield'].fillna(0)
    dataset['DailyYieldChange'] = dataset['DailyYieldChange'].fillna(0)
    dataset['NormalizedDailyYieldChange'] = dataset['NormalizedDailyYieldChange'].fillna(0)
    
    return dataset, params_dict

# Apply the curve fitting function to your dataset
data, params_dict = fit_wilmink_lactation_curve(data)
data
# Out:
#   4%|▍         | 102/2315 [00:06<01:52, 19.73 Segments/s]
# Insufficient data points for cow SE-5c06d92d-2621, lactation 3, skipping.
#   5%|▍         | 114/2315 [00:09<03:53,  9.44 Segments/s]
# Insufficient data points for cow SE-5c06d92d-2639, lactation 3, skipping.
#  10%|▉         | 230/2315 [00:19<03:36,  9.62 Segments/s]
# Insufficient data points for cow SE-5c06d92d-2804, lactation 5, skipping.
# Insufficient data points for cow SE-5c06d92d-2815, lactation 2, skipping.
#  11%|█         | 247/2315 [00:22<04:25,  7.79 Segments/s]
# Insufficient data points for cow SE-5c06d92d-2824, lactation 3, skipping.
#  12%|█▏        | 284/2315 [00:24<01:54, 17.78 Segments/s]
# Insufficient data points for cow SE-5c06d92d-2845, lactation 2, skipping.
#  13%|█▎        | 290/2315 [00:25<02:31, 13.32 Segments/s]
# Insufficient data points for cow SE-5c06d92d-2870, lactation 2, skipping.
#  15%|█▌        | 352/2315 [00:25<00:36, 53.12 Segments/s]
# Insufficient data points for cow SE-5c06d92d-2911, lactation 2, skipping.
# Insufficient data points for cow SE-5c06d92d-2914, lactation 2, skipping.
# Insufficient data points for cow SE-5c06d92d-2919, lactation 2, skipping.
#  19%|█▊        | 432/2315 [00:35<04:31,  6.94 Segments/s]
# Insufficient data points for cow SE-5c06d92d-3039, lactation 4, skipping.
#  19%|█▉        | 450/2315 [00:37<04:14,  7.32 Segments/s]
# Insufficient data points for cow SE-5c06d92d-3045, lactation 1, skipping.
# Insufficient data points for cow SE-5c06d92d-3047, lactation 1, skipping.
# Insufficient data points for cow SE-5c06d92d-3049, lactation 1, skipping.
#  22%|██▏       | 500/2315 [00:38<00:54, 33.02 Segments/s]
# Insufficient data points for cow SE-5c06d92d-3063, lactation 1, skipping.
# Insufficient data points for cow SE-5c06d92d-3063, lactation 3, skipping.
# Insufficient data points for cow SE-5c06d92d-3065, lactation 1, skipping.
# Insufficient data points for cow SE-5c06d92d-3068, lactation 1, skipping.
#  23%|██▎       | 536/2315 [00:39<00:39, 44.72 Segments/s]
# Insufficient data points for cow SE-5c06d92d-3116, lactation 3, skipping.
#  27%|██▋       | 630/2315 [00:45<02:30, 11.23 Segments/s]
# Insufficient data points for cow SE-5c06d92d-3173, lactation 3, skipping.
#  32%|███▏      | 738/2315 [00:49<00:31, 50.31 Segments/s]
# Insufficient data points for cow SE-5c06d92d-3267, lactation 2, skipping.
#  35%|███▌      | 815/2315 [00:52<00:44, 33.50 Segments/s]
# Insufficient data points for cow SE-5c06d92d-3357, lactation 2, skipping.
# Insufficient data points for cow SE-5c06d92d-3365, lactation 2, skipping.
# Insufficient data points for cow SE-5c06d92d-3370, lactation 2, skipping.
# Insufficient data points for cow SE-5c06d92d-3371, lactation 2, skipping.
#  39%|███▉      | 905/2315 [00:54<00:40, 34.60 Segments/s]
# Insufficient data points for cow SE-5c06d92d-3524, lactation 1, skipping.
#  40%|███▉      | 917/2315 [00:55<00:48, 28.80 Segments/s]
# Insufficient data points for cow SE-5c06d92d-3530, lactation 1, skipping.
# Insufficient data points for cow SE-5c06d92d-3536, lactation 1, skipping.
# Insufficient data points for cow SE-5c06d92d-3537, lactation 1, skipping.
#  40%|████      | 937/2315 [00:58<01:49, 12.63 Segments/s]
# Insufficient data points for cow SE-752efd72-0051, lactation 3, skipping.
#  43%|████▎     | 1004/2315 [01:04<02:04, 10.54 Segments/s]
# Insufficient data points for cow SE-752efd72-0117, lactation 2, skipping.
#  44%|████▍     | 1013/2315 [01:05<01:45, 12.38 Segments/s]
# Insufficient data points for cow SE-752efd72-0129, lactation 2, skipping.
#  45%|████▌     | 1046/2315 [01:05<00:48, 26.06 Segments/s]
# Insufficient data points for cow SE-752efd72-0136, lactation 2, skipping.
# Insufficient data points for cow SE-752efd72-0143, lactation 2, skipping.
#  46%|████▌     | 1063/2315 [01:07<01:23, 15.02 Segments/s]
# Insufficient data points for cow SE-752efd72-0166, lactation 1, skipping.
#  51%|█████     | 1174/2315 [01:22<00:59, 19.33 Segments/s]
# Insufficient data points for cow SE-752efd72-0232, lactation 1, skipping.
# Insufficient data points for cow SE-752efd72-0234, lactation 1, skipping.
# Insufficient data points for cow SE-752efd72-0239, lactation 1, skipping.
# Insufficient data points for cow SE-752efd72-0243, lactation 1, skipping.
#  56%|█████▋    | 1305/2315 [01:34<00:47, 21.44 Segments/s]
# Insufficient data points for cow SE-752efd72-0298, lactation 1, skipping.
#  57%|█████▋    | 1319/2315 [01:36<01:40,  9.91 Segments/s]
# Insufficient data points for cow SE-752efd72-0317, lactation 1, skipping.
#  58%|█████▊    | 1339/2315 [01:38<01:36, 10.14 Segments/s]
# Insufficient data points for cow SE-752efd72-0329, lactation 1, skipping.
#  61%|██████▏   | 1419/2315 [01:40<00:16, 54.38 Segments/s]
# Insufficient data points for cow SE-752efd72-0369, lactation 1, skipping.
#  65%|██████▌   | 1506/2315 [01:43<00:20, 39.50 Segments/s]
# Insufficient data points for cow SE-752efd72-0416, lactation 2, skipping.
#  66%|██████▌   | 1518/2315 [01:43<00:23, 33.58 Segments/s]
# Insufficient data points for cow SE-752efd72-0439, lactation 2, skipping.
# Insufficient data points for cow SE-752efd72-0440, lactation 2, skipping.
#  66%|██████▌   | 1527/2315 [01:45<00:43, 17.94 Segments/s]
# Insufficient data points for cow SE-752efd72-0446, lactation 2, skipping.
#  69%|██████▉   | 1597/2315 [01:47<00:16, 44.25 Segments/s]
# Insufficient data points for cow SE-752efd72-0533, lactation 1, skipping.
#  70%|██████▉   | 1609/2315 [01:47<00:19, 35.55 Segments/s]
# Insufficient data points for cow SE-752efd72-0544, lactation 1, skipping.
#  71%|███████   | 1640/2315 [01:50<00:44, 15.28 Segments/s]
# Insufficient data points for cow SE-752efd72-2751, lactation 5, skipping.
#  72%|███████▏  | 1659/2315 [01:55<01:45,  6.22 Segments/s]
# Insufficient data points for cow SE-752efd72-2794, lactation 6, skipping.
#  73%|███████▎  | 1692/2315 [01:57<00:38, 16.10 Segments/s]
# Insufficient data points for cow SE-752efd72-2797, lactation 3, skipping.
# Insufficient data points for cow SE-7fd04cd3-679, lactation 4, skipping.
# Insufficient data points for cow SE-a624fb9a-1162, lactation 7, skipping.
# Insufficient data points for cow SE-a624fb9a-1200, lactation 4, skipping.
#  74%|███████▎  | 1706/2315 [02:03<01:52,  5.41 Segments/s]
# Insufficient data points for cow SE-a624fb9a-1251, lactation 3, skipping.
#  75%|███████▍  | 1735/2315 [02:03<00:49, 11.70 Segments/s]
# Insufficient data points for cow SE-a624fb9a-1267, lactation 3, skipping.
#  76%|███████▌  | 1761/2315 [02:07<01:14,  7.45 Segments/s]
# Insufficient data points for cow SE-a624fb9a-1312, lactation 2, skipping.
#  77%|███████▋  | 1777/2315 [02:08<00:54,  9.87 Segments/s]
# Insufficient data points for cow SE-a624fb9a-1330, lactation 2, skipping.
# Insufficient data points for cow SE-a624fb9a-1333, lactation 1, skipping.
#  79%|███████▊  | 1822/2315 [02:09<00:19, 25.34 Segments/s]
# Insufficient data points for cow SE-a624fb9a-1373, lactation 1, skipping.
# Insufficient data points for cow SE-a624fb9a-1374, lactation 1, skipping.
#  86%|████████▌ | 1992/2315 [02:18<00:19, 16.92 Segments/s]
# Insufficient data points for cow SE-f454e660-0420, lactation 5, skipping.
#  86%|████████▋ | 1999/2315 [02:19<00:29, 10.82 Segments/s]
# Insufficient data points for cow SE-f454e660-0451, lactation 5, skipping.
#  87%|████████▋ | 2019/2315 [02:20<00:17, 16.45 Segments/s]
# Insufficient data points for cow SE-f454e660-0465, lactation 2, skipping.
# Insufficient data points for cow SE-f454e660-0494, lactation 2, skipping.
#  89%|████████▊ | 2053/2315 [02:23<00:20, 12.73 Segments/s]
# Insufficient data points for cow SE-f454e660-0545, lactation 4, skipping.
# Insufficient data points for cow SE-f454e660-0551, lactation 1, skipping.
# Insufficient data points for cow SE-f454e660-0559, lactation 1, skipping.
#  90%|████████▉ | 2075/2315 [02:24<00:17, 13.91 Segments/s]
# Insufficient data points for cow SE-f454e660-0585, lactation 1, skipping.
#  93%|█████████▎| 2150/2315 [02:28<00:08, 20.07 Segments/s]
# Insufficient data points for cow SE-f454e660-0713, lactation 2, skipping.
# Insufficient data points for cow SE-f454e660-0717, lactation 2, skipping.
#  94%|█████████▍| 2178/2315 [02:28<00:04, 32.86 Segments/s]
# Insufficient data points for cow SE-f454e660-0726, lactation 2, skipping.
#  96%|█████████▌| 2216/2315 [02:29<00:02, 46.77 Segments/s]
# Insufficient data points for cow SE-f454e660-0829, lactation 1, skipping.
#  98%|█████████▊| 2265/2315 [02:35<00:03, 13.30 Segments/s]
# Insufficient data points for cow SE-f454e660-509, lactation 3, skipping.
# Insufficient data points for cow SE-f454e660-510, lactation 2, skipping.
#  98%|█████████▊| 2274/2315 [02:35<00:03, 12.34 Segments/s]
# Insufficient data points for cow SE-f454e660-567, lactation 1, skipping.
# 100%|██████████| 2315/2315 [02:39<00:00, 14.55 Segments/s]
# Insufficient data points for cow SE-f454e660-729, lactation 1, skipping.
#                  SE_Number FarmName_Pseudo       Date  DailyYield  \
# 0         SE-064c0cec-1189        a624fb9a 2022-01-01       30.77
# 1         SE-064c0cec-1189        a624fb9a 2022-01-02       48.22
# 2         SE-064c0cec-1189        a624fb9a 2022-01-03       30.53
# 3         SE-064c0cec-1189        a624fb9a 2022-01-04       42.26
# 4         SE-064c0cec-1189        a624fb9a 2022-01-05       38.49
# ...                    ...             ...        ...         ...
# 483102  SE-fcdf259d-0044-0        f454e660 2023-06-08       15.14
# 483103  SE-fcdf259d-0044-0        f454e660 2023-06-09        7.47
# 483104  SE-fcdf259d-0044-0        f454e660 2023-06-10       14.73
# 483105  SE-fcdf259d-0044-0        f454e660 2023-06-12       12.27
# 483106  SE-fcdf259d-0044-0        f454e660 2023-06-13        7.96
#
#         PreviousDailyYield  DailyYieldChange  HW  MeanTemperature  \
# 0                 0.000000          0.000000   0        -3.025000
# 1                30.770000          8.725000   0        -0.279167
# 2                39.495000         -2.988333   0         2.033333
# 3                36.506667          1.438333   0         0.066667
# 4                37.945000          0.109000   0        -3.700000
# ...                    ...               ...  ..              ...
# 483102           13.252000          0.494000   0        15.570833
# 483103           13.746000         -2.968000   0        13.254167
# 483104           10.778000          0.378000   0        13.258333
# 483105           11.156000          0.560000   0        15.820833
# 483106           11.716000         -0.202000   0        16.341667
#
#         MeanTHI_adj  DaysInMilk  ... Temp15Threshold   Age   BreedName  \
# 0         28.012944         191  ...               0  3095      02 SLB
# 1         32.898193         192  ...               0  3096      02 SLB
# 2         36.760487         193  ...               0  3097      02 SLB
# 3         31.939524         194  ...               0  3098      02 SLB
# 4         26.498206         195  ...               0  3099      02 SLB
# ...             ...         ...  ...             ...   ...         ...
# 483102    59.383267         352  ...               1  4155  41 Fjällko
# 483103    54.534255         353  ...               1  4156  41 Fjällko
# 483104    54.082367         354  ...               1  4157  41 Fjällko
# 483105    62.015093         356  ...               1  4159  41 Fjällko
# 483106    63.457792         357  ...               1  4160  41 Fjällko
#
#         LactationNumber   HeatLoad  CumulativeHeatLoad  HeatStress  \
# 0                     7 -34.987056            0.000000           0
# 1                     7 -30.101807            0.000000           0
# 2                     7 -26.239513            0.000000           0
# 3                     7 -31.060476            0.000000           0
# 4                     7 -36.501794            0.000000           0
# ...                 ...        ...                 ...         ...
# 483102               10  -3.616733            0.000000           0
# 483103               10  -8.465745            0.000000           0
# 483104               10  -8.917633            0.000000           0
# 483105               10  -0.984907            0.000000           0
# 483106               10   0.457792            0.457792           0
#
#         ExpectedYield  NormalizedDailyYield  NormalizedDailyYieldChange
# 0           35.914865              0.856748                    0.000000
# 1           35.799613              1.103224                    0.243718
# 2           35.684360              1.023044                   -0.083744
# 3           35.569108              1.066796                    0.040438
# 4           35.453856              1.073339                    0.003074
# ...               ...                   ...                         ...
# 483102      13.149489              1.045364                    0.037568
# 483103      13.057668              0.825415                   -0.227299
# 483104      12.965846              0.860414                    0.029154
# 483105      12.782204              0.916587                    0.043811
# 483106      12.690383              0.907301                   -0.015918
#
# [483107 rows x 22 columns]

# %%
# Check if NormalizedDailyYield is centered around 1 for each unique farm
print("Mean of NormalizedDailyYield:", data.groupby('FarmName_Pseudo')['NormalizedDailyYield'].mean())
print("Standard Deviation of NormalizedDailyYield:", data.groupby('FarmName_Pseudo')['NormalizedDailyYield'].std())
# Out:
# Mean of NormalizedDailyYield: FarmName_Pseudo
# 5c06d92d    0.999873
# 752efd72    1.000064
# a624fb9a    1.000214
# f454e660    0.999874
# Name: NormalizedDailyYield, dtype: float64
# Standard Deviation of NormalizedDailyYield: FarmName_Pseudo
# 5c06d92d    0.110106
# 752efd72    0.073153
# a624fb9a    0.101905
# f454e660    0.114833
# Name: NormalizedDailyYield, dtype: float64

# %%
# Make a dataframe from the parameters dictionary, it should contain Se_Number, LactationNumber, a, b, c, d
params_df = pd.DataFrame(params_dict).T.reset_index()
params_df.columns = ['SE_Number', 'LactationNumber', 'a', 'b', 'c', 'd']
params_df.head(-5)
# Out:
#              SE_Number  LactationNumber              a          b  \
# 0     SE-064c0cec-1189                7      57.928060  -0.115252
# 1     SE-064c0cec-1189                8      41.195196  -0.080255
# 2     SE-30dc5787-1389                5     115.924643  -0.343237
# 3     SE-30dc5787-1389                6      52.877694  -0.084404
# 4     SE-30dc5787-1389                7      47.551089  -0.094727
# ...                ...              ...            ...        ...
# 2227   SE-f454e660-686                1      24.464747  -0.029503
# 2228   SE-f454e660-688                1      22.360134   0.006013
# 2229   SE-f454e660-693                1  722399.241220 -24.952569
# 2230   SE-f454e660-701                1      25.337203  -0.007307
# 2231   SE-f454e660-712                1      25.797342  -0.036395
#
#                   c          d
# 0         -6.063436  17.367795
# 1        -44.398922   0.159012
# 2         12.205804   0.099999
# 3        -32.593600   0.093018
# 4        -45.321451   0.203812
# ...             ...        ...
# 2227     -30.107339   0.322460
# 2228      -0.083601  26.265057
# 2229 -722371.384516   0.000035
# 2230       4.771692   5.566311
# 2231     -30.408853   0.134107
#
# [2232 rows x 6 columns]

# %%
# Calculate Z-scores for each parameter
params_df['z_a'] = zscore(params_df['a'])
params_df['z_b'] = zscore(params_df['b'])
params_df['z_c'] = zscore(params_df['c'])
params_df['z_d'] = zscore(params_df['d'])

params_df.head(-5)
# Out:
#              SE_Number  LactationNumber              a          b  \
# 0     SE-064c0cec-1189                7      57.928060  -0.115252
# 1     SE-064c0cec-1189                8      41.195196  -0.080255
# 2     SE-30dc5787-1389                5     115.924643  -0.343237
# 3     SE-30dc5787-1389                6      52.877694  -0.084404
# 4     SE-30dc5787-1389                7      47.551089  -0.094727
# ...                ...              ...            ...        ...
# 2227   SE-f454e660-686                1      24.464747  -0.029503
# 2228   SE-f454e660-688                1      22.360134   0.006013
# 2229   SE-f454e660-693                1  722399.241220 -24.952569
# 2230   SE-f454e660-701                1      25.337203  -0.007307
# 2231   SE-f454e660-712                1      25.797342  -0.036395
#
#                   c          d       z_a       z_b       z_c       z_d
# 0         -6.063436  17.367795 -0.188741  0.112085 -0.047044  1.264524
# 1        -44.398922   0.159012 -0.188937  0.114493 -0.047044 -0.223807
# 2         12.205804   0.099999 -0.188061  0.096396 -0.047044 -0.228911
# 3        -32.593600   0.093018 -0.188800  0.114207 -0.047044 -0.229515
# 4        -45.321451   0.203812 -0.188863  0.113497 -0.047044 -0.219933
# ...             ...        ...       ...       ...       ...       ...
# 2227     -30.107339   0.322460 -0.189133  0.117985 -0.047044 -0.209671
# 2228      -0.083601  26.265057 -0.189158  0.120429 -0.047044  2.034019
# 2229 -722371.384516   0.000035  8.278968 -1.597036 -0.047044 -0.237557
# 2230       4.771692   5.566311 -0.189123  0.119513 -0.047044  0.243852
# 2231     -30.408853   0.134107 -0.189118  0.117511 -0.047044 -0.225961
#
# [2232 rows x 10 columns]

# %%
# Identify outliers (using Z-score > 3.5 or < -3.5 as threshold)
outliers = params_df[(np.abs(params_df[['z_a', 'z_b', 'z_c', 'z_d']]) > 3.5).any(axis=1)]

x = outliers.count()
print("Number of outliers:", x)

# Optionally, drop the outliers
params_df_cleaned = params_df.drop(outliers.index)
params_df_cleaned.head(-5)
# Out:
# Number of outliers: SE_Number          119
# LactationNumber    119
# a                  119
# b                  119
# c                  119
# d                  119
# z_a                119
# z_b                119
# z_c                119
# z_d                119
# dtype: int64
#              SE_Number  LactationNumber           a         b          c  \
# 0     SE-064c0cec-1189                7   57.928060 -0.115252  -6.063436
# 1     SE-064c0cec-1189                8   41.195196 -0.080255 -44.398922
# 2     SE-30dc5787-1389                5  115.924643 -0.343237  12.205804
# 3     SE-30dc5787-1389                6   52.877694 -0.084404 -32.593600
# 4     SE-30dc5787-1389                7   47.551089 -0.094727 -45.321451
# ...                ...              ...         ...       ...        ...
# 2226   SE-f454e660-671                1   39.063211 -0.042430 -35.990729
# 2227   SE-f454e660-686                1   24.464747 -0.029503 -30.107339
# 2228   SE-f454e660-688                1   22.360134  0.006013  -0.083601
# 2230   SE-f454e660-701                1   25.337203 -0.007307   4.771692
# 2231   SE-f454e660-712                1   25.797342 -0.036395 -30.408853
#
#               d       z_a       z_b       z_c       z_d
# 0     17.367795 -0.188741  0.112085 -0.047044  1.264524
# 1      0.159012 -0.188937  0.114493 -0.047044 -0.223807
# 2      0.099999 -0.188061  0.096396 -0.047044 -0.228911
# 3      0.093018 -0.188800  0.114207 -0.047044 -0.229515
# 4      0.203812 -0.188863  0.113497 -0.047044 -0.219933
# ...         ...       ...       ...       ...       ...
# 2226   0.055196 -0.188962  0.117096 -0.047044 -0.232786
# 2227   0.322460 -0.189133  0.117985 -0.047044 -0.209671
# 2228  26.265057 -0.189158  0.120429 -0.047044  2.034019
# 2230   5.566311 -0.189123  0.119513 -0.047044  0.243852
# 2231   0.134107 -0.189118  0.117511 -0.047044 -0.225961
#
# [2113 rows x 10 columns]

# %%
# Identify unique SE_Number and LactationNumber combinations from the outliers
outlier_combinations = outliers[['SE_Number', 'LactationNumber']].drop_duplicates()

# Merge with the original data to find rows that match these outlier combinations
data_cleaned = data.merge(outlier_combinations, on=['SE_Number', 'LactationNumber'], how='left', indicator=True)

# Keep only the rows that do not match the outlier combinations
data_cleaned = data_cleaned[data_cleaned['_merge'] == 'left_only'].drop(columns=['_merge'])

# Now data_cleaned contains the original data with the outlier combinations removed
print("Number of rows removed:", len(data) - len(data_cleaned))
data_cleaned.head(-5)
# Out:
# Number of rows removed: 15717
#                  SE_Number FarmName_Pseudo       Date  DailyYield  \
# 0         SE-064c0cec-1189        a624fb9a 2022-01-01       30.77
# 1         SE-064c0cec-1189        a624fb9a 2022-01-02       48.22
# 2         SE-064c0cec-1189        a624fb9a 2022-01-03       30.53
# 3         SE-064c0cec-1189        a624fb9a 2022-01-04       42.26
# 4         SE-064c0cec-1189        a624fb9a 2022-01-05       38.49
# ...                    ...             ...        ...         ...
# 483097  SE-fcdf259d-0044-0        f454e660 2023-06-03       12.67
# 483098  SE-fcdf259d-0044-0        f454e660 2023-06-04       22.31
# 483099  SE-fcdf259d-0044-0        f454e660 2023-06-05       12.84
# 483100  SE-fcdf259d-0044-0        f454e660 2023-06-06        9.47
# 483101  SE-fcdf259d-0044-0        f454e660 2023-06-07        8.97
#
#         PreviousDailyYield  DailyYieldChange  HW  MeanTemperature  \
# 0                 0.000000          0.000000   0        -3.025000
# 1                30.770000          8.725000   0        -0.279167
# 2                39.495000         -2.988333   0         2.033333
# 3                36.506667          1.438333   0         0.066667
# 4                37.945000          0.109000   0        -3.700000
# ...                    ...               ...  ..              ...
# 483097           14.652000         -0.622000   0        12.666667
# 483098           14.030000          0.954000   0        13.079167
# 483099           14.984000         -0.092000   0        14.237500
# 483100           14.892000         -0.284000   0        15.345833
# 483101           14.608000         -1.356000   0        15.645833
#
#         MeanTHI_adj  DaysInMilk  ... Temp15Threshold   Age   BreedName  \
# 0         28.012944         191  ...               0  3095      02 SLB
# 1         32.898193         192  ...               0  3096      02 SLB
# 2         36.760487         193  ...               0  3097      02 SLB
# 3         31.939524         194  ...               0  3098      02 SLB
# 4         26.498206         195  ...               0  3099      02 SLB
# ...             ...         ...  ...             ...   ...         ...
# 483097    53.132530         347  ...               1  4150  41 Fjällko
# 483098    56.726870         348  ...               1  4151  41 Fjällko
# 483099    58.482418         349  ...               1  4152  41 Fjällko
# 483100    60.546358         350  ...               1  4153  41 Fjällko
# 483101    61.559237         351  ...               1  4154  41 Fjällko
#
#         LactationNumber   HeatLoad  CumulativeHeatLoad  HeatStress  \
# 0                     7 -34.987056                 0.0           0
# 1                     7 -30.101807                 0.0           0
# 2                     7 -26.239513                 0.0           0
# 3                     7 -31.060476                 0.0           0
# 4                     7 -36.501794                 0.0           0
# ...                 ...        ...                 ...         ...
# 483097               10  -9.867470                 0.0           0
# 483098               10  -6.273130                 0.0           0
# 483099               10  -4.517582                 0.0           0
# 483100               10  -2.453642                 0.0           0
# 483101               10  -1.440763                 0.0           0
#
#         ExpectedYield  NormalizedDailyYield  NormalizedDailyYieldChange
# 0           35.914865              0.856748                    0.000000
# 1           35.799613              1.103224                    0.243718
# 2           35.684360              1.023044                   -0.083744
# 3           35.569108              1.066796                    0.040438
# 4           35.453856              1.073339                    0.003074
# ...               ...                   ...                         ...
# 483097      13.608593              1.030966                   -0.045706
# 483098      13.516773              1.108549                    0.070579
# 483099      13.424952              1.109278                   -0.006853
# 483100      13.333131              1.095617                   -0.021300
# 483101      13.241310              1.000807                   -0.102407
#
# [467385 rows x 22 columns]

# %%
# Check if NormalizedDailyYield is centered around 1 for each unique farm
print("Mean of NormalizedDailyYield:", data_cleaned.groupby('FarmName_Pseudo')['NormalizedDailyYield'].mean())
print("Standard Deviation of NormalizedDailyYield:", data_cleaned.groupby('FarmName_Pseudo')['NormalizedDailyYield'].std())
# Out:
# Mean of NormalizedDailyYield: FarmName_Pseudo
# 5c06d92d    0.999882
# 752efd72    1.000083
# a624fb9a    1.000167
# f454e660    0.999931
# Name: NormalizedDailyYield, dtype: float64
# Standard Deviation of NormalizedDailyYield: FarmName_Pseudo
# 5c06d92d    0.110462
# 752efd72    0.072759
# a624fb9a    0.101240
# f454e660    0.115457
# Name: NormalizedDailyYield, dtype: float64

# %%
data_cleaned['Residuals'] = data_cleaned['DailyYield'] - data_cleaned['ExpectedYield']
data_cleaned
# Out:
#                  SE_Number FarmName_Pseudo       Date  DailyYield  \
# 0         SE-064c0cec-1189        a624fb9a 2022-01-01       30.77
# 1         SE-064c0cec-1189        a624fb9a 2022-01-02       48.22
# 2         SE-064c0cec-1189        a624fb9a 2022-01-03       30.53
# 3         SE-064c0cec-1189        a624fb9a 2022-01-04       42.26
# 4         SE-064c0cec-1189        a624fb9a 2022-01-05       38.49
# ...                    ...             ...        ...         ...
# 483102  SE-fcdf259d-0044-0        f454e660 2023-06-08       15.14
# 483103  SE-fcdf259d-0044-0        f454e660 2023-06-09        7.47
# 483104  SE-fcdf259d-0044-0        f454e660 2023-06-10       14.73
# 483105  SE-fcdf259d-0044-0        f454e660 2023-06-12       12.27
# 483106  SE-fcdf259d-0044-0        f454e660 2023-06-13        7.96
#
#         PreviousDailyYield  DailyYieldChange  HW  MeanTemperature  \
# 0                 0.000000          0.000000   0        -3.025000
# 1                30.770000          8.725000   0        -0.279167
# 2                39.495000         -2.988333   0         2.033333
# 3                36.506667          1.438333   0         0.066667
# 4                37.945000          0.109000   0        -3.700000
# ...                    ...               ...  ..              ...
# 483102           13.252000          0.494000   0        15.570833
# 483103           13.746000         -2.968000   0        13.254167
# 483104           10.778000          0.378000   0        13.258333
# 483105           11.156000          0.560000   0        15.820833
# 483106           11.716000         -0.202000   0        16.341667
#
#         MeanTHI_adj  DaysInMilk  ...   Age   BreedName  LactationNumber  \
# 0         28.012944         191  ...  3095      02 SLB                7
# 1         32.898193         192  ...  3096      02 SLB                7
# 2         36.760487         193  ...  3097      02 SLB                7
# 3         31.939524         194  ...  3098      02 SLB                7
# 4         26.498206         195  ...  3099      02 SLB                7
# ...             ...         ...  ...   ...         ...              ...
# 483102    59.383267         352  ...  4155  41 Fjällko               10
# 483103    54.534255         353  ...  4156  41 Fjällko               10
# 483104    54.082367         354  ...  4157  41 Fjällko               10
# 483105    62.015093         356  ...  4159  41 Fjällko               10
# 483106    63.457792         357  ...  4160  41 Fjällko               10
#
#          HeatLoad CumulativeHeatLoad  HeatStress  ExpectedYield  \
# 0      -34.987056           0.000000           0      35.914865
# 1      -30.101807           0.000000           0      35.799613
# 2      -26.239513           0.000000           0      35.684360
# 3      -31.060476           0.000000           0      35.569108
# 4      -36.501794           0.000000           0      35.453856
# ...           ...                ...         ...            ...
# 483102  -3.616733           0.000000           0      13.149489
# 483103  -8.465745           0.000000           0      13.057668
# 483104  -8.917633           0.000000           0      12.965846
# 483105  -0.984907           0.000000           0      12.782204
# 483106   0.457792           0.457792           0      12.690383
#
#         NormalizedDailyYield  NormalizedDailyYieldChange  Residuals
# 0                   0.856748                    0.000000  -5.144865
# 1                   1.103224                    0.243718  12.420387
# 2                   1.023044                   -0.083744  -5.154360
# 3                   1.066796                    0.040438   6.690892
# 4                   1.073339                    0.003074   3.036144
# ...                      ...                         ...        ...
# 483102              1.045364                    0.037568   1.990511
# 483103              0.825415                   -0.227299  -5.587668
# 483104              0.860414                    0.029154   1.764154
# 483105              0.916587                    0.043811  -0.512204
# 483106              0.907301                   -0.015918  -4.730383
#
# [467390 rows x 23 columns]

# %%
# Group by 'FarmName_Pseudo' to perform calculations at the farm level
farm_results = []

for farm_name, farm_group in data_cleaned.groupby('FarmName_Pseudo'):
    farm_residuals = []
    
    for se_number, cow_group in farm_group.groupby('SE_Number'):
        residuals = cow_group['Residuals']
        
        if len(residuals) > 1:  # Ensure there are residuals to analyze
            farm_residuals.append(residuals)
    
    if len(farm_residuals) > 0:
        # Combine residuals from all cows in the farm
        combined_residuals = np.concatenate(farm_residuals)
        
        # Calculate farm-level statistics
        mean_residuals = combined_residuals.mean()
        std_residuals = combined_residuals.std()
        acf_values = acf(combined_residuals, nlags=30, fft=False)
        pacf_values = pacf(combined_residuals, nlags=min(30, len(combined_residuals)//2))

        # Print the farm-level statistics
        print(f"Farm: {farm_name}")
        print(f"Mean Residuals: {mean_residuals}")
        print(f"Standard Deviation of Residuals: {std_residuals}")
        print(f"ACF (first 5 lags): {acf_values[:5]}")
        print(f"PACF (first 5 lags): {pacf_values[:5]}")
        print("=" * 50)
# Out:
# Farm: 5c06d92d
# Mean Residuals: -0.007358816187875687
# Standard Deviation of Residuals: 5.284313563996281
# ACF (first 5 lags): [1.         0.26277774 0.24544434 0.18996471 0.15302048]
# PACF (first 5 lags): [1.         0.26277914 0.18947808 0.09793554 0.0550846 ]
# ==================================================
# Farm: 752efd72
# Mean Residuals: -0.025321862666249733
# Standard Deviation of Residuals: 3.517667102901537
# ACF (first 5 lags): [1.         0.29635308 0.25974486 0.20619966 0.1613189 ]
# PACF (first 5 lags): [1.         0.29635515 0.18847521 0.09988853 0.04970753]
# ==================================================
# Farm: a624fb9a
# Mean Residuals: -0.02967946086057544
# Standard Deviation of Residuals: 5.723818107888552
# ACF (first 5 lags): [ 1.         -0.05558486  0.24159506  0.20277682  0.18253758]
# PACF (first 5 lags): [ 1.         -0.05558582  0.23925285  0.24078754  0.17611915]
# ==================================================
# Farm: f454e660
# Mean Residuals: -0.013491751557388564
# Standard Deviation of Residuals: 6.964295467505133
# ACF (first 5 lags): [ 1.         -0.13958374  0.17589227  0.15993898  0.13689694]
# PACF (first 5 lags): [ 1.         -0.13958552  0.15952076  0.21228061  0.17345261]
# ==================================================

# %%
# Group by 'FarmName_Pseudo', 'SE_Number', and 'LactationNumber' to perform individual calculations
farm_results = []

for farm_name, farm_group in data_cleaned.groupby('FarmName_Pseudo'):
    print(f"Farm: {farm_name}")
    
    for (se_number, lactation_number), cow_group in farm_group.groupby(['SE_Number', 'LactationNumber']):
        residuals = cow_group['Residuals']
        
        if len(residuals) > 1:  # Ensure there are residuals to analyze
            mean_residuals = residuals.mean()
            std_residuals = residuals.std()
            acf_values = acf(residuals, nlags=30, fft=False)
            pacf_values = pacf(residuals, nlags=min(30, len(residuals)//2))

            # Print the statistics
            print(f"\nCow: {se_number}, Lactation Number: {lactation_number}")
            print(f"Mean Residuals: {mean_residuals}")
            print(f"Standard Deviation of Residuals: {std_residuals}")
            print(f"ACF (first 5 lags): {acf_values[:5]}")
            print(f"PACF (first 5 lags): {pacf_values[:5]}")
            print("-" * 50)
            
    print("=" * 50)
# Out:
# Farm: 5c06d92d
#
# Cow: SE-5c06d92d-2055, Lactation Number: 6
# Mean Residuals: -0.3578012321028742
# Standard Deviation of Residuals: 4.788415669121281
# ACF (first 5 lags): [ 1.          0.076273    0.31997299  0.02182998 -0.00740504]
# PACF (first 5 lags): [ 1.          0.07671388  0.31968996 -0.02151787 -0.12452141]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2055, Lactation Number: 7
# Mean Residuals: -0.07712953746114429
# Standard Deviation of Residuals: 8.538929848843226
# ACF (first 5 lags): [1.         0.37688227 0.31437413 0.26089741 0.23573651]
# PACF (first 5 lags): [1.         0.37790087 0.20213581 0.11109077 0.08573913]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2058, Lactation Number: 7
# Mean Residuals: -0.20389820995257132
# Standard Deviation of Residuals: 4.423873471197473
# ACF (first 5 lags): [ 1.         -0.047472    0.1369884   0.04060856  0.04892148]
# PACF (first 5 lags): [ 1.         -0.04769487  0.13631604  0.05451853  0.03615355]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2058, Lactation Number: 8
# Mean Residuals: -0.03964493660716798
# Standard Deviation of Residuals: 7.674564234201358
# ACF (first 5 lags): [1.         0.28956606 0.36330413 0.23780856 0.24356763]
# PACF (first 5 lags): [1.         0.29041772 0.30699803 0.09309798 0.08836119]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2211, Lactation Number: 7
# Mean Residuals: 0.09355828520987773
# Standard Deviation of Residuals: 8.589714493665701
# ACF (first 5 lags): [1.         0.33456747 0.43922025 0.41873603 0.35832941]
# PACF (first 5 lags): [1.         0.3361164  0.37240382 0.26952797 0.12368516]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2246, Lactation Number: 6
# Mean Residuals: 0.009655629080331556
# Standard Deviation of Residuals: 11.062182844605005
# ACF (first 5 lags): [1.         0.45480144 0.42360083 0.25172448 0.26964449]
# PACF (first 5 lags): [ 1.          0.45743035  0.27730866 -0.01694829  0.10500698]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2254, Lactation Number: 6
# Mean Residuals: -0.12897498920372127
# Standard Deviation of Residuals: 4.538955323321541
# ACF (first 5 lags): [ 1.         -0.1138256   0.06163606 -0.00441078 -0.05398553]
# PACF (first 5 lags): [ 1.         -0.11451966  0.04993243  0.00814095 -0.05897822]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2254, Lactation Number: 7
# Mean Residuals: -0.13855051052256542
# Standard Deviation of Residuals: 12.785406680651517
# ACF (first 5 lags): [1.         0.53388988 0.42727268 0.32114043 0.33393023]
# PACF (first 5 lags): [1.         0.53612373 0.20129149 0.04795953 0.14642668]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2268, Lactation Number: 6
# Mean Residuals: -0.368013626021052
# Standard Deviation of Residuals: 5.459130894373948
# ACF (first 5 lags): [1.         0.22794046 0.18380278 0.08821343 0.00296401]
# PACF (first 5 lags): [ 1.          0.22988867  0.14160674  0.02269527 -0.04889537]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2268, Lactation Number: 7
# Mean Residuals: 0.026947063502888075
# Standard Deviation of Residuals: 7.541917909453218
# ACF (first 5 lags): [1.         0.3465319  0.32572283 0.27850188 0.24122128]
# PACF (first 5 lags): [1.         0.34749182 0.23517995 0.13490938 0.0809633 ]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2268, Lactation Number: 8
# Mean Residuals: -0.35101266356346955
# Standard Deviation of Residuals: 3.4061181284213657
# ACF (first 5 lags): [ 1.          0.17622646 -0.03170125 -0.47076322 -0.43559364]
# PACF (first 5 lags): [ 1.          0.18881406 -0.07489933 -0.59116167 -0.62093187]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2283, Lactation Number: 6
# Mean Residuals: -0.1852028463604773
# Standard Deviation of Residuals: 4.104975451213846
# ACF (first 5 lags): [ 1.         -0.10898144  0.08981081 -0.05459357  0.09245231]
# PACF (first 5 lags): [ 1.         -0.10961506  0.07980465 -0.0383463   0.07967735]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2283, Lactation Number: 7
# Mean Residuals: -0.11585385233934986
# Standard Deviation of Residuals: 11.24326428205999
# ACF (first 5 lags): [1.         0.38611055 0.33200098 0.26495413 0.29014181]
# PACF (first 5 lags): [1.         0.38724952 0.21646483 0.10139853 0.14599601]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2325, Lactation Number: 5
# Mean Residuals: -0.15670607866725228
# Standard Deviation of Residuals: 2.701028530634671
# ACF (first 5 lags): [1.         0.09303587 0.33801273 0.17168722 0.27259969]
# PACF (first 5 lags): [1.         0.09419882 0.34071995 0.14230879 0.18164154]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2325, Lactation Number: 6
# Mean Residuals: 0.0417873545350707
# Standard Deviation of Residuals: 11.033519990097272
# ACF (first 5 lags): [1.         0.33287315 0.28173434 0.29723515 0.22718037]
# PACF (first 5 lags): [1.         0.33365272 0.19324583 0.18546605 0.06903692]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2325, Lactation Number: 7
# Mean Residuals: 3.6579669402261743
# Standard Deviation of Residuals: 11.097099277701446
# ACF (first 5 lags): [ 1.          0.02569758  0.26228795 -0.01072629  0.15912795]
# PACF (first 5 lags): [ 1.          0.02698245  0.28937984 -0.02826668  0.12420176]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2328, Lactation Number: 5
# Mean Residuals: 0.1194707028460514
# Standard Deviation of Residuals: 4.604544951111774
# ACF (first 5 lags): [ 1.00000000e+00 -3.09932120e-01  9.22376660e-02 -1.21253043e-02
#   8.04406011e-04]
# PACF (first 5 lags): [ 1.         -0.32185259 -0.00443146  0.01911742  0.00280605]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2333, Lactation Number: 6
# Mean Residuals: -0.09737885238344403
# Standard Deviation of Residuals: 5.442542210600574
# ACF (first 5 lags): [1.         0.09664689 0.19872318 0.15787795 0.11582042]
# PACF (first 5 lags): [1.         0.09694336 0.19235584 0.1310733  0.06365561]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2333, Lactation Number: 7
# Mean Residuals: 0.10222142734185913
# Standard Deviation of Residuals: 5.139396710294967
# ACF (first 5 lags): [1.         0.29032599 0.36844331 0.3652201  0.24971538]
# PACF (first 5 lags): [1.         0.29146452 0.31298111 0.2471118  0.04953227]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2351, Lactation Number: 5
# Mean Residuals: -0.13191177551614156
# Standard Deviation of Residuals: 4.68972473006063
# ACF (first 5 lags): [1.         0.51224242 0.60963628 0.49218351 0.45832176]
# PACF (first 5 lags): [1.         0.51435912 0.47608605 0.1543906  0.03934638]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2384, Lactation Number: 5
# Mean Residuals: -0.10942989321765516
# Standard Deviation of Residuals: 5.6136317947071595
# ACF (first 5 lags): [1.         0.43058808 0.43847133 0.32809642 0.35707719]
# PACF (first 5 lags): [1.         0.43375417 0.31634194 0.09071404 0.15157452]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2397, Lactation Number: 5
# Mean Residuals: -0.19201816157428758
# Standard Deviation of Residuals: 2.795630944727985
# ACF (first 5 lags): [1.         0.10888404 0.14519287 0.09496655 0.09424779]
# PACF (first 5 lags): [1.         0.10936797 0.13615649 0.06962114 0.06338636]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2401, Lactation Number: 5
# Mean Residuals: -0.08049945284075301
# Standard Deviation of Residuals: 4.512051927938067
# ACF (first 5 lags): [ 1.         -0.0082083   0.10655244  0.08518717  0.19564344]
# PACF (first 5 lags): [ 1.         -0.00824478  0.10744312  0.08904405  0.19350631]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2405, Lactation Number: 6
# Mean Residuals: 0.038322028575349394
# Standard Deviation of Residuals: 5.235675087918909
# ACF (first 5 lags): [1.         0.4541249  0.41849529 0.38189499 0.32088871]
# PACF (first 5 lags): [1.         0.45510573 0.26887558 0.16607916 0.06651737]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2406, Lactation Number: 5
# Mean Residuals: -0.09199689987100053
# Standard Deviation of Residuals: 9.599393653100845
# ACF (first 5 lags): [1.         0.59797518 0.49201478 0.38017513 0.25109694]
# PACF (first 5 lags): [ 1.          0.59984971  0.21133036  0.03724502 -0.06960349]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2408, Lactation Number: 5
# Mean Residuals: -0.13985234820457743
# Standard Deviation of Residuals: 4.41367547000305
# ACF (first 5 lags): [ 1.         -0.00984557  0.0961672   0.02670299  0.09432892]
# PACF (first 5 lags): [ 1.         -0.0098929   0.09700798  0.02919652  0.08824614]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2408, Lactation Number: 6
# Mean Residuals: -0.07118816237454342
# Standard Deviation of Residuals: 11.375942519962889
# ACF (first 5 lags): [1.         0.39928509 0.29810705 0.34304645 0.29335858]
# PACF (first 5 lags): [1.         0.40040668 0.16608939 0.2196547  0.1004144 ]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2410, Lactation Number: 4
# Mean Residuals: -0.5314648602476624
# Standard Deviation of Residuals: 5.861529560353431
# ACF (first 5 lags): [1.         0.61576413 0.58998155 0.45835285 0.35083473]
# PACF (first 5 lags): [ 1.          0.62238525  0.35166661  0.02114216 -0.07659663]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2410, Lactation Number: 5
# Mean Residuals: 0.029046880450360586
# Standard Deviation of Residuals: 9.206765451760445
# ACF (first 5 lags): [1.         0.25106137 0.20497073 0.19798626 0.1946725 ]
# PACF (first 5 lags): [1.         0.25157689 0.15215322 0.12790138 0.11087015]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2424, Lactation Number: 5
# Mean Residuals: -0.2710995579579893
# Standard Deviation of Residuals: 6.73619289689397
# ACF (first 5 lags): [ 1.          0.11127244  0.11547026  0.13493157 -0.0321318 ]
# PACF (first 5 lags): [ 1.          0.11174393  0.10528089  0.11597154 -0.071149  ]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2430, Lactation Number: 5
# Mean Residuals: -0.12098351027554685
# Standard Deviation of Residuals: 5.983737628876295
# ACF (first 5 lags): [1.         0.30275346 0.35690164 0.36180579 0.37149338]
# PACF (first 5 lags): [1.         0.30379028 0.29421909 0.24015219 0.209781  ]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2457, Lactation Number: 5
# Mean Residuals: 0.04906337496045417
# Standard Deviation of Residuals: 8.878165394388649
# ACF (first 5 lags): [1.         0.25750102 0.22906056 0.17092483 0.15639521]
# PACF (first 5 lags): [1.         0.25815624 0.17526507 0.08618725 0.0730028 ]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2457, Lactation Number: 6
# Mean Residuals: 0.1394295911158278
# Standard Deviation of Residuals: 10.559821387120188
# ACF (first 5 lags): [ 1.         -0.14873297  0.20823168  0.01981428  0.06527723]
# PACF (first 5 lags): [ 1.         -0.14946927  0.19225781  0.07884964  0.04133237]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2461, Lactation Number: 4
# Mean Residuals: -0.6125497222222241
# Standard Deviation of Residuals: 7.2412620091927185
# ACF (first 5 lags): [1.         0.56037612 0.404727   0.20699026 0.18870543]
# PACF (first 5 lags): [ 1.          0.57638686  0.14422851 -0.10506527  0.11448517]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2461, Lactation Number: 5
# Mean Residuals: 0.019616311288811597
# Standard Deviation of Residuals: 7.199709964228086
# ACF (first 5 lags): [1.         0.10443268 0.15530596 0.13486072 0.00877171]
# PACF (first 5 lags): [ 1.          0.10468074  0.14669495  0.11008065 -0.03552566]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2465, Lactation Number: 5
# Mean Residuals: -0.06114073135999069
# Standard Deviation of Residuals: 5.482415745990347
# ACF (first 5 lags): [1.         0.105387   0.07325182 0.07537507 0.01798651]
# PACF (first 5 lags): [1.00000000e+00 1.05652457e-01 6.31644097e-02 6.29378973e-02
#  1.14816030e-04]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2470, Lactation Number: 4
# Mean Residuals: -0.9029791312833445
# Standard Deviation of Residuals: 8.524902086756896
# ACF (first 5 lags): [ 1.          0.41360614  0.20436844  0.13379893 -0.08785031]
# PACF (first 5 lags): [ 1.          0.42542345  0.04322876  0.04831167 -0.22510497]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2470, Lactation Number: 5
# Mean Residuals: -0.10386022417000756
# Standard Deviation of Residuals: 7.8608189189861015
# ACF (first 5 lags): [1.         0.21903137 0.08438322 0.04361943 0.08349751]
# PACF (first 5 lags): [1.         0.21974716 0.03850721 0.01856486 0.07190429]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2470, Lactation Number: 6
# Mean Residuals: 0.08337855336912231
# Standard Deviation of Residuals: 9.011737670311822
# ACF (first 5 lags): [ 1.         -0.20265853  0.0470484   0.06765495  0.10204411]
# PACF (first 5 lags): [ 1.         -0.20366179  0.00629972  0.08301562  0.14060403]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2478, Lactation Number: 5
# Mean Residuals: -0.05833179610311904
# Standard Deviation of Residuals: 7.950618449685666
# ACF (first 5 lags): [1.         0.32858056 0.24210358 0.16243319 0.12879574]
# PACF (first 5 lags): [1.         0.32955269 0.15137557 0.0526852  0.04049003]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2478, Lactation Number: 6
# Mean Residuals: 0.0636706650590238
# Standard Deviation of Residuals: 7.091564746840962
# ACF (first 5 lags): [1.         0.20643118 0.39606336 0.40630719 0.26298526]
# PACF (first 5 lags): [1.         0.20726022 0.37229315 0.34223607 0.08842723]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2483, Lactation Number: 4
# Mean Residuals: -0.18548124161663535
# Standard Deviation of Residuals: 5.79215095349634
# ACF (first 5 lags): [1.         0.16614667 0.03041433 0.14657595 0.21610027]
# PACF (first 5 lags): [1.         0.16735063 0.00293428 0.14832443 0.18243429]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2483, Lactation Number: 5
# Mean Residuals: 0.04050081607207814
# Standard Deviation of Residuals: 8.857844311463925
# ACF (first 5 lags): [1.         0.30343704 0.3423368  0.29271384 0.20606742]
# PACF (first 5 lags): [1.         0.30428939 0.27735422 0.16128934 0.02984034]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2489, Lactation Number: 5
# Mean Residuals: -0.36696545337246883
# Standard Deviation of Residuals: 7.626902248023443
# ACF (first 5 lags): [1.         0.3980207  0.30082588 0.23957303 0.21059917]
# PACF (first 5 lags): [1.         0.39963867 0.17085853 0.09039738 0.07241598]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2501, Lactation Number: 5
# Mean Residuals: -0.10992162241570068
# Standard Deviation of Residuals: 4.7312886193066275
# ACF (first 5 lags): [1.         0.22747521 0.21414702 0.07865372 0.14029017]
# PACF (first 5 lags): [ 1.00000000e+00  2.28080201e-01  1.72227960e-01 -6.99459789e-04
#   9.76981176e-02]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2502, Lactation Number: 4
# Mean Residuals: -0.4330982439291555
# Standard Deviation of Residuals: 2.034004510830807
# ACF (first 5 lags): [ 1.         -0.1636344  -0.15088013 -0.06692686  0.07212168]
# PACF (first 5 lags): [ 1.         -0.17325995 -0.20594131 -0.16306249  0.00470998]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2506, Lactation Number: 5
# Mean Residuals: 0.0806901529428068
# Standard Deviation of Residuals: 7.964197303668228
# ACF (first 5 lags): [1.         0.16672625 0.15212472 0.12811702 0.17499503]
# PACF (first 5 lags): [1.         0.16720951 0.12864699 0.08936978 0.13398725]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2514, Lactation Number: 4
# Mean Residuals: -0.09766862046762421
# Standard Deviation of Residuals: 5.143611245518111
# ACF (first 5 lags): [1.         0.02232468 0.17783921 0.10306125 0.01431847]
# PACF (first 5 lags): [ 1.          0.02247972  0.17991205  0.10119484 -0.02055995]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2514, Lactation Number: 5
# Mean Residuals: -0.09225300455267135
# Standard Deviation of Residuals: 5.61555137165802
# ACF (first 5 lags): [1.         0.22987195 0.24002383 0.12746824 0.12305922]
# PACF (first 5 lags): [1.         0.23052131 0.19880836 0.04194192 0.05067304]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2514, Lactation Number: 6
# Mean Residuals: 0.42676990304527335
# Standard Deviation of Residuals: 3.9177672027089354
# ACF (first 5 lags): [1.         0.31760238 0.08577917 0.13023393 0.21308708]
# PACF (first 5 lags): [ 1.          0.32382988 -0.0174895   0.12792703  0.16915243]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2515, Lactation Number: 4
# Mean Residuals: -1.1255281064436462
# Standard Deviation of Residuals: 6.519800282376801
# ACF (first 5 lags): [ 1.          0.21434549  0.07130581 -0.02180095  0.00793199]
# PACF (first 5 lags): [ 1.          0.22228421  0.0288038  -0.04990249  0.02386829]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2515, Lactation Number: 5
# Mean Residuals: -0.14955046649845644
# Standard Deviation of Residuals: 6.051203808805832
# ACF (first 5 lags): [ 1.          0.08314809  0.16772038 -0.04983351  0.11387102]
# PACF (first 5 lags): [ 1.          0.08347416  0.16321032 -0.07847858  0.10189342]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2515, Lactation Number: 6
# Mean Residuals: 0.11396004948569095
# Standard Deviation of Residuals: 8.977618905640183
# ACF (first 5 lags): [1.         0.16798796 0.28232753 0.20901945 0.21952975]
# PACF (first 5 lags): [1.         0.16859224 0.26343022 0.14551349 0.12460838]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2529, Lactation Number: 4
# Mean Residuals: -1.229104723262731
# Standard Deviation of Residuals: 4.848484077985481
# ACF (first 5 lags): [1.         0.49332064 0.18864902 0.05446381 0.08019885]
# PACF (first 5 lags): [ 1.          0.50741551 -0.07774032 -0.01405317  0.10695381]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2529, Lactation Number: 5
# Mean Residuals: 0.08253579399804412
# Standard Deviation of Residuals: 6.820883078643599
# ACF (first 5 lags): [ 1.          0.02620235  0.12221221  0.10480103 -0.03607888]
# PACF (first 5 lags): [ 1.          0.02628103  0.12234223  0.10128461 -0.05651651]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2534, Lactation Number: 5
# Mean Residuals: -0.17565044416789222
# Standard Deviation of Residuals: 3.877311327716682
# ACF (first 5 lags): [ 1.         -0.14145367  0.02351366 -0.03396769  0.03367954]
# PACF (first 5 lags): [ 1.         -0.14207682  0.00360877 -0.03117951  0.02554156]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2536, Lactation Number: 4
# Mean Residuals: -0.1921178240495146
# Standard Deviation of Residuals: 4.564560085311503
# ACF (first 5 lags): [ 1.         -0.11803058  0.09408053  0.05805738  0.02207706]
# PACF (first 5 lags): [ 1.         -0.11872081  0.08225204  0.08090418  0.03121881]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2536, Lactation Number: 5
# Mean Residuals: -0.045307999396031834
# Standard Deviation of Residuals: 7.392082244102582
# ACF (first 5 lags): [1.         0.19748982 0.15604511 0.1105606  0.01516991]
# PACF (first 5 lags): [ 1.          0.19818035  0.12268315  0.06350616 -0.03533363]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2536, Lactation Number: 6
# Mean Residuals: 0.02074923513440873
# Standard Deviation of Residuals: 6.431394720712653
# ACF (first 5 lags): [ 1.         -0.08063585 -0.00973282 -0.06196336  0.15599887]
# PACF (first 5 lags): [ 1.         -0.08154187 -0.01671423 -0.06675053  0.15395206]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2550, Lactation Number: 4
# Mean Residuals: -0.4750560780203514
# Standard Deviation of Residuals: 4.448443516916122
# ACF (first 5 lags): [1.         0.24066636 0.26917689 0.11116114 0.08408288]
# PACF (first 5 lags): [1.         0.24281517 0.22854239 0.00826122 0.00200112]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2550, Lactation Number: 5
# Mean Residuals: 0.06971938137662811
# Standard Deviation of Residuals: 4.2680243433085545
# ACF (first 5 lags): [1.         0.13643628 0.21724425 0.08269366 0.02877493]
# PACF (first 5 lags): [ 1.          0.13676113  0.20338158  0.03368906 -0.0294292 ]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2558, Lactation Number: 5
# Mean Residuals: -0.30316959267060856
# Standard Deviation of Residuals: 6.470540553116426
# ACF (first 5 lags): [1.         0.46954425 0.31650236 0.21462527 0.159052  ]
# PACF (first 5 lags): [1.         0.47137127 0.12443176 0.03506302 0.02782339]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2558, Lactation Number: 6
# Mean Residuals: -0.1846716602988938
# Standard Deviation of Residuals: 8.75902516824943
# ACF (first 5 lags): [1.         0.22179719 0.22645205 0.20134086 0.13419104]
# PACF (first 5 lags): [1.         0.22256732 0.18779664 0.13134341 0.04180627]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2564, Lactation Number: 4
# Mean Residuals: -0.44343371254123365
# Standard Deviation of Residuals: 3.838840914384191
# ACF (first 5 lags): [1.         0.2667595  0.2893293  0.09945341 0.05061603]
# PACF (first 5 lags): [ 1.          0.26865141  0.23850258 -0.02572425 -0.03882391]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2564, Lactation Number: 5
# Mean Residuals: -0.06383430861635175
# Standard Deviation of Residuals: 6.482916582049543
# ACF (first 5 lags): [1.         0.06540462 0.2715639  0.17508048 0.1172695 ]
# PACF (first 5 lags): [1.         0.0655702  0.26980295 0.15777139 0.03955063]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2566, Lactation Number: 4
# Mean Residuals: -0.3279737684587245
# Standard Deviation of Residuals: 6.357876032866514
# ACF (first 5 lags): [1.         0.22780767 0.2008711  0.12380807 0.16658184]
# PACF (first 5 lags): [1.         0.22861838 0.15831402 0.05413228 0.11253456]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2569, Lactation Number: 5
# Mean Residuals: -0.2525865143615541
# Standard Deviation of Residuals: 6.342590876826505
# ACF (first 5 lags): [ 1.          0.11487092  0.06787226 -0.0268137  -0.00408327]
# PACF (first 5 lags): [ 1.00000000e+00  1.15265665e-01  5.57954780e-02 -4.16423053e-02
#  -4.59678522e-04]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2569, Lactation Number: 6
# Mean Residuals: -0.004803455113460907
# Standard Deviation of Residuals: 12.143195350064625
# ACF (first 5 lags): [1.         0.38597843 0.38491806 0.50715781 0.247379  ]
# PACF (first 5 lags): [ 1.          0.38817149  0.28097679  0.38116561 -0.07712713]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2572, Lactation Number: 4
# Mean Residuals: -0.14883706764822313
# Standard Deviation of Residuals: 2.721927319920731
# ACF (first 5 lags): [ 1.          0.17490918  0.07211749 -0.03956924 -0.3218043 ]
# PACF (first 5 lags): [ 1.          0.17782434  0.04434284 -0.06432885 -0.34273968]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2572, Lactation Number: 5
# Mean Residuals: 0.04517296188833407
# Standard Deviation of Residuals: 4.528474017740151
# ACF (first 5 lags): [1.         0.10836739 0.25317136 0.13419106 0.13372949]
# PACF (first 5 lags): [1.         0.10855852 0.24517033 0.09417299 0.0610335 ]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2577, Lactation Number: 4
# Mean Residuals: -1.1246536843047672
# Standard Deviation of Residuals: 6.689920683853048
# ACF (first 5 lags): [1.         0.23223795 0.18956966 0.22550259 0.04886241]
# PACF (first 5 lags): [ 1.          0.2369775   0.14971797  0.17842183 -0.05996353]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2577, Lactation Number: 5
# Mean Residuals: 0.001982971382823066
# Standard Deviation of Residuals: 6.032929609178159
# ACF (first 5 lags): [ 1.          0.16215397  0.05807329  0.06784202 -0.02602143]
# PACF (first 5 lags): [ 1.          0.1626909   0.0328606   0.05550351 -0.04896033]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2577, Lactation Number: 6
# Mean Residuals: 0.2052207596548579
# Standard Deviation of Residuals: 9.896688237374445
# ACF (first 5 lags): [ 1.          0.04916279  0.14012462  0.15172384 -0.02926915]
# PACF (first 5 lags): [ 1.          0.04945369  0.13968873  0.14467868 -0.06214715]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2582, Lactation Number: 4
# Mean Residuals: -2.1413055291749075
# Standard Deviation of Residuals: 8.815560782932804
# ACF (first 5 lags): [ 1.          0.57169448  0.363502    0.11437621 -0.15025827]
# PACF (first 5 lags): [ 1.          0.59768059  0.06362874 -0.20198513 -0.33678899]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2582, Lactation Number: 5
# Mean Residuals: -0.11639412859930368
# Standard Deviation of Residuals: 11.513471853591806
# ACF (first 5 lags): [1.         0.53109338 0.46302044 0.43231422 0.36852097]
# PACF (first 5 lags): [1.         0.5331051  0.25473698 0.17345814 0.06253491]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2582, Lactation Number: 6
# Mean Residuals: 0.13299925033411605
# Standard Deviation of Residuals: 10.10958160588955
# ACF (first 5 lags): [ 1.          0.14675915  0.01410607  0.18108376 -0.02589437]
# PACF (first 5 lags): [ 1.          0.1476486  -0.00768964  0.18752655 -0.08627098]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2591, Lactation Number: 4
# Mean Residuals: 0.04066971062443219
# Standard Deviation of Residuals: 5.879952071966344
# ACF (first 5 lags): [1.         0.11283265 0.16991071 0.10029823 0.08319526]
# PACF (first 5 lags): [1.         0.11314782 0.16010995 0.06943616 0.04341527]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2594, Lactation Number: 4
# Mean Residuals: -0.39887280813967846
# Standard Deviation of Residuals: 6.436815260826194
# ACF (first 5 lags): [1.         0.2751542  0.26027697 0.23126068 0.08702277]
# PACF (first 5 lags): [ 1.          0.2764049   0.2016611   0.1362744  -0.04530826]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2594, Lactation Number: 5
# Mean Residuals: 0.0731646963840381
# Standard Deviation of Residuals: 6.32499915983628
# ACF (first 5 lags): [ 1.         -0.0774428   0.21141638  0.08258614  0.01087472]
# PACF (first 5 lags): [ 1.         -0.07764606  0.20775271  0.11822971 -0.01958278]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2595, Lactation Number: 4
# Mean Residuals: -0.029964282600324244
# Standard Deviation of Residuals: 9.853115776137491
# ACF (first 5 lags): [1.         0.30952686 0.19668684 0.21225997 0.12821336]
# PACF (first 5 lags): [1.         0.31039632 0.11226537 0.1397676  0.01836918]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2601, Lactation Number: 5
# Mean Residuals: 0.0739865645312463
# Standard Deviation of Residuals: 7.153459164649893
# ACF (first 5 lags): [ 1.          0.09243697  0.18293841  0.18185307 -0.06709448]
# PACF (first 5 lags): [ 1.          0.09262409  0.17661656  0.15887075 -0.12965703]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2606, Lactation Number: 4
# Mean Residuals: -2.024587441732747
# Standard Deviation of Residuals: 6.746738698222557
# ACF (first 5 lags): [ 1.          0.42658718  0.34667361  0.12375974 -0.11990196]
# PACF (first 5 lags): [ 1.          0.4459775   0.22568131 -0.11764137 -0.32905654]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2606, Lactation Number: 5
# Mean Residuals: 0.08067860945940122
# Standard Deviation of Residuals: 6.470438746466692
# ACF (first 5 lags): [1.         0.09758475 0.16481263 0.166563   0.15300795]
# PACF (first 5 lags): [1.         0.0979201  0.15787468 0.14408699 0.11287929]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2607, Lactation Number: 5
# Mean Residuals: -0.0759553649608094
# Standard Deviation of Residuals: 5.723991442250526
# ACF (first 5 lags): [1.         0.23886513 0.17390811 0.07954775 0.02238055]
# PACF (first 5 lags): [ 1.          0.23974009  0.1248896   0.0148016  -0.02037098]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2607, Lactation Number: 6
# Mean Residuals: 0.012104209686157621
# Standard Deviation of Residuals: 2.9044268513767904
# ACF (first 5 lags): [1.         0.26062902 0.16276143 0.14280411 0.18585465]
# PACF (first 5 lags): [1.         0.2618137  0.10274416 0.0860282  0.13169248]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2610, Lactation Number: 4
# Mean Residuals: -0.04067412621613358
# Standard Deviation of Residuals: 11.291518169776902
# ACF (first 5 lags): [1.         0.5146039  0.48354685 0.37910368 0.32153665]
# PACF (first 5 lags): [1.         0.51543391 0.29882711 0.07715225 0.03538566]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2618, Lactation Number: 4
# Mean Residuals: -0.13644289916327507
# Standard Deviation of Residuals: 3.8403731356213644
# ACF (first 5 lags): [1.         0.06687183 0.06511623 0.17906267 0.05551173]
# PACF (first 5 lags): [1.         0.06710163 0.06133886 0.17411194 0.03310184]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2621, Lactation Number: 4
# Mean Residuals: -0.08688122309461473
# Standard Deviation of Residuals: 7.744054746059199
# ACF (first 5 lags): [1.         0.17206214 0.13653731 0.00499545 0.02001749]
# PACF (first 5 lags): [ 1.          0.17264939  0.11097253 -0.03674747  0.01025311]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2621, Lactation Number: 5
# Mean Residuals: -0.08942507935142363
# Standard Deviation of Residuals: 5.274444394952702
# ACF (first 5 lags): [1.         0.2481668  0.2764669  0.12797035 0.09490388]
# PACF (first 5 lags): [1.         0.24914    0.23090554 0.02091225 0.00427047]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2628, Lactation Number: 4
# Mean Residuals: -0.26188888561573304
# Standard Deviation of Residuals: 5.219026071063348
# ACF (first 5 lags): [ 1.         -0.00606564 -0.01365466 -0.01016385 -0.0328373 ]
# PACF (first 5 lags): [ 1.         -0.00611456 -0.01391459 -0.01058734 -0.03425942]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2628, Lactation Number: 5
# Mean Residuals: -0.15102804269821285
# Standard Deviation of Residuals: 12.533162675948283
# ACF (first 5 lags): [1.         0.74983256 0.69225849 0.69237341 0.65166951]
# PACF (first 5 lags): [1.         0.75690646 0.31032375 0.2829371  0.10923007]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2630, Lactation Number: 4
# Mean Residuals: -0.3183511688786941
# Standard Deviation of Residuals: 6.1818063687084015
# ACF (first 5 lags): [1.         0.14941642 0.15021404 0.15660362 0.18021674]
# PACF (first 5 lags): [1.         0.14986244 0.13161059 0.12348962 0.13576288]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2630, Lactation Number: 5
# Mean Residuals: 0.21910635716685212
# Standard Deviation of Residuals: 9.44549192281902
# ACF (first 5 lags): [ 1.         -0.11012214  0.11657244  0.20518073 -0.00979043]
# PACF (first 5 lags): [ 1.         -0.11059274  0.10664668  0.23680088  0.02898897]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2631, Lactation Number: 4
# Mean Residuals: -0.13744720770293614
# Standard Deviation of Residuals: 4.227670915061532
# ACF (first 5 lags): [ 1.         -0.0038634   0.02104017  0.07886677 -0.00391802]
# PACF (first 5 lags): [ 1.         -0.00388331  0.02124344  0.08029981 -0.00373104]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2631, Lactation Number: 5
# Mean Residuals: 0.4287151363871564
# Standard Deviation of Residuals: 9.205318386351122
# ACF (first 5 lags): [1.         0.45969208 0.32782928 0.26982437 0.06743227]
# PACF (first 5 lags): [ 1.          0.46566211  0.15273424  0.10034058 -0.15865308]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2636, Lactation Number: 4
# Mean Residuals: -0.3853848498262589
# Standard Deviation of Residuals: 8.492048229968432
# ACF (first 5 lags): [ 1.         -0.01582807  0.01930818 -0.02580727 -0.03310835]
# PACF (first 5 lags): [ 1.         -0.01589689  0.01922895 -0.0255534  -0.03490405]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2636, Lactation Number: 5
# Mean Residuals: -0.029435299634413135
# Standard Deviation of Residuals: 10.68145657322861
# ACF (first 5 lags): [1.         0.39964763 0.53225268 0.32833279 0.33494609]
# PACF (first 5 lags): [1.         0.40220947 0.45017371 0.05153063 0.0302496 ]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2638, Lactation Number: 4
# Mean Residuals: -0.24694133395954349
# Standard Deviation of Residuals: 4.550753983047439
# ACF (first 5 lags): [ 1.          0.00823755  0.04817442 -0.02529437 -0.00819335]
# PACF (first 5 lags): [ 1.          0.00826806  0.04846754 -0.02642394 -0.01025793]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2638, Lactation Number: 5
# Mean Residuals: -0.025243245084591442
# Standard Deviation of Residuals: 4.93620949179537
# ACF (first 5 lags): [1.         0.346145   0.36961601 0.28854378 0.26589836]
# PACF (first 5 lags): [1.         0.34718136 0.28574304 0.12349267 0.08732085]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2639, Lactation Number: 4
# Mean Residuals: 0.002166757470537836
# Standard Deviation of Residuals: 4.260168588383137
# ACF (first 5 lags): [1.         0.06657192 0.09430267 0.04799611 0.04670831]
# PACF (first 5 lags): [1.         0.06681577 0.0909377  0.03715306 0.03419065]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2639, Lactation Number: 5
# Mean Residuals: -0.06746129337805049
# Standard Deviation of Residuals: 4.079692995842759
# ACF (first 5 lags): [1.         0.25274369 0.26868662 0.22149175 0.11689703]
# PACF (first 5 lags): [ 1.          0.25365284  0.22047194  0.12858647 -0.00540033]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2643, Lactation Number: 4
# Mean Residuals: -0.2532986366916844
# Standard Deviation of Residuals: 4.914199934052641
# ACF (first 5 lags): [ 1.         -0.02137362  0.13893825 -0.02674584 -0.01792525]
# PACF (first 5 lags): [ 1.         -0.02152205  0.14048332 -0.02212806 -0.03988861]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2643, Lactation Number: 5
# Mean Residuals: 0.01825713871569641
# Standard Deviation of Residuals: 5.323588505917023
# ACF (first 5 lags): [ 1.          0.11711174 -0.00163054  0.1614557   0.11831906]
# PACF (first 5 lags): [ 1.          0.1174859  -0.01566008  0.1673999   0.08373053]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2643, Lactation Number: 6
# Mean Residuals: 0.4035527352951595
# Standard Deviation of Residuals: 3.7415169258630856
# ACF (first 5 lags): [ 1.          0.12018152  0.11362041 -0.02400885  0.08041845]
# PACF (first 5 lags): [ 1.          0.12151687  0.10292719 -0.0512915   0.0828806 ]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2647, Lactation Number: 3
# Mean Residuals: -2.401710690658645
# Standard Deviation of Residuals: 8.55561362303295
# ACF (first 5 lags): [ 1.          0.63568753  0.3537516   0.03840813 -0.25574784]
# PACF (first 5 lags): [ 1.          0.675418   -0.10163647 -0.34007116 -0.41713853]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2647, Lactation Number: 4
# Mean Residuals: 0.10190350940722741
# Standard Deviation of Residuals: 8.269561209974263
# ACF (first 5 lags): [1.         0.41451903 0.4231533  0.36096679 0.21600526]
# PACF (first 5 lags): [ 1.          0.41613824  0.30635249  0.15301401 -0.06064511]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2649, Lactation Number: 3
# Mean Residuals: -0.5337187972466877
# Standard Deviation of Residuals: 4.16547092365818
# ACF (first 5 lags): [ 1.          0.202779    0.02311448 -0.02329749 -0.02074636]
# PACF (first 5 lags): [ 1.          0.20525191 -0.01925429 -0.02629114 -0.01152763]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2649, Lactation Number: 4
# Mean Residuals: 0.0933308245103981
# Standard Deviation of Residuals: 7.277971511595492
# ACF (first 5 lags): [ 1.          0.04418315  0.06791404 -0.05085427 -0.01782267]
# PACF (first 5 lags): [ 1.          0.04431994  0.06650224 -0.0574707  -0.01805997]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2649, Lactation Number: 5
# Mean Residuals: 0.15540170909091258
# Standard Deviation of Residuals: 8.714149300748636
# ACF (first 5 lags): [ 1.00000000e+00 -2.09270314e-02  6.27541058e-02  2.24122019e-01
#  -5.46308897e-04]
# PACF (first 5 lags): [ 1.         -0.02106748  0.06318634  0.23231259  0.00838066]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2650, Lactation Number: 4
# Mean Residuals: -0.2857258662705196
# Standard Deviation of Residuals: 8.580269886784585
# ACF (first 5 lags): [ 1.          0.03965232 -0.0316021   0.07842542  0.051647  ]
# PACF (first 5 lags): [ 1.          0.03983338 -0.03353193  0.08238149  0.04507859]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2651, Lactation Number: 4
# Mean Residuals: 0.03727783543495174
# Standard Deviation of Residuals: 4.71621944199507
# ACF (first 5 lags): [ 1.          0.04729366  0.04579502 -0.0599064  -0.05353402]
# PACF (first 5 lags): [ 1.          0.04742878  0.04390674 -0.0648645  -0.05074472]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2651, Lactation Number: 5
# Mean Residuals: 0.06692470679155349
# Standard Deviation of Residuals: 4.614303586353713
# ACF (first 5 lags): [1.         0.1935553  0.15607172 0.15448141 0.03821162]
# PACF (first 5 lags): [ 1.          0.19445976  0.12442777  0.11152719 -0.02550785]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2656, Lactation Number: 4
# Mean Residuals: -0.0569479307738729
# Standard Deviation of Residuals: 5.12797204749229
# ACF (first 5 lags): [1.         0.31179298 0.3193752  0.23352015 0.19116422]
# PACF (first 5 lags): [1.         0.31253182 0.24737934 0.09726611 0.04872945]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2657, Lactation Number: 4
# Mean Residuals: -0.17165243132875457
# Standard Deviation of Residuals: 3.473579667051334
# ACF (first 5 lags): [ 1.00000000e+00  7.61792118e-04 -4.22104178e-02 -4.79921706e-02
#   1.07345441e-01]
# PACF (first 5 lags): [ 1.00000000e+00  7.66409040e-04 -4.27257915e-02 -4.88978640e-02
#   1.08604091e-01]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2657, Lactation Number: 5
# Mean Residuals: 0.024850881591624234
# Standard Deviation of Residuals: 5.535759726066511
# ACF (first 5 lags): [ 1.         -0.0112991  -0.02196212  0.03876526  0.01155332]
# PACF (first 5 lags): [ 1.         -0.01134256 -0.02226323  0.03873106  0.01213633]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2660, Lactation Number: 4
# Mean Residuals: 0.003452322442212405
# Standard Deviation of Residuals: 9.116588197399754
# ACF (first 5 lags): [1.         0.3615863  0.39144933 0.28013477 0.21365685]
# PACF (first 5 lags): [1.         0.36311199 0.30284683 0.0936057  0.01195341]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2662, Lactation Number: 4
# Mean Residuals: -0.30193078165143294
# Standard Deviation of Residuals: 7.434907541760405
# ACF (first 5 lags): [1.         0.23353771 0.32831197 0.18412031 0.109653  ]
# PACF (first 5 lags): [ 1.          0.23435143  0.29170805  0.0726516  -0.02932604]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2662, Lactation Number: 5
# Mean Residuals: 0.13182576450582306
# Standard Deviation of Residuals: 8.274762683803235
# ACF (first 5 lags): [1.         0.09352419 0.23511691 0.15255922 0.07383553]
# PACF (first 5 lags): [1.         0.09383909 0.22992443 0.12295521 0.0045437 ]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2663, Lactation Number: 4
# Mean Residuals: -0.22575197921377851
# Standard Deviation of Residuals: 6.086569651540649
# ACF (first 5 lags): [1.         0.12379159 0.10151631 0.15666604 0.06794407]
# PACF (first 5 lags): [1.         0.12419482 0.08811457 0.13889578 0.029445  ]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2669, Lactation Number: 3
# Mean Residuals: 0.32812699559970715
# Standard Deviation of Residuals: 10.18172228422591
# ACF (first 5 lags): [1.         0.65281922 0.4187067  0.32988193 0.1989874 ]
# PACF (first 5 lags): [ 1.          0.66561959 -0.01363581  0.11736687 -0.10723119]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2673, Lactation Number: 3
# Mean Residuals: -0.2675835119400193
# Standard Deviation of Residuals: 3.8785030358653305
# ACF (first 5 lags): [1.         0.14652494 0.11013136 0.05251181 0.15980438]
# PACF (first 5 lags): [1.         0.14805124 0.09255957 0.02616968 0.15029509]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2673, Lactation Number: 4
# Mean Residuals: -0.048113045288392726
# Standard Deviation of Residuals: 8.073439432079853
# ACF (first 5 lags): [1.         0.28643521 0.34631462 0.32593387 0.34891527]
# PACF (first 5 lags): [1.         0.28699247 0.28911278 0.20684167 0.1977256 ]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2683, Lactation Number: 3
# Mean Residuals: -0.15598802759890457
# Standard Deviation of Residuals: 4.246944672391096
# ACF (first 5 lags): [1.         0.12169368 0.15437437 0.13916417 0.07846903]
# PACF (first 5 lags): [1.         0.12215464 0.14275675 0.11091243 0.03484643]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2688, Lactation Number: 4
# Mean Residuals: -0.23749218558122878
# Standard Deviation of Residuals: 6.556810100184086
# ACF (first 5 lags): [ 1.00000000e+00 -3.71627927e-02  1.42632976e-02 -1.43833458e-04
#   9.39816972e-02]
# PACF (first 5 lags): [ 1.00000000e+00 -3.73250756e-02  1.30133827e-02  8.71412368e-04
#   9.56340204e-02]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2688, Lactation Number: 5
# Mean Residuals: 0.09629838437141654
# Standard Deviation of Residuals: 9.232272972041683
# ACF (first 5 lags): [ 1.         -0.00392483  0.16072127  0.10979194  0.03881465]
# PACF (first 5 lags): [ 1.         -0.0039348   0.16152621  0.11479759  0.01657116]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2689, Lactation Number: 4
# Mean Residuals: -0.22792262083566595
# Standard Deviation of Residuals: 4.678447997771247
# ACF (first 5 lags): [1.         0.0043469  0.03556749 0.00174523 0.00481355]
# PACF (first 5 lags): [1.         0.00436588 0.03586111 0.00146261 0.00360326]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2689, Lactation Number: 5
# Mean Residuals: -0.060027659275123435
# Standard Deviation of Residuals: 7.6786829584440195
# ACF (first 5 lags): [1.         0.06531377 0.25843388 0.17036157 0.11958498]
# PACF (first 5 lags): [1.         0.06553294 0.25698324 0.15331913 0.04916035]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2689, Lactation Number: 6
# Mean Residuals: 1.861309568994095
# Standard Deviation of Residuals: 3.025183234667285
# ACF (first 5 lags): [1.         0.21960287 0.3821613  0.19630429 0.12460145]
# PACF (first 5 lags): [ 1.          0.23006015  0.3879849   0.09801101 -0.06390358]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2690, Lactation Number: 4
# Mean Residuals: -0.1683711502120291
# Standard Deviation of Residuals: 4.998245513607139
# ACF (first 5 lags): [1.         0.00504463 0.1291129  0.09709408 0.04416136]
# PACF (first 5 lags): [1.         0.00506696 0.13023824 0.09883948 0.02915267]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2690, Lactation Number: 5
# Mean Residuals: -0.04013743726258322
# Standard Deviation of Residuals: 5.489594253394809
# ACF (first 5 lags): [1.         0.15170391 0.20537535 0.19565992 0.13317603]
# PACF (first 5 lags): [1.         0.15220791 0.18793112 0.15224361 0.06306967]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2690, Lactation Number: 6
# Mean Residuals: 3.3038752701663756
# Standard Deviation of Residuals: 3.3403122105133596
# ACF (first 5 lags): [1.         0.4423447  0.24615006 0.08130232 0.2372133 ]
# PACF (first 5 lags): [ 1.          0.45872783  0.06921937 -0.06856675  0.31042499]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2697, Lactation Number: 3
# Mean Residuals: -0.9222948149883684
# Standard Deviation of Residuals: 5.783154110705701
# ACF (first 5 lags): [ 1.          0.40436894  0.23222002  0.12184024 -0.2641695 ]
# PACF (first 5 lags): [ 1.          0.41158981  0.08579188  0.00332474 -0.42958125]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2710, Lactation Number: 4
# Mean Residuals: -0.007789360768383629
# Standard Deviation of Residuals: 5.853706185322168
# ACF (first 5 lags): [ 1.          0.20665341  0.12173057 -0.02165082  0.02122824]
# PACF (first 5 lags): [ 1.          0.20737597  0.08315614 -0.06569108  0.02927874]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2710, Lactation Number: 5
# Mean Residuals: 0.11931921901326308
# Standard Deviation of Residuals: 4.560695127979677
# ACF (first 5 lags): [1.         0.26512989 0.32448257 0.25377972 0.16076907]
# PACF (first 5 lags): [1.         0.26607678 0.27551753 0.13999752 0.00601601]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2712, Lactation Number: 4
# Mean Residuals: -0.1775401342420803
# Standard Deviation of Residuals: 6.453577802702013
# ACF (first 5 lags): [ 1.          0.19633516  0.17848362  0.02115911 -0.08544398]
# PACF (first 5 lags): [ 1.          0.19695845  0.1465114  -0.04007048 -0.11702067]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2713, Lactation Number: 4
# Mean Residuals: -0.13796007749821856
# Standard Deviation of Residuals: 5.225500770375959
# ACF (first 5 lags): [1.         0.08526626 0.26050068 0.14513836 0.03060779]
# PACF (first 5 lags): [ 1.          0.08551199  0.25657028  0.116251   -0.05378644]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2713, Lactation Number: 5
# Mean Residuals: 0.38135283888414945
# Standard Deviation of Residuals: 6.848231289113161
# ACF (first 5 lags): [1.         0.44229981 0.37475503 0.24611417 0.25502517]
# PACF (first 5 lags): [1.         0.44565057 0.22694417 0.02575501 0.10954182]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2719, Lactation Number: 3
# Mean Residuals: -0.11603966839761352
# Standard Deviation of Residuals: 3.7794681940118275
# ACF (first 5 lags): [1.         0.18962114 0.07121642 0.21138781 0.12301712]
# PACF (first 5 lags): [1.         0.19049901 0.03692918 0.20171433 0.05326642]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2724, Lactation Number: 3
# Mean Residuals: -0.4991481388441824
# Standard Deviation of Residuals: 4.515870606521716
# ACF (first 5 lags): [ 1.          0.20249209 -0.04580251 -0.11326994 -0.11132771]
# PACF (first 5 lags): [ 1.          0.20575809 -0.09360345 -0.09378702 -0.08214212]
# --------------------------------------------------
#
# Cow: SE-5c06d92d-2724, Lactation Number: 4
# Mean Residuals: 0.08970966745785242
# Standard Deviation of Residuals: 6.400852165583397
# ACF (first 5 lags): [ 1.          0.03915013 -0.0328334   0.12219632  0.03110693]
# ...
#
# Cow: SE-f454e660-495, Lactation Number: 2
# Mean Residuals: -0.3323837546784081
# Standard Deviation of Residuals: 8.077364794686375
# ACF (first 5 lags): [1.         0.3080516  0.39152099 0.38541226 0.39509647]
# PACF (first 5 lags): [1.         0.30972579 0.33168877 0.25739881 0.22130408]
# --------------------------------------------------
#
# Cow: SE-f454e660-500, Lactation Number: 2
# Mean Residuals: -0.6501606226105135
# Standard Deviation of Residuals: 6.307433651428528
# ACF (first 5 lags): [ 1.         -0.21370715  0.08153328 -0.06629766 -0.04985606]
# PACF (first 5 lags): [ 1.         -0.21739176  0.03897694 -0.04598431 -0.08472178]
# --------------------------------------------------
#
# Cow: SE-f454e660-500, Lactation Number: 3
# Mean Residuals: 0.07966057833530081
# Standard Deviation of Residuals: 8.506729990232056
# ACF (first 5 lags): [1.         0.2437343  0.33646468 0.30626709 0.18324804]
# PACF (first 5 lags): [1.         0.24571588 0.29969891 0.21207625 0.01613152]
# --------------------------------------------------
#
# Cow: SE-f454e660-502, Lactation Number: 2
# Mean Residuals: -0.08366553338153558
# Standard Deviation of Residuals: 4.387846417350416
# ACF (first 5 lags): [ 1.         -0.21476503  0.19781427  0.17939208  0.01801815]
# PACF (first 5 lags): [ 1.         -0.21524017  0.1597648   0.26999001  0.08739125]
# --------------------------------------------------
#
# Cow: SE-f454e660-510, Lactation Number: 3
# Mean Residuals: -0.2924794657144125
# Standard Deviation of Residuals: 9.204643800096765
# ACF (first 5 lags): [1.         0.11876685 0.18809768 0.13498599 0.20535774]
# PACF (first 5 lags): [1.         0.12035041 0.18132351 0.1045806  0.16968564]
# --------------------------------------------------
#
# Cow: SE-f454e660-514, Lactation Number: 3
# Mean Residuals: -0.005515239603568579
# Standard Deviation of Residuals: 5.376486868297307
# ACF (first 5 lags): [ 1.         -0.11213378  0.12089355  0.07492762  0.16129932]
# PACF (first 5 lags): [ 1.         -0.11246554  0.11035839  0.10271001  0.17463228]
# --------------------------------------------------
#
# Cow: SE-f454e660-526, Lactation Number: 2
# Mean Residuals: -0.018539767163964604
# Standard Deviation of Residuals: 7.389301788774884
# ACF (first 5 lags): [ 1.         -0.15629739  0.22819171  0.12073654  0.14499602]
# PACF (first 5 lags): [ 1.         -0.15659009  0.20966869  0.19579309  0.15965297]
# --------------------------------------------------
#
# Cow: SE-f454e660-527, Lactation Number: 2
# Mean Residuals: -0.13260293333784734
# Standard Deviation of Residuals: 5.25996733436534
# ACF (first 5 lags): [ 1.         -0.16915192  0.16600253  0.18535409  0.16969949]
# PACF (first 5 lags): [ 1.         -0.16962441  0.14225304  0.24730972  0.24354785]
# --------------------------------------------------
#
# Cow: SE-f454e660-539, Lactation Number: 1
# Mean Residuals: -0.06838801969331662
# Standard Deviation of Residuals: 5.644206750591063
# ACF (first 5 lags): [ 1.         -0.16704384  0.06833152  0.07154858  0.02703665]
# PACF (first 5 lags): [ 1.         -0.16779292  0.04197442  0.09343673  0.05326044]
# --------------------------------------------------
#
# Cow: SE-f454e660-539, Lactation Number: 2
# Mean Residuals: -0.0791590859901805
# Standard Deviation of Residuals: 7.950591839203438
# ACF (first 5 lags): [ 1.         -0.40414869  0.24367666 -0.05516175  0.10984247]
# PACF (first 5 lags): [ 1.         -0.4071874   0.09777907  0.08988616  0.11743284]
# --------------------------------------------------
#
# Cow: SE-f454e660-548, Lactation Number: 3
# Mean Residuals: 0.07563822754113514
# Standard Deviation of Residuals: 7.838711328676756
# ACF (first 5 lags): [ 1.         -0.32002063 -0.06622207  0.07970669  0.04495777]
# PACF (first 5 lags): [ 1.         -0.32099929 -0.18916003 -0.00660349  0.07102997]
# --------------------------------------------------
#
# Cow: SE-f454e660-550, Lactation Number: 2
# Mean Residuals: -0.2231019784373156
# Standard Deviation of Residuals: 4.6032117692268635
# ACF (first 5 lags): [ 1.         -0.16169275  0.12478069  0.18726471  0.02082559]
# PACF (first 5 lags): [ 1.         -0.16244133  0.10225241  0.23340087  0.0814424 ]
# --------------------------------------------------
#
# Cow: SE-f454e660-550, Lactation Number: 3
# Mean Residuals: 0.05844968564543406
# Standard Deviation of Residuals: 4.002483810226744
# ACF (first 5 lags): [ 1.         -0.00117789  0.09633938 -0.07760163  0.19943784]
# PACF (first 5 lags): [ 1.         -0.00120055  0.1001161  -0.08286002  0.20972605]
# --------------------------------------------------
#
# Cow: SE-f454e660-567, Lactation Number: 2
# Mean Residuals: -0.006175437148649116
# Standard Deviation of Residuals: 6.686352256635092
# ACF (first 5 lags): [ 1.         -0.32591596  0.12609568  0.08937406  0.01258321]
# PACF (first 5 lags): [ 1.         -0.32648875  0.02232445  0.15401264  0.09509047]
# --------------------------------------------------
#
# Cow: SE-f454e660-576, Lactation Number: 3
# Mean Residuals: 0.03712394319334086
# Standard Deviation of Residuals: 17.460485726792424
# ACF (first 5 lags): [1.         0.50619001 0.51219434 0.43545097 0.3139786 ]
# PACF (first 5 lags): [ 1.          0.51363399  0.35815127  0.15175283 -0.05185973]
# --------------------------------------------------
#
# Cow: SE-f454e660-578, Lactation Number: 1
# Mean Residuals: -0.10071786112082368
# Standard Deviation of Residuals: 5.391749831240591
# ACF (first 5 lags): [ 1.         -0.08857997  0.33933115  0.22164682  0.28519495]
# PACF (first 5 lags): [ 1.         -0.08877594  0.3355997   0.31011757  0.29034425]
# --------------------------------------------------
#
# Cow: SE-f454e660-580, Lactation Number: 2
# Mean Residuals: -0.06443987384386643
# Standard Deviation of Residuals: 7.304115467015189
# ACF (first 5 lags): [ 1.         -0.19424306 -0.0031622   0.15035835  0.08541356]
# PACF (first 5 lags): [ 1.         -0.19508031 -0.04287767  0.14924991  0.15551474]
# --------------------------------------------------
#
# Cow: SE-f454e660-580, Lactation Number: 3
# Mean Residuals: 0.19252623253183057
# Standard Deviation of Residuals: 10.192458799033641
# ACF (first 5 lags): [1.         0.05996222 0.38010574 0.28166238 0.28887708]
# PACF (first 5 lags): [1.         0.06052262 0.3850249  0.29693858 0.20615427]
# --------------------------------------------------
#
# Cow: SE-f454e660-587, Lactation Number: 2
# Mean Residuals: -0.04670060313345653
# Standard Deviation of Residuals: 5.258037919475956
# ACF (first 5 lags): [ 1.         -0.26368515  0.1626101   0.09468501  0.15555713]
# PACF (first 5 lags): [ 1.         -0.26450151  0.10070444  0.17502135  0.22962985]
# --------------------------------------------------
#
# Cow: SE-f454e660-587, Lactation Number: 3
# Mean Residuals: -0.07403304168381142
# Standard Deviation of Residuals: 4.907847059774844
# ACF (first 5 lags): [ 1.         -0.29689436  0.14654117 -0.06203908  0.26093156]
# PACF (first 5 lags): [ 1.         -0.29823777  0.06468066 -0.00259005  0.26228764]
# --------------------------------------------------
#
# Cow: SE-f454e660-600, Lactation Number: 1
# Mean Residuals: -0.8012754810097323
# Standard Deviation of Residuals: 2.610209697892319
# ACF (first 5 lags): [ 1.          0.05747945 -0.23454454 -0.14285671  0.0458797 ]
# PACF (first 5 lags): [ 1.          0.06107192 -0.27055604 -0.14763676  0.0073859 ]
# --------------------------------------------------
#
# Cow: SE-f454e660-600, Lactation Number: 2
# Mean Residuals: -0.056083962168349044
# Standard Deviation of Residuals: 6.857605176410629
# ACF (first 5 lags): [ 1.         -0.29399683  0.12227935  0.00852123  0.16061618]
# PACF (first 5 lags): [ 1.         -0.29455259  0.03939967  0.06021431  0.192723  ]
# --------------------------------------------------
#
# Cow: SE-f454e660-601, Lactation Number: 1
# Mean Residuals: -0.05499407104385439
# Standard Deviation of Residuals: 5.4940097349956325
# ACF (first 5 lags): [ 1.         -0.2133942   0.32732371  0.17091852  0.14816613]
# PACF (first 5 lags): [ 1.         -0.21404085  0.29711176  0.32831573  0.19185817]
# --------------------------------------------------
#
# Cow: SE-f454e660-602, Lactation Number: 1
# Mean Residuals: -0.07111146175873206
# Standard Deviation of Residuals: 3.825464339443096
# ACF (first 5 lags): [ 1.         -0.00447831  0.10511615  0.17131747  0.15533785]
# PACF (first 5 lags): [ 1.         -0.00450545  0.10637992  0.17738923  0.15933612]
# --------------------------------------------------
#
# Cow: SE-f454e660-602, Lactation Number: 2
# Mean Residuals: 0.03204452396748496
# Standard Deviation of Residuals: 4.827428252029332
# ACF (first 5 lags): [ 1.         -0.32610704 -0.03844113  0.07879562 -0.00974319]
# PACF (first 5 lags): [ 1.         -0.32722769 -0.16326643  0.01317956  0.02122375]
# --------------------------------------------------
#
# Cow: SE-f454e660-603, Lactation Number: 1
# Mean Residuals: -0.0724138181300385
# Standard Deviation of Residuals: 5.896990657347038
# ACF (first 5 lags): [ 1.         -0.19359404  0.16393548  0.17156972  0.14684856]
# PACF (first 5 lags): [ 1.         -0.1940233   0.13198772  0.23906407  0.22513436]
# --------------------------------------------------
#
# Cow: SE-f454e660-625, Lactation Number: 1
# Mean Residuals: -0.02595235435634101
# Standard Deviation of Residuals: 4.047491429606423
# ACF (first 5 lags): [ 1.         -0.34245283  0.02914193  0.07775535  0.03868914]
# PACF (first 5 lags): [ 1.         -0.3431877  -0.10032679  0.06283794  0.10563216]
# --------------------------------------------------
#
# Cow: SE-f454e660-636, Lactation Number: 1
# Mean Residuals: 0.14898873420289532
# Standard Deviation of Residuals: 6.79595239163942
# ACF (first 5 lags): [ 1.         -0.03661345  0.23396419  0.17794863  0.26500431]
# PACF (first 5 lags): [ 1.         -0.03671214  0.23419673  0.20617761  0.25748867]
# --------------------------------------------------
#
# Cow: SE-f454e660-636, Lactation Number: 2
# Mean Residuals: -0.3664282901563689
# Standard Deviation of Residuals: 8.068094094523348
# ACF (first 5 lags): [ 1.         -0.38874215  0.07552198  0.03094213 -0.08327216]
# PACF (first 5 lags): [ 1.         -0.39360143 -0.09169351  0.03498236 -0.06474572]
# --------------------------------------------------
#
# Cow: SE-f454e660-639, Lactation Number: 1
# Mean Residuals: 0.1406298159879853
# Standard Deviation of Residuals: 5.9547913229970915
# ACF (first 5 lags): [ 1.         -0.34594909 -0.01036135  0.00607259  0.07213149]
# PACF (first 5 lags): [ 1.         -0.34769631 -0.14942348 -0.0581415   0.06316561]
# --------------------------------------------------
#
# Cow: SE-f454e660-639, Lactation Number: 2
# Mean Residuals: 0.1880803360012032
# Standard Deviation of Residuals: 9.092688665026369
# ACF (first 5 lags): [ 1.         -0.37124497  0.01183946 -0.01152459 -0.03260562]
# PACF (first 5 lags): [ 1.         -0.37393515 -0.14859251 -0.07392412 -0.07678445]
# --------------------------------------------------
#
# Cow: SE-f454e660-641, Lactation Number: 1
# Mean Residuals: -0.11628145021019855
# Standard Deviation of Residuals: 5.733288148911378
# ACF (first 5 lags): [ 1.         -0.41599053  0.03015502 -0.06881505  0.04460507]
# PACF (first 5 lags): [ 1.         -0.42002927 -0.1768852  -0.16289318 -0.0659065 ]
# --------------------------------------------------
#
# Cow: SE-f454e660-651, Lactation Number: 2
# Mean Residuals: -0.01667694597279139
# Standard Deviation of Residuals: 9.051188788527659
# ACF (first 5 lags): [ 1.         -0.37845135  0.03050765  0.08375579 -0.10392696]
# PACF (first 5 lags): [ 1.        -0.3800152 -0.1328334  0.0565935 -0.0536569]
# --------------------------------------------------
#
# Cow: SE-f454e660-657, Lactation Number: 1
# Mean Residuals: -0.09086548738995576
# Standard Deviation of Residuals: 5.840655909764745
# ACF (first 5 lags): [ 1.         -0.18827914  0.13779552  0.11279163  0.08718145]
# PACF (first 5 lags): [ 1.         -0.18871396  0.10661746  0.16470725  0.13111209]
# --------------------------------------------------
#
# Cow: SE-f454e660-665, Lactation Number: 1
# Mean Residuals: 0.646903815436531
# Standard Deviation of Residuals: 3.4040962507801695
# ACF (first 5 lags): [ 1.         -0.04422783 -0.14191938  0.23114951  0.04465313]
# PACF (first 5 lags): [ 1.         -0.04599694 -0.15619218  0.2526231   0.05050345]
# --------------------------------------------------
#
# Cow: SE-f454e660-667, Lactation Number: 1
# Mean Residuals: -0.04121728747081138
# Standard Deviation of Residuals: 3.80780467933484
# ACF (first 5 lags): [ 1.         -0.20567983  0.06099852  0.20520139 -0.06352596]
# PACF (first 5 lags): [ 1.         -0.20894459  0.02018981  0.24311112  0.02641987]
# --------------------------------------------------
#
# Cow: SE-f454e660-671, Lactation Number: 1
# Mean Residuals: 0.030718083613548133
# Standard Deviation of Residuals: 6.789145840113025
# ACF (first 5 lags): [ 1.         -0.33320089  0.09875237  0.04226361 -0.03113537]
# PACF (first 5 lags): [ 1.         -0.33405966 -0.01388235  0.08058084  0.00964003]
# --------------------------------------------------
#
# Cow: SE-f454e660-686, Lactation Number: 1
# Mean Residuals: -0.03439761685392406
# Standard Deviation of Residuals: 4.226761946396705
# ACF (first 5 lags): [ 1.         -0.36593082 -0.04538725  0.02155337  0.1115494 ]
# PACF (first 5 lags): [ 1.         -0.3671306  -0.2085848  -0.09072603  0.09554573]
# --------------------------------------------------
#
# Cow: SE-f454e660-688, Lactation Number: 1
# Mean Residuals: 0.02872767137991791
# Standard Deviation of Residuals: 6.094796734469616
# ACF (first 5 lags): [ 1.         -0.3458626   0.22214625  0.09542837  0.05799723]
# PACF (first 5 lags): [ 1.         -0.34699287  0.11732534  0.23696772  0.15965495]
# --------------------------------------------------
#
# Cow: SE-f454e660-701, Lactation Number: 1
# Mean Residuals: 0.009939125627397174
# Standard Deviation of Residuals: 6.5482645748121815
# ACF (first 5 lags): [ 1.         -0.0171963   0.14404617  0.13316431  0.31466905]
# PACF (first 5 lags): [ 1.         -0.01723401  0.14442523  0.14166266  0.31631393]
# --------------------------------------------------
#
# Cow: SE-f454e660-712, Lactation Number: 1
# Mean Residuals: 0.021134140916219245
# Standard Deviation of Residuals: 5.09376005440017
# ACF (first 5 lags): [ 1.         -0.20204199  0.14448474  0.05216511  0.07937681]
# PACF (first 5 lags): [ 1.         -0.20273629  0.10885327  0.1066544   0.09991581]
# --------------------------------------------------
#
# Cow: SE-f454e660-714, Lactation Number: 1
# Mean Residuals: -0.062436193693873404
# Standard Deviation of Residuals: 4.866536469115167
# ACF (first 5 lags): [ 1.         -0.0979284   0.22202853  0.06384175  0.20854258]
# PACF (first 5 lags): [ 1.         -0.09839472  0.2165684   0.10949668  0.19241543]
# --------------------------------------------------
#
# Cow: SE-f454e660-735, Lactation Number: 1
# Mean Residuals: 0.14676340805665067
# Standard Deviation of Residuals: 5.659393388203006
# ACF (first 5 lags): [ 1.         -0.15836684  0.07900908  0.13993756  0.08100127]
# PACF (first 5 lags): [ 1.         -0.15891294  0.05570938  0.16690618  0.13207165]
# --------------------------------------------------
#
# Cow: SE-f454e660-735, Lactation Number: 2
# Mean Residuals: 0.2877139851091473
# Standard Deviation of Residuals: 8.506735500151231
# ACF (first 5 lags): [ 1.         -0.39454554  0.05010495  0.12008192 -0.08739732]
# PACF (first 5 lags): [ 1.         -0.39995027 -0.12911706  0.117151    0.01597388]
# --------------------------------------------------
#
# Cow: SE-fcdf259d-0044-0, Lactation Number: 9
# Mean Residuals: -0.3699400232911329
# Standard Deviation of Residuals: 3.7360613196544405
# ACF (first 5 lags): [ 1.         -0.37024795  0.03135025  0.14023297 -0.16344135]
# PACF (first 5 lags): [ 1.         -0.37465566 -0.12593882  0.13206069 -0.07323722]
# --------------------------------------------------
#
# Cow: SE-fcdf259d-0044-0, Lactation Number: 10
# Mean Residuals: -0.04534673602320302
# Standard Deviation of Residuals: 6.320997748266175
# ACF (first 5 lags): [ 1.         -0.02715316  0.21824682  0.11334557  0.19453998]
# PACF (first 5 lags): [ 1.         -0.02727547  0.21964136  0.1320324   0.16959658]
# --------------------------------------------------
# ==================================================

# %%
# Define the thresholds
mean_residual_threshold = 0.05
std_residual_threshold = 5.0
acf_threshold = 0.2
pacf_threshold = 0.2

# List to collect flagged combinations
flagged_combinations = []

for farm_name, farm_group in data_cleaned.groupby('FarmName_Pseudo'):
    for (se_number, lactation_number), cow_group in farm_group.groupby(['SE_Number', 'LactationNumber']):
        residuals = cow_group['Residuals'].dropna()
        
        if len(residuals) > 1:  # Ensure there are residuals to analyze
            mean_residuals = residuals.mean()
            std_residuals = residuals.std()
            acf_values = acf(residuals, nlags=30, fft=False)
            pacf_values = pacf(residuals, nlags=min(30, len(residuals)//2))

            # Check against thresholds
            if (abs(mean_residuals) > mean_residual_threshold or 
                std_residuals > std_residual_threshold or 
                abs(acf_values[1]) > acf_threshold or 
                abs(pacf_values[1]) > pacf_threshold):
                
                # Collect the combination if it exceeds any threshold
                flagged_combinations.append({
                    'Farm': farm_name,
                    'SE_Number': se_number,
                    'LactationNumber': lactation_number,
                    'Mean Residuals': mean_residuals,
                    'Std Residuals': std_residuals,
                    'ACF[1]': acf_values[1],
                    'PACF[1]': pacf_values[1]
                })

# Convert to a DataFrame for easier inspection
flagged_df = pd.DataFrame(flagged_combinations)
flagged_df
# Out:
#           Farm           SE_Number  LactationNumber  Mean Residuals  \
# 0     5c06d92d    SE-5c06d92d-2055                6       -0.357801
# 1     5c06d92d    SE-5c06d92d-2055                7       -0.077130
# 2     5c06d92d    SE-5c06d92d-2058                7       -0.203898
# 3     5c06d92d    SE-5c06d92d-2058                8       -0.039645
# 4     5c06d92d    SE-5c06d92d-2211                7        0.093558
# ...        ...                 ...              ...             ...
# 1953  f454e660     SE-f454e660-714                1       -0.062436
# 1954  f454e660     SE-f454e660-735                1        0.146763
# 1955  f454e660     SE-f454e660-735                2        0.287714
# 1956  f454e660  SE-fcdf259d-0044-0                9       -0.369940
# 1957  f454e660  SE-fcdf259d-0044-0               10       -0.045347
#
#       Std Residuals    ACF[1]   PACF[1]
# 0          4.788416  0.076273  0.076714
# 1          8.538930  0.376882  0.377901
# 2          4.423873 -0.047472 -0.047695
# 3          7.674564  0.289566  0.290418
# 4          8.589714  0.334567  0.336116
# ...             ...       ...       ...
# 1953       4.866536 -0.097928 -0.098395
# 1954       5.659393 -0.158367 -0.158913
# 1955       8.506736 -0.394546 -0.399950
# 1956       3.736061 -0.370248 -0.374656
# 1957       6.320998 -0.027153 -0.027275
#
# [1958 rows x 7 columns]

# %%
# Define the Wilmink Lactation Curve function
def wilmink_lactation_curve(dim, a, b, c, d):
    dim = np.array(dim, dtype=float)
    return a + b * dim + c * np.exp(-d * dim)

# Function to directly refit the Wilmink Lactation Curve (Standard Process)
def refit_wilmink(cow_data):
    x_data = cow_data['DaysInMilk'].values
    y_data = cow_data['DailyYield'].values

    # Use initial guesses and bounds from the original fitting process
    initial_guesses = [np.mean(y_data), 0, np.mean(y_data) / 2, 0.1]
    bounds = ([-np.inf, -np.inf, -np.inf, 0], [np.inf, np.inf, np.inf, np.inf])

    popt, _ = curve_fit(wilmink_lactation_curve, x_data, y_data, p0=initial_guesses, bounds=bounds, maxfev=30000)
    
    # Calculate the expected yield with the refitted parameters
    cow_data['ExpectedYield'] = wilmink_lactation_curve(cow_data['DaysInMilk'], *popt)
    
    # Calculate new residuals
    cow_data['Residuals'] = cow_data['DailyYield'] - cow_data['ExpectedYield']
    
    return cow_data

# Function to add lagged variables for addressing autocorrelation
def add_lagged_variables(cow_data, max_lag=3):
    for lag in range(1, max_lag + 1):
        cow_data[f'lag_{lag}'] = cow_data['DailyYield'].shift(lag)
    return cow_data.dropna()

# Define the Robust Wilmink Lactation Curve function
def robust_wilmink_lactation_curve(dim, a, b, c, d, lag1, lag2, lag3):
    dim = np.array(dim, dtype=np.float64)
    days_in_milk = dim[0]
    lag_1 = dim[1]
    lag_2 = dim[2]
    lag_3 = dim[3]
    
    return a + b * days_in_milk + c * np.exp(-d * days_in_milk) + lag1 * lag_1 + lag2 * lag_2 + lag3 * lag_3

# Function to fit the robust Wilmink model
def fit_robust_wilmink(cow_data, lags=3):
    cow_data = add_lagged_variables(cow_data, max_lag=lags)
    
    x_data = cow_data[['DaysInMilk', 'lag_1', 'lag_2', 'lag_3']].values.T
    y_data = cow_data['DailyYield'].values
    
    initial_guesses = [np.mean(y_data), 0, np.mean(y_data) / 2, 0.1, 0, 0, 0]
    bounds = ([-np.inf, -np.inf, -np.inf, 0, -np.inf, -np.inf, -np.inf], 
              [np.inf, np.inf, np.inf, np.inf, np.inf, np.inf, np.inf])
    
    try:
        popt, _ = curve_fit(robust_wilmink_lactation_curve, x_data, y_data, p0=initial_guesses, bounds=bounds, maxfev=50000)
        cow_data.loc[:, 'ExpectedYield'] = robust_wilmink_lactation_curve(x_data, *popt)
        cow_data.loc[:, 'Residuals'] = cow_data['DailyYield'] - cow_data['ExpectedYield']
    except RuntimeError as e:
        print(f"Curve fitting failed: {e}")
        cow_data.loc[:, 'ExpectedYield'] = np.nan
        cow_data.loc[:, 'Residuals'] = np.nan
    
    return cow_data

# Function to add lagged variables for addressing autocorrelation
def add_lagged_variables(cow_data, max_lag=3):
    for lag in range(1, max_lag + 1):
        cow_data[f'lag_{lag}'] = cow_data['DailyYield'].shift(lag)
    return cow_data.dropna()

# Example usage: Applying the robust model to flagged cases
for index, row in flagged_df.iterrows():
    se_number = row['SE_Number']
    lactation_number = row['LactationNumber']
    
    cow_data = data_cleaned[(data_cleaned['SE_Number'] == se_number) & 
                            (data_cleaned['LactationNumber'] == lactation_number)].copy()
    
    if abs(row['ACF[1]']) > 0.2:  # Significant autocorrelation
        cow_data = add_lagged_variables(cow_data, max_lag=3)
        cow_data_refitted = fit_robust_wilmink(cow_data, lags=3)
        data_cleaned.update(cow_data_refitted)
    else:
        cow_data_refitted = refit_wilmink(cow_data)
        data_cleaned.update(cow_data_refitted)

data_cleaned['NormalizedDailyYield'] = data_cleaned['DailyYield'] / data_cleaned['ExpectedYield']
data_cleaned['NormalizedDailyYieldChange'] = data_cleaned['DailyYieldChange'] / data_cleaned['ExpectedYield']

data_cleaned
# Out:
# /var/folders/n0/fphw_xw93vv749r_ntt01qd80000gn/T/ipykernel_37467/311340443.py:53: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, _ = curve_fit(robust_wilmink_lactation_curve, x_data, y_data, p0=initial_guesses, bounds=bounds, maxfev=50000)
# Curve fitting failed: Optimal parameters not found: The maximum number of function evaluations is exceeded.
# /var/folders/n0/fphw_xw93vv749r_ntt01qd80000gn/T/ipykernel_37467/311340443.py:53: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, _ = curve_fit(robust_wilmink_lactation_curve, x_data, y_data, p0=initial_guesses, bounds=bounds, maxfev=50000)
#                  SE_Number FarmName_Pseudo       Date  DailyYield  \
# 0         SE-064c0cec-1189        a624fb9a 2022-01-01       30.77
# 1         SE-064c0cec-1189        a624fb9a 2022-01-02       48.22
# 2         SE-064c0cec-1189        a624fb9a 2022-01-03       30.53
# 3         SE-064c0cec-1189        a624fb9a 2022-01-04       42.26
# 4         SE-064c0cec-1189        a624fb9a 2022-01-05       38.49
# ...                    ...             ...        ...         ...
# 483102  SE-fcdf259d-0044-0        f454e660 2023-06-08       15.14
# 483103  SE-fcdf259d-0044-0        f454e660 2023-06-09        7.47
# 483104  SE-fcdf259d-0044-0        f454e660 2023-06-10       14.73
# 483105  SE-fcdf259d-0044-0        f454e660 2023-06-12       12.27
# 483106  SE-fcdf259d-0044-0        f454e660 2023-06-13        7.96
#
#         PreviousDailyYield  DailyYieldChange  HW  MeanTemperature  \
# 0                 0.000000          0.000000   0        -3.025000
# 1                30.770000          8.725000   0        -0.279167
# 2                39.495000         -2.988333   0         2.033333
# 3                36.506667          1.438333   0         0.066667
# 4                37.945000          0.109000   0        -3.700000
# ...                    ...               ...  ..              ...
# 483102           13.252000          0.494000   0        15.570833
# 483103           13.746000         -2.968000   0        13.254167
# 483104           10.778000          0.378000   0        13.258333
# 483105           11.156000          0.560000   0        15.820833
# 483106           11.716000         -0.202000   0        16.341667
#
#         MeanTHI_adj  DaysInMilk  ...   Age   BreedName  LactationNumber  \
# 0         28.012944         191  ...  3095      02 SLB                7
# 1         32.898193         192  ...  3096      02 SLB                7
# 2         36.760487         193  ...  3097      02 SLB                7
# 3         31.939524         194  ...  3098      02 SLB                7
# 4         26.498206         195  ...  3099      02 SLB                7
# ...             ...         ...  ...   ...         ...              ...
# 483102    59.383267         352  ...  4155  41 Fjällko               10
# 483103    54.534255         353  ...  4156  41 Fjällko               10
# 483104    54.082367         354  ...  4157  41 Fjällko               10
# 483105    62.015093         356  ...  4159  41 Fjällko               10
# 483106    63.457792         357  ...  4160  41 Fjällko               10
#
#          HeatLoad CumulativeHeatLoad  HeatStress  ExpectedYield  \
# 0      -34.987056           0.000000           0      35.914865
# 1      -30.101807           0.000000           0      35.799613
# 2      -26.239513           0.000000           0      35.684360
# 3      -31.060476           0.000000           0      35.569108
# 4      -36.501794           0.000000           0      35.453856
# ...           ...                ...         ...            ...
# 483102  -3.616733           0.000000           0      12.479001
# 483103  -8.465745           0.000000           0      12.383706
# 483104  -8.917633           0.000000           0      12.288410
# 483105  -0.984907           0.000000           0      12.097818
# 483106   0.457792           0.457792           0      12.002521
#
#         NormalizedDailyYield  NormalizedDailyYieldChange  Residuals
# 0                   0.856748                    0.000000  -5.144865
# 1                   1.346942                    0.243718  12.420387
# 2                   0.855557                   -0.083744  -5.154360
# 3                   1.188110                    0.040438   6.690892
# 4                   1.085637                    0.003074   3.036144
# ...                      ...                         ...        ...
# 483102              1.213238                    0.039587   2.660999
# 483103              0.603212                   -0.239670  -4.913706
# 483104              1.198690                    0.030761   2.441590
# 483105              1.014232                    0.046289   0.172182
# 483106              0.663194                   -0.016830  -4.042521
#
# [467390 rows x 23 columns]

# %%
# Define the thresholds
mean_residual_threshold = 0.05
std_residual_threshold = 5.0
acf_threshold = 0.2
pacf_threshold = 0.2

# List to collect flagged combinations
flagged_combinations = []

for farm_name, farm_group in data_cleaned.groupby('FarmName_Pseudo'):
    for (se_number, lactation_number), cow_group in farm_group.groupby(['SE_Number', 'LactationNumber']):
        residuals = cow_group['Residuals'].dropna()
        
        if len(residuals) > 1:  # Ensure there are residuals to analyze
            mean_residuals = residuals.mean()
            std_residuals = residuals.std()
            acf_values = acf(residuals, nlags=30, fft=False)
            pacf_values = pacf(residuals, nlags=min(30, len(residuals)//2))

            # Check against thresholds
            if (abs(mean_residuals) > mean_residual_threshold or 
                std_residuals > std_residual_threshold or 
                abs(acf_values[1]) > acf_threshold or 
                abs(pacf_values[1]) > pacf_threshold):
                
                # Collect the combination if it exceeds any threshold
                flagged_combinations.append({
                    'Farm': farm_name,
                    'SE_Number': se_number,
                    'LactationNumber': lactation_number,
                    'Mean Residuals': float(f"{mean_residuals:.6f}"),  # Convert to regular decimal form
                    'Std Residuals': std_residuals,
                    'ACF[1]': acf_values[1],
                    'PACF[1]': pacf_values[1]
                })

# Convert to a DataFrame for easier inspection
flagged_df = pd.DataFrame(flagged_combinations)
flagged_df
# Out:
#           Farm           SE_Number  LactationNumber  Mean Residuals  \
# 0     5c06d92d    SE-5c06d92d-2055                7        0.129817
# 1     5c06d92d    SE-5c06d92d-2058                8       -0.172312
# 2     5c06d92d    SE-5c06d92d-2211                7       -0.142066
# 3     5c06d92d    SE-5c06d92d-2246                6       -0.676966
# 4     5c06d92d    SE-5c06d92d-2254                7       -0.132351
# ...        ...                 ...              ...             ...
# 1162  f454e660     SE-f454e660-712                1        0.089389
# 1163  f454e660     SE-f454e660-735                1        0.000055
# 1164  f454e660     SE-f454e660-735                2        0.093748
# 1165  f454e660  SE-fcdf259d-0044-0                9       -0.080118
# 1166  f454e660  SE-fcdf259d-0044-0               10        0.000000
#
#       Std Residuals    ACF[1]   PACF[1]
# 0          7.646087 -0.008971 -0.008996
# 1          6.998856 -0.012969 -0.013007
# 2          7.138250 -0.030489 -0.030630
# 3          9.827048  0.129483  0.130232
# 4         10.386472  0.002686  0.002697
# ...             ...       ...       ...
# 1162       4.922108  0.005358  0.005376
# 1163       5.653616 -0.161290 -0.161846
# 1164       7.629328 -0.022853 -0.023166
# 1165       3.412328 -0.001702 -0.001722
# 1166       6.274577 -0.050155 -0.050381
#
# [1167 rows x 7 columns]

# %%
def remove_outliers(data, threshold=3.5):
    # Calculate z-scores of residuals
    data = data.copy()  # Create a copy to avoid the SettingWithCopyWarning
    data['z_score'] = (data['Residuals'] - data['Residuals'].mean()) / data['Residuals'].std()
    
    # Identify the number of outliers
    num_outliers = (data['z_score'].abs() >= threshold).sum()
    print(f"Number of outliers detected: {num_outliers}")
    
    # Remove rows where the z-score of the residual is greater than the threshold
    cleaned_data = data.loc[(data['z_score'].abs() < threshold)].drop(columns=['z_score'])
    
    # Print the number of rows before and after
    print(f"Number of rows before outlier removal: {len(data)}")
    print(f"Number of rows after outlier removal: {len(cleaned_data)}")
    
    return cleaned_data

# Apply to flagged cases
for index, row in flagged_df.iterrows():
    se_number = row['SE_Number']
    lactation_number = row['LactationNumber']
    
    # Select the cow data for the specific SE_Number and LactationNumber
    cow_data = data_cleaned.loc[(data_cleaned['SE_Number'] == se_number) & 
                                (data_cleaned['LactationNumber'] == lactation_number)]
    
    # Remove outliers
    cow_data_trimmed = remove_outliers(cow_data, threshold=3.5)
    
    # Recalculate the residuals and update the dataset
    cow_data_trimmed['Residuals'] = cow_data_trimmed['DailyYield'] - cow_data_trimmed['ExpectedYield']
    
    # Remove the old data for this cow from data_cleaned
    data_cleaned = data_cleaned.loc[~((data_cleaned['SE_Number'] == se_number) & 
                                      (data_cleaned['LactationNumber'] == lactation_number))]
    
    # Append the cleaned data back to data_cleaned
    data_cleaned = pd.concat([data_cleaned, cow_data_trimmed], ignore_index=True)
# Out:
# Number of outliers detected: 4
# Number of rows before outlier removal: 371
# Number of rows after outlier removal: 367
# Number of outliers detected: 4
# Number of rows before outlier removal: 341
# Number of rows after outlier removal: 337
# Number of outliers detected: 3
# Number of rows before outlier removal: 217
# Number of rows after outlier removal: 214
# Number of outliers detected: 0
# Number of rows before outlier removal: 174
# Number of rows after outlier removal: 174
# Number of outliers detected: 0
# Number of rows before outlier removal: 240
# Number of rows after outlier removal: 240
# Number of outliers detected: 1
# Number of rows before outlier removal: 118
# Number of rows after outlier removal: 117
# Number of outliers detected: 4
# Number of rows before outlier removal: 362
# Number of rows after outlier removal: 358
# Number of outliers detected: 0
# Number of rows before outlier removal: 340
# Number of rows after outlier removal: 340
# Number of outliers detected: 3
# Number of rows before outlier removal: 428
# Number of rows after outlier removal: 425
# Number of outliers detected: 0
# Number of rows before outlier removal: 21
# Number of rows after outlier removal: 21
# Number of outliers detected: 0
# Number of rows before outlier removal: 27
# Number of rows after outlier removal: 27
# Number of outliers detected: 6
# Number of rows before outlier removal: 327
# Number of rows after outlier removal: 321
# Number of outliers detected: 6
# Number of rows before outlier removal: 256
# Number of rows after outlier removal: 250
# Number of outliers detected: 0
# Number of rows before outlier removal: 137
# Number of rows after outlier removal: 137
# Number of outliers detected: 4
# Number of rows before outlier removal: 464
# Number of rows after outlier removal: 460
# Number of outliers detected: 2
# Number of rows before outlier removal: 320
# Number of rows after outlier removal: 318
# Number of outliers detected: 0
# Number of rows before outlier removal: 357
# Number of rows after outlier removal: 357
# Number of outliers detected: 7
# Number of rows before outlier removal: 488
# Number of rows after outlier removal: 481
# Number of outliers detected: 3
# Number of rows before outlier removal: 237
# Number of rows after outlier removal: 234
# Number of outliers detected: 3
# Number of rows before outlier removal: 293
# Number of rows after outlier removal: 290
# Number of outliers detected: 6
# Number of rows before outlier removal: 394
# Number of rows after outlier removal: 388
# Number of outliers detected: 0
# Number of rows before outlier removal: 203
# Number of rows after outlier removal: 203
# Number of outliers detected: 4
# Number of rows before outlier removal: 422
# Number of rows after outlier removal: 418
# Number of outliers detected: 5
# Number of rows before outlier removal: 398
# Number of rows after outlier removal: 393
# Number of outliers detected: 0
# Number of rows before outlier removal: 36
# Number of rows after outlier removal: 36
# Number of outliers detected: 2
# Number of rows before outlier removal: 307
# Number of rows after outlier removal: 305
# Number of outliers detected: 1
# Number of rows before outlier removal: 203
# Number of rows after outlier removal: 202
# Number of outliers detected: 6
# Number of rows before outlier removal: 339
# Number of rows after outlier removal: 333
# Number of outliers detected: 3
# Number of rows before outlier removal: 250
# Number of rows after outlier removal: 247
# Number of outliers detected: 2
# Number of rows before outlier removal: 139
# Number of rows after outlier removal: 137
# Number of outliers detected: 7
# Number of rows before outlier removal: 357
# Number of rows after outlier removal: 350
# Number of outliers detected: 1
# Number of rows before outlier removal: 247
# Number of rows after outlier removal: 246
# Number of outliers detected: 4
# Number of rows before outlier removal: 377
# Number of rows after outlier removal: 373
# Number of outliers detected: 0
# Number of rows before outlier removal: 18
# Number of rows after outlier removal: 18
# Number of outliers detected: 7
# Number of rows before outlier removal: 346
# Number of rows after outlier removal: 339
# Number of outliers detected: 1
# Number of rows before outlier removal: 145
# Number of rows after outlier removal: 144
# Number of outliers detected: 3
# Number of rows before outlier removal: 355
# Number of rows after outlier removal: 352
# Number of outliers detected: 0
# Number of rows before outlier removal: 52
# Number of rows after outlier removal: 52
# Number of outliers detected: 0
# Number of rows before outlier removal: 28
# Number of rows after outlier removal: 28
# Number of outliers detected: 3
# Number of rows before outlier removal: 256
# Number of rows after outlier removal: 253
# Number of outliers detected: 3
# Number of rows before outlier removal: 279
# Number of rows after outlier removal: 276
# Number of outliers detected: 0
# Number of rows before outlier removal: 36
# Number of rows after outlier removal: 36
# Number of outliers detected: 4
# Number of rows before outlier removal: 334
# Number of rows after outlier removal: 330
# Number of outliers detected: 4
# Number of rows before outlier removal: 287
# Number of rows after outlier removal: 283
# Number of outliers detected: 1
# Number of rows before outlier removal: 90
# Number of rows after outlier removal: 89
# Number of outliers detected: 0
# Number of rows before outlier removal: 113
# Number of rows after outlier removal: 113
# Number of outliers detected: 4
# Number of rows before outlier removal: 258
# Number of rows after outlier removal: 254
# Number of outliers detected: 1
# Number of rows before outlier removal: 289
# Number of rows after outlier removal: 288
# Number of outliers detected: 2
# Number of rows before outlier removal: 396
# Number of rows after outlier removal: 394
# Number of outliers detected: 5
# Number of rows before outlier removal: 282
# Number of rows after outlier removal: 277
# Number of outliers detected: 6
# Number of rows before outlier removal: 292
# Number of rows after outlier removal: 286
# Number of outliers detected: 0
# Number of rows before outlier removal: 177
# Number of rows after outlier removal: 177
# Number of outliers detected: 1
# Number of rows before outlier removal: 50
# Number of rows after outlier removal: 49
# Number of outliers detected: 3
# Number of rows before outlier removal: 303
# Number of rows after outlier removal: 300
# Number of outliers detected: 0
# Number of rows before outlier removal: 170
# Number of rows after outlier removal: 170
# Number of outliers detected: 0
# Number of rows before outlier removal: 23
# Number of rows after outlier removal: 23
# Number of outliers detected: 1
# Number of rows before outlier removal: 265
# Number of rows after outlier removal: 264
# Number of outliers detected: 0
# Number of rows before outlier removal: 166
# Number of rows after outlier removal: 166
# Number of outliers detected: 5
# Number of rows before outlier removal: 359
# Number of rows after outlier removal: 354
# Number of outliers detected: 2
# Number of rows before outlier removal: 221
# Number of rows after outlier removal: 219
# Number of outliers detected: 6
# Number of rows before outlier removal: 382
# Number of rows after outlier removal: 376
# Number of outliers detected: 7
# Number of rows before outlier removal: 357
# Number of rows after outlier removal: 350
# Number of outliers detected: 9
# Number of rows before outlier removal: 495
# Number of rows after outlier removal: 486
# Number of outliers detected: 0
# Number of rows before outlier removal: 23
# Number of rows after outlier removal: 23
# Number of outliers detected: 4
# Number of rows before outlier removal: 292
# Number of rows after outlier removal: 288
# Number of outliers detected: 5
# Number of rows before outlier removal: 274
# Number of rows after outlier removal: 269
# Number of outliers detected: 3
# Number of rows before outlier removal: 621
# Number of rows after outlier removal: 618
# Number of outliers detected: 3
# Number of rows before outlier removal: 294
# Number of rows after outlier removal: 291
# Number of outliers detected: 1
# Number of rows before outlier removal: 125
# Number of rows after outlier removal: 124
# Number of outliers detected: 1
# Number of rows before outlier removal: 107
# Number of rows after outlier removal: 106
# Number of outliers detected: 3
# Number of rows before outlier removal: 336
# Number of rows after outlier removal: 333
# Number of outliers detected: 1
# Number of rows before outlier removal: 235
# Number of rows after outlier removal: 234
# Number of outliers detected: 0
# Number of rows before outlier removal: 78
# Number of rows after outlier removal: 78
# Number of outliers detected: 2
# Number of rows before outlier removal: 231
# Number of rows after outlier removal: 229
# Number of outliers detected: 2
# Number of rows before outlier removal: 157
# Number of rows after outlier removal: 155
# Number of outliers detected: 7
# Number of rows before outlier removal: 335
# Number of rows after outlier removal: 328
# Number of outliers detected: 4
# Number of rows before outlier removal: 314
# Number of rows after outlier removal: 310
# Number of outliers detected: 0
# Number of rows before outlier removal: 17
# Number of rows after outlier removal: 17
# Number of outliers detected: 8
# Number of rows before outlier removal: 257
# Number of rows after outlier removal: 249
# Number of outliers detected: 1
# Number of rows before outlier removal: 83
# Number of rows after outlier removal: 82
# Number of outliers detected: 6
# Number of rows before outlier removal: 324
# Number of rows after outlier removal: 318
# Number of outliers detected: 4
# Number of rows before outlier removal: 150
# Number of rows after outlier removal: 146
# Number of outliers detected: 1
# Number of rows before outlier removal: 220
# Number of rows after outlier removal: 219
# Number of outliers detected: 7
# Number of rows before outlier removal: 423
# Number of rows after outlier removal: 416
# Number of outliers detected: 4
# Number of rows before outlier removal: 261
# Number of rows after outlier removal: 257
# Number of outliers detected: 6
# Number of rows before outlier removal: 238
# Number of rows after outlier removal: 232
# Number of outliers detected: 6
# Number of rows before outlier removal: 288
# Number of rows after outlier removal: 282
# Number of outliers detected: 0
# Number of rows before outlier removal: 298
# Number of rows after outlier removal: 298
# Number of outliers detected: 4
# Number of rows before outlier removal: 308
# Number of rows after outlier removal: 304
# Number of outliers detected: 0
# Number of rows before outlier removal: 52
# Number of rows after outlier removal: 52
# Number of outliers detected: 5
# Number of rows before outlier removal: 515
# Number of rows after outlier removal: 510
# Number of outliers detected: 3
# Number of rows before outlier removal: 230
# Number of rows after outlier removal: 227
# Number of outliers detected: 2
# Number of rows before outlier removal: 395
# Number of rows after outlier removal: 393
# Number of outliers detected: 1
# Number of rows before outlier removal: 299
# Number of rows after outlier removal: 298
# Number of outliers detected: 0
# Number of rows before outlier removal: 22
# Number of rows after outlier removal: 22
# Number of outliers detected: 3
# Number of rows before outlier removal: 302
# Number of rows after outlier removal: 299
# Number of outliers detected: 0
# Number of rows before outlier removal: 28
# Number of rows after outlier removal: 28
# Number of outliers detected: 0
# Number of rows before outlier removal: 57
# Number of rows after outlier removal: 57
# Number of outliers detected: 3
# Number of rows before outlier removal: 287
# Number of rows after outlier removal: 284
# Number of outliers detected: 4
# Number of rows before outlier removal: 281
# Number of rows after outlier removal: 277
# Number of outliers detected: 4
# Number of rows before outlier removal: 316
# Number of rows after outlier removal: 312
# Number of outliers detected: 6
# Number of rows before outlier removal: 348
# Number of rows after outlier removal: 342
# Number of outliers detected: 3
# Number of rows before outlier removal: 133
# Number of rows after outlier removal: 130
# Number of outliers detected: 0
# Number of rows before outlier removal: 217
# Number of rows after outlier removal: 217
# Number of outliers detected: 1
# Number of rows before outlier removal: 63
# Number of rows after outlier removal: 62
# Number of outliers detected: 4
# Number of rows before outlier removal: 270
# Number of rows after outlier removal: 266
# Number of outliers detected: 4
# Number of rows before outlier removal: 320
# Number of rows after outlier removal: 316
# Number of outliers detected: 1
# Number of rows before outlier removal: 107
# Number of rows after outlier removal: 106
# Number of outliers detected: 1
# Number of rows before outlier removal: 44
# Number of rows after outlier removal: 43
# Number of outliers detected: 4
# Number of rows before outlier removal: 322
# Number of rows after outlier removal: 318
# Number of outliers detected: 4
# Number of rows before outlier removal: 187
# Number of rows after outlier removal: 183
# Number of outliers detected: 0
# Number of rows before outlier removal: 46
# Number of rows after outlier removal: 46
# Number of outliers detected: 2
# Number of rows before outlier removal: 146
# Number of rows after outlier removal: 144
# Number of outliers detected: 2
# Number of rows before outlier removal: 141
# Number of rows after outlier removal: 139
# Number of outliers detected: 2
# Number of rows before outlier removal: 304
# Number of rows after outlier removal: 302
# Number of outliers detected: 3
# Number of rows before outlier removal: 243
# Number of rows after outlier removal: 240
# Number of outliers detected: 0
# Number of rows before outlier removal: 23
# Number of rows after outlier removal: 23
# Number of outliers detected: 4
# Number of rows before outlier removal: 347
# Number of rows after outlier removal: 343
# Number of outliers detected: 4
# Number of rows before outlier removal: 267
# Number of rows after outlier removal: 263
# Number of outliers detected: 2
# Number of rows before outlier removal: 160
# Number of rows after outlier removal: 158
# Number of outliers detected: 3
# Number of rows before outlier removal: 284
# Number of rows after outlier removal: 281
# Number of outliers detected: 3
# Number of rows before outlier removal: 164
# Number of rows after outlier removal: 161
# Number of outliers detected: 6
# Number of rows before outlier removal: 287
# Number of rows after outlier removal: 281
# Number of outliers detected: 3
# Number of rows before outlier removal: 136
# Number of rows after outlier removal: 133
# Number of outliers detected: 2
# Number of rows before outlier removal: 77
# Number of rows after outlier removal: 75
# Number of outliers detected: 6
# Number of rows before outlier removal: 346
# Number of rows after outlier removal: 340
# Number of outliers detected: 4
# Number of rows before outlier removal: 192
# Number of rows after outlier removal: 188
# Number of outliers detected: 3
# Number of rows before outlier removal: 275
# Number of rows after outlier removal: 272
# Number of outliers detected: 4
# Number of rows before outlier removal: 202
# Number of rows after outlier removal: 198
# Number of outliers detected: 4
# Number of rows before outlier removal: 292
# Number of rows after outlier removal: 288
# Number of outliers detected: 2
# Number of rows before outlier removal: 210
# Number of rows after outlier removal: 208
# Number of outliers detected: 1
# Number of rows before outlier removal: 223
# Number of rows after outlier removal: 222
# Number of outliers detected: 5
# Number of rows before outlier removal: 313
# Number of rows after outlier removal: 308
# Number of outliers detected: 3
# Number of rows before outlier removal: 266
# Number of rows after outlier removal: 263
# Number of outliers detected: 3
# Number of rows before outlier removal: 144
# Number of rows after outlier removal: 141
# Number of outliers detected: 3
# Number of rows before outlier removal: 337
# Number of rows after outlier removal: 334
# Number of outliers detected: 3
# Number of rows before outlier removal: 271
# Number of rows after outlier removal: 268
# Number of outliers detected: 1
# Number of rows before outlier removal: 68
# Number of rows after outlier removal: 67
# Number of outliers detected: 2
# Number of rows before outlier removal: 76
# Number of rows after outlier removal: 74
# Number of outliers detected: 2
# Number of rows before outlier removal: 279
# Number of rows after outlier removal: 277
# Number of outliers detected: 2
# Number of rows before outlier removal: 184
# Number of rows after outlier removal: 182
# Number of outliers detected: 4
# Number of rows before outlier removal: 429
# Number of rows after outlier removal: 425
# Number of outliers detected: 1
# Number of rows before outlier removal: 51
# Number of rows after outlier removal: 50
# Number of outliers detected: 4
# Number of rows before outlier removal: 264
# Number of rows after outlier removal: 260
# Number of outliers detected: 2
# Number of rows before outlier removal: 144
# Number of rows after outlier removal: 142
# Number of outliers detected: 6
# Number of rows before outlier removal: 395
# Number of rows after outlier removal: 389
# Number of outliers detected: 5
# Number of rows before outlier removal: 382
# Number of rows after outlier removal: 377
# Number of outliers detected: 4
# Number of rows before outlier removal: 329
# Number of rows after outlier removal: 325
# Number of outliers detected: 1
# Number of rows before outlier removal: 61
# Number of rows after outlier removal: 60
# Number of outliers detected: 4
# Number of rows before outlier removal: 267
# Number of rows after outlier removal: 263
# Number of outliers detected: 6
# Number of rows before outlier removal: 253
# Number of rows after outlier removal: 247
# Number of outliers detected: 4
# Number of rows before outlier removal: 299
# Number of rows after outlier removal: 295
# Number of outliers detected: 2
# Number of rows before outlier removal: 306
# Number of rows after outlier removal: 304
# Number of outliers detected: 4
# Number of rows before outlier removal: 275
# Number of rows after outlier removal: 271
# Number of outliers detected: 5
# Number of rows before outlier removal: 353
# Number of rows after outlier removal: 348
# Number of outliers detected: 5
# Number of rows before outlier removal: 239
# Number of rows after outlier removal: 234
# Number of outliers detected: 2
# Number of rows before outlier removal: 171
# Number of rows after outlier removal: 169
# Number of outliers detected: 0
# Number of rows before outlier removal: 65
# Number of rows after outlier removal: 65
# Number of outliers detected: 4
# Number of rows before outlier removal: 389
# Number of rows after outlier removal: 385
# Number of outliers detected: 1
# Number of rows before outlier removal: 74
# Number of rows after outlier removal: 73
# Number of outliers detected: 4
# Number of rows before outlier removal: 250
# Number of rows after outlier removal: 246
# Number of outliers detected: 5
# Number of rows before outlier removal: 287
# Number of rows after outlier removal: 282
# Number of outliers detected: 0
# Number of rows before outlier removal: 18
# Number of rows after outlier removal: 18
# Number of outliers detected: 0
# Number of rows before outlier removal: 14
# Number of rows after outlier removal: 14
# Number of outliers detected: 0
# Number of rows before outlier removal: 37
# Number of rows after outlier removal: 37
# Number of outliers detected: 6
# Number of rows before outlier removal: 388
# Number of rows after outlier removal: 382
# Number of outliers detected: 2
# Number of rows before outlier removal: 226
# Number of rows after outlier removal: 224
# Number of outliers detected: 2
# Number of rows before outlier removal: 315
# Number of rows after outlier removal: 313
# Number of outliers detected: 5
# Number of rows before outlier removal: 261
# Number of rows after outlier removal: 256
# Number of outliers detected: 0
# Number of rows before outlier removal: 48
# Number of rows after outlier removal: 48
# Number of outliers detected: 0
# Number of rows before outlier removal: 28
# Number of rows after outlier removal: 28
# Number of outliers detected: 1
# Number of rows before outlier removal: 58
# Number of rows after outlier removal: 57
# Number of outliers detected: 0
# Number of rows before outlier removal: 255
# Number of rows after outlier removal: 255
# Number of outliers detected: 6
# Number of rows before outlier removal: 314
# Number of rows after outlier removal: 308
# Number of outliers detected: 2
# Number of rows before outlier removal: 150
# Number of rows after outlier removal: 148
# Number of outliers detected: 1
# Number of rows before outlier removal: 153
# Number of rows after outlier removal: 152
# Number of outliers detected: 3
# Number of rows before outlier removal: 250
# Number of rows after outlier removal: 247
# Number of outliers detected: 0
# Number of rows before outlier removal: 88
# Number of rows after outlier removal: 88
# Number of outliers detected: 2
# Number of rows before outlier removal: 318
# Number of rows after outlier removal: 316
# Number of outliers detected: 5
# Number of rows before outlier removal: 314
# Number of rows after outlier removal: 309
# Number of outliers detected: 2
# Number of rows before outlier removal: 221
# Number of rows after outlier removal: 219
# Number of outliers detected: 3
# Number of rows before outlier removal: 358
# Number of rows after outlier removal: 355
# Number of outliers detected: 6
# Number of rows before outlier removal: 319
# Number of rows after outlier removal: 313
# Number of outliers detected: 0
# Number of rows before outlier removal: 258
# Number of rows after outlier removal: 258
# Number of outliers detected: 1
# Number of rows before outlier removal: 292
# Number of rows after outlier removal: 291
# Number of outliers detected: 3
# Number of rows before outlier removal: 318
# Number of rows after outlier removal: 315
# Number of outliers detected: 0
# Number of rows before outlier removal: 141
# Number of rows after outlier removal: 141
# Number of outliers detected: 4
# Number of rows before outlier removal: 219
# Number of rows after outlier removal: 215
# Number of outliers detected: 0
# Number of rows before outlier removal: 72
# Number of rows after outlier removal: 72
# Number of outliers detected: 0
# Number of rows before outlier removal: 22
# Number of rows after outlier removal: 22
# Number of outliers detected: 2
# Number of rows before outlier removal: 296
# Number of rows after outlier removal: 294
# Number of outliers detected: 3
# Number of rows before outlier removal: 346
# Number of rows after outlier removal: 343
# Number of outliers detected: 3
# Number of rows before outlier removal: 341
# Number of rows after outlier removal: 338
# Number of outliers detected: 0
# Number of rows before outlier removal: 23
# Number of rows after outlier removal: 23
# Number of outliers detected: 6
# Number of rows before outlier removal: 264
# Number of rows after outlier removal: 258
# Number of outliers detected: 3
# Number of rows before outlier removal: 335
# Number of rows after outlier removal: 332
# Number of outliers detected: 2
# Number of rows before outlier removal: 67
# Number of rows after outlier removal: 65
# Number of outliers detected: 4
# Number of rows before outlier removal: 423
# Number of rows after outlier removal: 419
# Number of outliers detected: 5
# Number of rows before outlier removal: 291
# Number of rows after outlier removal: 286
# Number of outliers detected: 5
# Number of rows before outlier removal: 256
# Number of rows after outlier removal: 251
# Number of outliers detected: 5
# Number of rows before outlier removal: 299
# Number of rows after outlier removal: 294
# Number of outliers detected: 4
# Number of rows before outlier removal: 312
# Number of rows after outlier removal: 308
# Number of outliers detected: 3
# Number of rows before outlier removal: 153
# Number of rows after outlier removal: 150
# Number of outliers detected: 7
# Number of rows before outlier removal: 348
# Number of rows after outlier removal: 341
# Number of outliers detected: 1
# Number of rows before outlier removal: 114
# Number of rows after outlier removal: 113
# Number of outliers detected: 1
# Number of rows before outlier removal: 360
# Number of rows after outlier removal: 359
# Number of outliers detected: 3
# Number of rows before outlier removal: 209
# Number of rows after outlier removal: 206
# Number of outliers detected: 1
# Number of rows before outlier removal: 28
# Number of rows after outlier removal: 27
# Number of outliers detected: 2
# Number of rows before outlier removal: 182
# Number of rows after outlier removal: 180
# Number of outliers detected: 1
# Number of rows before outlier removal: 112
# Number of rows after outlier removal: 111
# Number of outliers detected: 2
# Number of rows before outlier removal: 303
# Number of rows after outlier removal: 301
# Number of outliers detected: 0
# Number of rows before outlier removal: 63
# Number of rows after outlier removal: 63
# Number of outliers detected: 5
# Number of rows before outlier removal: 295
# Number of rows after outlier removal: 290
# Number of outliers detected: 4
# Number of rows before outlier removal: 182
# Number of rows after outlier removal: 178
# Number of outliers detected: 0
# Number of rows before outlier removal: 99
# Number of rows after outlier removal: 99
# Number of outliers detected: 2
# Number of rows before outlier removal: 286
# Number of rows after outlier removal: 284
# Number of outliers detected: 0
# Number of rows before outlier removal: 27
# Number of rows after outlier removal: 27
# Number of outliers detected: 6
# Number of rows before outlier removal: 473
# Number of rows after outlier removal: 467
# Number of outliers detected: 2
# Number of rows before outlier removal: 147
# Number of rows after outlier removal: 145
# Number of outliers detected: 3
# Number of rows before outlier removal: 90
# Number of rows after outlier removal: 87
# Number of outliers detected: 3
# Number of rows before outlier removal: 273
# Number of rows after outlier removal: 270
# Number of outliers detected: 2
# Number of rows before outlier removal: 200
# Number of rows after outlier removal: 198
# Number of outliers detected: 4
# Number of rows before outlier removal: 246
# Number of rows after outlier removal: 242
# Number of outliers detected: 1
# Number of rows before outlier removal: 343
# Number of rows after outlier removal: 342
# Number of outliers detected: 5
# Number of rows before outlier removal: 273
# Number of rows after outlier removal: 268
# Number of outliers detected: 1
# Number of rows before outlier removal: 118
# Number of rows after outlier removal: 117
# Number of outliers detected: 4
# Number of rows before outlier removal: 111
# Number of rows after outlier removal: 107
# Number of outliers detected: 0
# Number of rows before outlier removal: 140
# Number of rows after outlier removal: 140
# Number of outliers detected: 2
# Number of rows before outlier removal: 236
# Number of rows after outlier removal: 234
# Number of outliers detected: 3
# Number of rows before outlier removal: 269
# Number of rows after outlier removal: 266
# Number of outliers detected: 4
# Number of rows before outlier removal: 287
# Number of rows after outlier removal: 283
# Number of outliers detected: 1
# Number of rows before outlier removal: 76
# Number of rows after outlier removal: 75
# Number of outliers detected: 1
# Number of rows before outlier removal: 133
# Number of rows after outlier removal: 132
# Number of outliers detected: 5
# Number of rows before outlier removal: 239
# Number of rows after outlier removal: 234
# Number of outliers detected: 2
# Number of rows before outlier removal: 173
# Number of rows after outlier removal: 171
# Number of outliers detected: 3
# Number of rows before outlier removal: 147
# Number of rows after outlier removal: 144
# Number of outliers detected: 1
# Number of rows before outlier removal: 78
# Number of rows after outlier removal: 77
# Number of outliers detected: 3
# Number of rows before outlier removal: 239
# Number of rows after outlier removal: 236
# Number of outliers detected: 3
# Number of rows before outlier removal: 256
# Number of rows after outlier removal: 253
# Number of outliers detected: 7
# Number of rows before outlier removal: 424
# Number of rows after outlier removal: 417
# Number of outliers detected: 1
# Number of rows before outlier removal: 183
# Number of rows after outlier removal: 182
# Number of outliers detected: 6
# Number of rows before outlier removal: 346
# Number of rows after outlier removal: 340
# Number of outliers detected: 8
# Number of rows before outlier removal: 286
# Number of rows after outlier removal: 278
# Number of outliers detected: 6
# Number of rows before outlier removal: 271
# Number of rows after outlier removal: 265
# Number of outliers detected: 0
# Number of rows before outlier removal: 15
# Number of rows after outlier removal: 15
# Number of outliers detected: 0
# Number of rows before outlier removal: 22
# Number of rows after outlier removal: 22
# Number of outliers detected: 2
# Number of rows before outlier removal: 286
# Number of rows after outlier removal: 284
# Number of outliers detected: 0
# Number of rows before outlier removal: 18
# Number of rows after outlier removal: 18
# Number of outliers detected: 2
# Number of rows before outlier removal: 247
# Number of rows after outlier removal: 245
# Number of outliers detected: 3
# Number of rows before outlier removal: 259
# Number of rows after outlier removal: 256
# Number of outliers detected: 2
# Number of rows before outlier removal: 69
# Number of rows after outlier removal: 67
# Number of outliers detected: 8
# Number of rows before outlier removal: 377
# Number of rows after outlier removal: 369
# Number of outliers detected: 3
# Number of rows before outlier removal: 250
# Number of rows after outlier removal: 247
# Number of outliers detected: 3
# Number of rows before outlier removal: 258
# Number of rows after outlier removal: 255
# Number of outliers detected: 6
# Number of rows before outlier removal: 265
# Number of rows after outlier removal: 259
# Number of outliers detected: 0
# Number of rows before outlier removal: 90
# Number of rows after outlier removal: 90
# Number of outliers detected: 4
# Number of rows before outlier removal: 584
# Number of rows after outlier removal: 580
# Number of outliers detected: 1
# Number of rows before outlier removal: 221
# Number of rows after outlier removal: 220
# Number of outliers detected: 6
# Number of rows before outlier removal: 321
# Number of rows after outlier removal: 315
# Number of outliers detected: 3
# Number of rows before outlier removal: 216
# Number of rows after outlier removal: 213
# Number of outliers detected: 2
# Number of rows before outlier removal: 41
# Number of rows after outlier removal: 39
# Number of outliers detected: 4
# Number of rows before outlier removal: 148
# Number of rows after outlier removal: 144
# Number of outliers detected: 5
# Number of rows before outlier removal: 198
# Number of rows after outlier removal: 193
# Number of outliers detected: 3
# Number of rows before outlier removal: 291
# Number of rows after outlier removal: 288
# Number of outliers detected: 7
# Number of rows before outlier removal: 253
# Number of rows after outlier removal: 246
# Number of outliers detected: 1
# Number of rows before outlier removal: 640
# Number of rows after outlier removal: 639
# Number of outliers detected: 2
# Number of rows before outlier removal: 117
# Number of rows after outlier removal: 115
# Number of outliers detected: 3
# Number of rows before outlier removal: 253
# Number of rows after outlier removal: 250
# Number of outliers detected: 6
# Number of rows before outlier removal: 229
# Number of rows after outlier removal: 223
# Number of outliers detected: 4
# Number of rows before outlier removal: 264
# Number of rows after outlier removal: 260
# Number of outliers detected: 4
# Number of rows before outlier removal: 331
# Number of rows after outlier removal: 327
# Number of outliers detected: 6
# Number of rows before outlier removal: 410
# Number of rows after outlier removal: 404
# Number of outliers detected: 0
# Number of rows before outlier removal: 160
# Number of rows after outlier removal: 160
# Number of outliers detected: 3
# Number of rows before outlier removal: 171
# Number of rows after outlier removal: 168
# Number of outliers detected: 0
# Number of rows before outlier removal: 16
# Number of rows after outlier removal: 16
# Number of outliers detected: 3
# Number of rows before outlier removal: 293
# Number of rows after outlier removal: 290
# Number of outliers detected: 0
# Number of rows before outlier removal: 25
# Number of rows after outlier removal: 25
# Number of outliers detected: 1
# Number of rows before outlier removal: 103
# Number of rows after outlier removal: 102
# Number of outliers detected: 0
# Number of rows before outlier removal: 16
# Number of rows after outlier removal: 16
# Number of outliers detected: 2
# Number of rows before outlier removal: 325
# Number of rows after outlier removal: 323
# Number of outliers detected: 1
# Number of rows before outlier removal: 51
# Number of rows after outlier removal: 50
# Number of outliers detected: 3
# Number of rows before outlier removal: 146
# Number of rows after outlier removal: 143
# Number of outliers detected: 0
# Number of rows before outlier removal: 36
# Number of rows after outlier removal: 36
# Number of outliers detected: 3
# Number of rows before outlier removal: 297
# Number of rows after outlier removal: 294
# Number of outliers detected: 1
# Number of rows before outlier removal: 57
# Number of rows after outlier removal: 56
# Number of outliers detected: 3
# Number of rows before outlier removal: 211
# Number of rows after outlier removal: 208
# Number of outliers detected: 4
# Number of rows before outlier removal: 264
# Number of rows after outlier removal: 260
# Number of outliers detected: 4
# Number of rows before outlier removal: 195
# Number of rows after outlier removal: 191
# Number of outliers detected: 1
# Number of rows before outlier removal: 63
# Number of rows after outlier removal: 62
# Number of outliers detected: 1
# Number of rows before outlier removal: 36
# Number of rows after outlier removal: 35
# Number of outliers detected: 5
# Number of rows before outlier removal: 309
# Number of rows after outlier removal: 304
# Number of outliers detected: 4
# Number of rows before outlier removal: 202
# Number of rows after outlier removal: 198
# Number of outliers detected: 2
# Number of rows before outlier removal: 135
# Number of rows after outlier removal: 133
# Number of outliers detected: 3
# Number of rows before outlier removal: 98
# Number of rows after outlier removal: 95
# Number of outliers detected: 7
# Number of rows before outlier removal: 372
# Number of rows after outlier removal: 365
# Number of outliers detected: 0
# Number of rows before outlier removal: 71
# Number of rows after outlier removal: 71
# Number of outliers detected: 2
# Number of rows before outlier removal: 280
# Number of rows after outlier removal: 278
# Number of outliers detected: 4
# Number of rows before outlier removal: 197
# Number of rows after outlier removal: 193
# Number of outliers detected: 4
# Number of rows before outlier removal: 315
# Number of rows after outlier removal: 311
# Number of outliers detected: 3
# Number of rows before outlier removal: 158
# Number of rows after outlier removal: 155
# Number of outliers detected: 2
# Number of rows before outlier removal: 77
# Number of rows after outlier removal: 75
# Number of outliers detected: 4
# Number of rows before outlier removal: 286
# Number of rows after outlier removal: 282
# Number of outliers detected: 1
# Number of rows before outlier removal: 178
# Number of rows after outlier removal: 177
# Number of outliers detected: 2
# Number of rows before outlier removal: 62
# Number of rows after outlier removal: 60
# Number of outliers detected: 3
# Number of rows before outlier removal: 313
# Number of rows after outlier removal: 310
# Number of outliers detected: 3
# Number of rows before outlier removal: 139
# Number of rows after outlier removal: 136
# Number of outliers detected: 3
# Number of rows before outlier removal: 289
# Number of rows after outlier removal: 286
# Number of outliers detected: 2
# Number of rows before outlier removal: 172
# Number of rows after outlier removal: 170
# Number of outliers detected: 2
# Number of rows before outlier removal: 140
# Number of rows after outlier removal: 138
# Number of outliers detected: 0
# Number of rows before outlier removal: 180
# Number of rows after outlier removal: 180
# Number of outliers detected: 1
# Number of rows before outlier removal: 98
# Number of rows after outlier removal: 97
# Number of outliers detected: 1
# Number of rows before outlier removal: 247
# Number of rows after outlier removal: 246
# Number of outliers detected: 2
# Number of rows before outlier removal: 195
# Number of rows after outlier removal: 193
# Number of outliers detected: 6
# Number of rows before outlier removal: 376
# Number of rows after outlier removal: 370
# Number of outliers detected: 4
# Number of rows before outlier removal: 264
# Number of rows after outlier removal: 260
# Number of outliers detected: 5
# Number of rows before outlier removal: 183
# Number of rows after outlier removal: 178
# Number of outliers detected: 2
# Number of rows before outlier removal: 117
# Number of rows after outlier removal: 115
# Number of outliers detected: 2
# Number of rows before outlier removal: 131
# Number of rows after outlier removal: 129
# Number of outliers detected: 0
# Number of rows before outlier removal: 139
# Number of rows after outlier removal: 139
# Number of outliers detected: 2
# Number of rows before outlier removal: 154
# Number of rows after outlier removal: 152
# Number of outliers detected: 4
# Number of rows before outlier removal: 331
# Number of rows after outlier removal: 327
# Number of outliers detected: 6
# Number of rows before outlier removal: 307
# Number of rows after outlier removal: 301
# Number of outliers detected: 0
# Number of rows before outlier removal: 56
# Number of rows after outlier removal: 56
# Number of outliers detected: 1
# Number of rows before outlier removal: 134
# Number of rows after outlier removal: 133
# Number of outliers detected: 0
# Number of rows before outlier removal: 24
# Number of rows after outlier removal: 24
# Number of outliers detected: 0
# Number of rows before outlier removal: 322
# Number of rows after outlier removal: 322
# Number of outliers detected: 4
# Number of rows before outlier removal: 348
# Number of rows after outlier removal: 344
# Number of outliers detected: 6
# Number of rows before outlier removal: 328
# Number of rows after outlier removal: 322
# Number of outliers detected: 2
# Number of rows before outlier removal: 100
# Number of rows after outlier removal: 98
# Number of outliers detected: 4
# Number of rows before outlier removal: 114
# Number of rows after outlier removal: 110
# Number of outliers detected: 10
# Number of rows before outlier removal: 436
# Number of rows after outlier removal: 426
# Number of outliers detected: 0
# Number of rows before outlier removal: 11
# Number of rows after outlier removal: 11
# Number of outliers detected: 1
# Number of rows before outlier removal: 110
# Number of rows after outlier removal: 109
# Number of outliers detected: 0
# Number of rows before outlier removal: 181
# Number of rows after outlier removal: 181
# Number of outliers detected: 1
# Number of rows before outlier removal: 97
# Number of rows after outlier removal: 96
# Number of outliers detected: 1
# Number of rows before outlier removal: 147
# Number of rows after outlier removal: 146
# Number of outliers detected: 2
# Number of rows before outlier removal: 113
# Number of rows after outlier removal: 111
# Number of outliers detected: 2
# Number of rows before outlier removal: 60
# Number of rows after outlier removal: 58
# Number of outliers detected: 3
# Number of rows before outlier removal: 285
# Number of rows after outlier removal: 282
# Number of outliers detected: 5
# Number of rows before outlier removal: 229
# Number of rows after outlier removal: 224
# Number of outliers detected: 10
# Number of rows before outlier removal: 349
# Number of rows after outlier removal: 339
# Number of outliers detected: 6
# Number of rows before outlier removal: 344
# Number of rows after outlier removal: 338
# Number of outliers detected: 1
# Number of rows before outlier removal: 51
# Number of rows after outlier removal: 50
# Number of outliers detected: 3
# Number of rows before outlier removal: 367
# Number of rows after outlier removal: 364
# Number of outliers detected: 7
# Number of rows before outlier removal: 312
# Number of rows after outlier removal: 305
# Number of outliers detected: 1
# Number of rows before outlier removal: 53
# Number of rows after outlier removal: 52
# Number of outliers detected: 7
# Number of rows before outlier removal: 267
# Number of rows after outlier removal: 260
# Number of outliers detected: 0
# Number of rows before outlier removal: 17
# Number of rows after outlier removal: 17
# Number of outliers detected: 0
# Number of rows before outlier removal: 36
# Number of rows after outlier removal: 36
# Number of outliers detected: 1
# Number of rows before outlier removal: 157
# Number of rows after outlier removal: 156
# Number of outliers detected: 4
# Number of rows before outlier removal: 263
# Number of rows after outlier removal: 259
# Number of outliers detected: 6
# Number of rows before outlier removal: 269
# Number of rows after outlier removal: 263
# Number of outliers detected: 3
# Number of rows before outlier removal: 239
# Number of rows after outlier removal: 236
# Number of outliers detected: 4
# Number of rows before outlier removal: 200
# Number of rows after outlier removal: 196
# Number of outliers detected: 1
# Number of rows before outlier removal: 232
# Number of rows after outlier removal: 231
# Number of outliers detected: 5
# Number of rows before outlier removal: 232
# Number of rows after outlier removal: 227
# Number of outliers detected: 5
# Number of rows before outlier removal: 262
# Number of rows after outlier removal: 257
# Number of outliers detected: 5
# Number of rows before outlier removal: 212
# Number of rows after outlier removal: 207
# Number of outliers detected: 1
# Number of rows before outlier removal: 173
# Number of rows after outlier removal: 172
# Number of outliers detected: 2
# Number of rows before outlier removal: 183
# Number of rows after outlier removal: 181
# Number of outliers detected: 1
# Number of rows before outlier removal: 176
# Number of rows after outlier removal: 175
# Number of outliers detected: 0
# Number of rows before outlier removal: 89
# Number of rows after outlier removal: 89
# Number of outliers detected: 2
# Number of rows before outlier removal: 142
# Number of rows after outlier removal: 140
# Number of outliers detected: 3
# Number of rows before outlier removal: 232
# Number of rows after outlier removal: 229
# Number of outliers detected: 1
# Number of rows before outlier removal: 72
# Number of rows after outlier removal: 71
# Number of outliers detected: 1
# Number of rows before outlier removal: 70
# Number of rows after outlier removal: 69
# Number of outliers detected: 3
# Number of rows before outlier removal: 164
# Number of rows after outlier removal: 161
# Number of outliers detected: 5
# Number of rows before outlier removal: 160
# Number of rows after outlier removal: 155
# Number of outliers detected: 6
# Number of rows before outlier removal: 175
# Number of rows after outlier removal: 169
# Number of outliers detected: 1
# Number of rows before outlier removal: 141
# Number of rows after outlier removal: 140
# Number of outliers detected: 2
# Number of rows before outlier removal: 143
# Number of rows after outlier removal: 141
# Number of outliers detected: 1
# Number of rows before outlier removal: 154
# Number of rows after outlier removal: 153
# Number of outliers detected: 9
# Number of rows before outlier removal: 316
# Number of rows after outlier removal: 307
# Number of outliers detected: 2
# Number of rows before outlier removal: 118
# Number of rows after outlier removal: 116
# Number of outliers detected: 3
# Number of rows before outlier removal: 137
# Number of rows after outlier removal: 134
# Number of outliers detected: 3
# Number of rows before outlier removal: 137
# Number of rows after outlier removal: 134
# Number of outliers detected: 1
# Number of rows before outlier removal: 143
# Number of rows after outlier removal: 142
# Number of outliers detected: 3
# Number of rows before outlier removal: 150
# Number of rows after outlier removal: 147
# Number of outliers detected: 3
# Number of rows before outlier removal: 168
# Number of rows after outlier removal: 165
# Number of outliers detected: 4
# Number of rows before outlier removal: 121
# Number of rows after outlier removal: 117
# Number of outliers detected: 1
# Number of rows before outlier removal: 101
# Number of rows after outlier removal: 100
# Number of outliers detected: 3
# Number of rows before outlier removal: 86
# Number of rows after outlier removal: 83
# Number of outliers detected: 10
# Number of rows before outlier removal: 333
# Number of rows after outlier removal: 323
# Number of outliers detected: 1
# Number of rows before outlier removal: 50
# Number of rows after outlier removal: 49
# Number of outliers detected: 1
# Number of rows before outlier removal: 68
# Number of rows after outlier removal: 67
# Number of outliers detected: 5
# Number of rows before outlier removal: 296
# Number of rows after outlier removal: 291
# Number of outliers detected: 0
# Number of rows before outlier removal: 11
# Number of rows after outlier removal: 11
# Number of outliers detected: 1
# Number of rows before outlier removal: 70
# Number of rows after outlier removal: 69
# Number of outliers detected: 3
# Number of rows before outlier removal: 79
# Number of rows after outlier removal: 76
# Number of outliers detected: 9
# Number of rows before outlier removal: 254
# Number of rows after outlier removal: 245
# Number of outliers detected: 3
# Number of rows before outlier removal: 250
# Number of rows after outlier removal: 247
# Number of outliers detected: 4
# Number of rows before outlier removal: 282
# Number of rows after outlier removal: 278
# Number of outliers detected: 4
# Number of rows before outlier removal: 193
# Number of rows after outlier removal: 189
# Number of outliers detected: 0
# Number of rows before outlier removal: 177
# Number of rows after outlier removal: 177
# Number of outliers detected: 1
# Number of rows before outlier removal: 184
# Number of rows after outlier removal: 183
# Number of outliers detected: 2
# Number of rows before outlier removal: 180
# Number of rows after outlier removal: 178
# Number of outliers detected: 4
# Number of rows before outlier removal: 185
# Number of rows after outlier removal: 181
# Number of outliers detected: 3
# Number of rows before outlier removal: 164
# Number of rows after outlier removal: 161
# Number of outliers detected: 1
# Number of rows before outlier removal: 142
# Number of rows after outlier removal: 141
# Number of outliers detected: 1
# Number of rows before outlier removal: 118
# Number of rows after outlier removal: 117
# Number of outliers detected: 0
# Number of rows before outlier removal: 133
# Number of rows after outlier removal: 133
# Number of outliers detected: 2
# Number of rows before outlier removal: 155
# Number of rows after outlier removal: 153
# Number of outliers detected: 3
# Number of rows before outlier removal: 136
# Number of rows after outlier removal: 133
# Number of outliers detected: 1
# Number of rows before outlier removal: 88
# Number of rows after outlier removal: 87
# Number of outliers detected: 1
# Number of rows before outlier removal: 38
# Number of rows after outlier removal: 37
# Number of outliers detected: 0
# Number of rows before outlier removal: 100
# Number of rows after outlier removal: 100
# Number of outliers detected: 1
# Number of rows before outlier removal: 57
# Number of rows after outlier removal: 56
# Number of outliers detected: 1
# Number of rows before outlier removal: 64
# Number of rows after outlier removal: 63
# Number of outliers detected: 0
# Number of rows before outlier removal: 64
# Number of rows after outlier removal: 64
# Number of outliers detected: 0
# Number of rows before outlier removal: 39
# Number of rows after outlier removal: 39
# Number of outliers detected: 0
# Number of rows before outlier removal: 50
# Number of rows after outlier removal: 50
# Number of outliers detected: 1
# Number of rows before outlier removal: 19
# Number of rows after outlier removal: 18
# Number of outliers detected: 1
# Number of rows before outlier removal: 33
# Number of rows after outlier removal: 32
# Number of outliers detected: 1
# Number of rows before outlier removal: 25
# Number of rows after outlier removal: 24
# Number of outliers detected: 3
# Number of rows before outlier removal: 165
# Number of rows after outlier removal: 162
# Number of outliers detected: 3
# ...
# Number of rows after outlier removal: 153
# Number of outliers detected: 0
# Number of rows before outlier removal: 292
# Number of rows after outlier removal: 292
# Number of outliers detected: 0
# Number of rows before outlier removal: 257
# Number of rows after outlier removal: 257
# Number of outliers detected: 1
# Number of rows before outlier removal: 243
# Number of rows after outlier removal: 242
# Number of outliers detected: 0
# Number of rows before outlier removal: 293
# Number of rows after outlier removal: 293
# Number of outliers detected: 0
# Number of rows before outlier removal: 270
# Number of rows after outlier removal: 270
# Number of outliers detected: 0
# Number of rows before outlier removal: 316
# Number of rows after outlier removal: 316
# Number of outliers detected: 0
# Number of rows before outlier removal: 41
# Number of rows after outlier removal: 41
# Number of outliers detected: 0
# Number of rows before outlier removal: 250
# Number of rows after outlier removal: 250
# Number of outliers detected: 1
# Number of rows before outlier removal: 294
# Number of rows after outlier removal: 293
# Number of outliers detected: 0
# Number of rows before outlier removal: 223
# Number of rows after outlier removal: 223
# Number of outliers detected: 0
# Number of rows before outlier removal: 98
# Number of rows after outlier removal: 98
# Number of outliers detected: 1
# Number of rows before outlier removal: 351
# Number of rows after outlier removal: 350
# Number of outliers detected: 0
# Number of rows before outlier removal: 153
# Number of rows after outlier removal: 153
# Number of outliers detected: 0
# Number of rows before outlier removal: 69
# Number of rows after outlier removal: 69
# Number of outliers detected: 0
# Number of rows before outlier removal: 299
# Number of rows after outlier removal: 299
# Number of outliers detected: 0
# Number of rows before outlier removal: 218
# Number of rows after outlier removal: 218
# Number of outliers detected: 0
# Number of rows before outlier removal: 306
# Number of rows after outlier removal: 306
# Number of outliers detected: 0
# Number of rows before outlier removal: 153
# Number of rows after outlier removal: 153
# Number of outliers detected: 0
# Number of rows before outlier removal: 320
# Number of rows after outlier removal: 320
# Number of outliers detected: 0
# Number of rows before outlier removal: 83
# Number of rows after outlier removal: 83
# Number of outliers detected: 0
# Number of rows before outlier removal: 109
# Number of rows after outlier removal: 109
# Number of outliers detected: 0
# Number of rows before outlier removal: 370
# Number of rows after outlier removal: 370
# Number of outliers detected: 0
# Number of rows before outlier removal: 306
# Number of rows after outlier removal: 306
# Number of outliers detected: 0
# Number of rows before outlier removal: 117
# Number of rows after outlier removal: 117
# Number of outliers detected: 0
# Number of rows before outlier removal: 300
# Number of rows after outlier removal: 300
# Number of outliers detected: 0
# Number of rows before outlier removal: 60
# Number of rows after outlier removal: 60
# Number of outliers detected: 0
# Number of rows before outlier removal: 307
# Number of rows after outlier removal: 307
# Number of outliers detected: 0
# Number of rows before outlier removal: 237
# Number of rows after outlier removal: 237
# Number of outliers detected: 0
# Number of rows before outlier removal: 43
# Number of rows after outlier removal: 43
# Number of outliers detected: 0
# Number of rows before outlier removal: 372
# Number of rows after outlier removal: 372
# Number of outliers detected: 1
# Number of rows before outlier removal: 332
# Number of rows after outlier removal: 331
# Number of outliers detected: 0
# Number of rows before outlier removal: 48
# Number of rows after outlier removal: 48
# Number of outliers detected: 0
# Number of rows before outlier removal: 326
# Number of rows after outlier removal: 326
# Number of outliers detected: 0
# Number of rows before outlier removal: 17
# Number of rows after outlier removal: 17
# Number of outliers detected: 0
# Number of rows before outlier removal: 280
# Number of rows after outlier removal: 280
# Number of outliers detected: 0
# Number of rows before outlier removal: 357
# Number of rows after outlier removal: 357
# Number of outliers detected: 0
# Number of rows before outlier removal: 245
# Number of rows after outlier removal: 245
# Number of outliers detected: 0
# Number of rows before outlier removal: 257
# Number of rows after outlier removal: 257
# Number of outliers detected: 0
# Number of rows before outlier removal: 327
# Number of rows after outlier removal: 327
# Number of outliers detected: 0
# Number of rows before outlier removal: 107
# Number of rows after outlier removal: 107
# Number of outliers detected: 0
# Number of rows before outlier removal: 308
# Number of rows after outlier removal: 308
# Number of outliers detected: 1
# Number of rows before outlier removal: 249
# Number of rows after outlier removal: 248
# Number of outliers detected: 0
# Number of rows before outlier removal: 341
# Number of rows after outlier removal: 341
# Number of outliers detected: 0
# Number of rows before outlier removal: 224
# Number of rows after outlier removal: 224
# Number of outliers detected: 0
# Number of rows before outlier removal: 285
# Number of rows after outlier removal: 285
# Number of outliers detected: 0
# Number of rows before outlier removal: 242
# Number of rows after outlier removal: 242
# Number of outliers detected: 0
# Number of rows before outlier removal: 148
# Number of rows after outlier removal: 148
# Number of outliers detected: 0
# Number of rows before outlier removal: 270
# Number of rows after outlier removal: 270
# Number of outliers detected: 0
# Number of rows before outlier removal: 241
# Number of rows after outlier removal: 241
# Number of outliers detected: 0
# Number of rows before outlier removal: 270
# Number of rows after outlier removal: 270
# Number of outliers detected: 0
# Number of rows before outlier removal: 48
# Number of rows after outlier removal: 48
# Number of outliers detected: 0
# Number of rows before outlier removal: 184
# Number of rows after outlier removal: 184
# Number of outliers detected: 1
# Number of rows before outlier removal: 148
# Number of rows after outlier removal: 147
# Number of outliers detected: 1
# Number of rows before outlier removal: 243
# Number of rows after outlier removal: 242
# Number of outliers detected: 0
# Number of rows before outlier removal: 60
# Number of rows after outlier removal: 60
# Number of outliers detected: 0
# Number of rows before outlier removal: 121
# Number of rows after outlier removal: 121
# Number of outliers detected: 0
# Number of rows before outlier removal: 113
# Number of rows after outlier removal: 113
# Number of outliers detected: 0
# Number of rows before outlier removal: 166
# Number of rows after outlier removal: 166
# Number of outliers detected: 0
# Number of rows before outlier removal: 200
# Number of rows after outlier removal: 200
# Number of outliers detected: 0
# Number of rows before outlier removal: 98
# Number of rows after outlier removal: 98
# Number of outliers detected: 0
# Number of rows before outlier removal: 119
# Number of rows after outlier removal: 119
# Number of outliers detected: 0
# Number of rows before outlier removal: 200
# Number of rows after outlier removal: 200
# Number of outliers detected: 0
# Number of rows before outlier removal: 65
# Number of rows after outlier removal: 65
# Number of outliers detected: 0
# Number of rows before outlier removal: 74
# Number of rows after outlier removal: 74
# Number of outliers detected: 0
# Number of rows before outlier removal: 162
# Number of rows after outlier removal: 162
# Number of outliers detected: 0
# Number of rows before outlier removal: 46
# Number of rows after outlier removal: 46
# Number of outliers detected: 0
# Number of rows before outlier removal: 60
# Number of rows after outlier removal: 60
# Number of outliers detected: 0
# Number of rows before outlier removal: 104
# Number of rows after outlier removal: 104
# Number of outliers detected: 0
# Number of rows before outlier removal: 164
# Number of rows after outlier removal: 164
# Number of outliers detected: 1
# Number of rows before outlier removal: 302
# Number of rows after outlier removal: 301
# Number of outliers detected: 0
# Number of rows before outlier removal: 230
# Number of rows after outlier removal: 230
# Number of outliers detected: 0
# Number of rows before outlier removal: 148
# Number of rows after outlier removal: 148
# Number of outliers detected: 0
# Number of rows before outlier removal: 91
# Number of rows after outlier removal: 91
# Number of outliers detected: 0
# Number of rows before outlier removal: 175
# Number of rows after outlier removal: 175
# Number of outliers detected: 0
# Number of rows before outlier removal: 108
# Number of rows after outlier removal: 108
# Number of outliers detected: 1
# Number of rows before outlier removal: 261
# Number of rows after outlier removal: 260
# Number of outliers detected: 0
# Number of rows before outlier removal: 133
# Number of rows after outlier removal: 133
# Number of outliers detected: 0
# Number of rows before outlier removal: 163
# Number of rows after outlier removal: 163
# Number of outliers detected: 0
# Number of rows before outlier removal: 254
# Number of rows after outlier removal: 254
# Number of outliers detected: 2
# Number of rows before outlier removal: 269
# Number of rows after outlier removal: 267
# Number of outliers detected: 0
# Number of rows before outlier removal: 270
# Number of rows after outlier removal: 270
# Number of outliers detected: 0
# Number of rows before outlier removal: 169
# Number of rows after outlier removal: 169
# Number of outliers detected: 1
# Number of rows before outlier removal: 382
# Number of rows after outlier removal: 381
# Number of outliers detected: 0
# Number of rows before outlier removal: 59
# Number of rows after outlier removal: 59
# Number of outliers detected: 1
# Number of rows before outlier removal: 287
# Number of rows after outlier removal: 286
# Number of outliers detected: 2
# Number of rows before outlier removal: 360
# Number of rows after outlier removal: 358
# Number of outliers detected: 0
# Number of rows before outlier removal: 162
# Number of rows after outlier removal: 162
# Number of outliers detected: 0
# Number of rows before outlier removal: 359
# Number of rows after outlier removal: 359
# Number of outliers detected: 0
# Number of rows before outlier removal: 204
# Number of rows after outlier removal: 204
# Number of outliers detected: 0
# Number of rows before outlier removal: 25
# Number of rows after outlier removal: 25
# Number of outliers detected: 0
# Number of rows before outlier removal: 272
# Number of rows after outlier removal: 272
# Number of outliers detected: 0
# Number of rows before outlier removal: 507
# Number of rows after outlier removal: 507
# Number of outliers detected: 0
# Number of rows before outlier removal: 329
# Number of rows after outlier removal: 329
# Number of outliers detected: 0
# Number of rows before outlier removal: 168
# Number of rows after outlier removal: 168
# Number of outliers detected: 0
# Number of rows before outlier removal: 309
# Number of rows after outlier removal: 309
# Number of outliers detected: 0
# Number of rows before outlier removal: 151
# Number of rows after outlier removal: 151
# Number of outliers detected: 1
# Number of rows before outlier removal: 252
# Number of rows after outlier removal: 251
# Number of outliers detected: 0
# Number of rows before outlier removal: 107
# Number of rows after outlier removal: 107
# Number of outliers detected: 0
# Number of rows before outlier removal: 279
# Number of rows after outlier removal: 279
# Number of outliers detected: 0
# Number of rows before outlier removal: 271
# Number of rows after outlier removal: 271
# Number of outliers detected: 0
# Number of rows before outlier removal: 185
# Number of rows after outlier removal: 185
# Number of outliers detected: 0
# Number of rows before outlier removal: 59
# Number of rows after outlier removal: 59
# Number of outliers detected: 0
# Number of rows before outlier removal: 124
# Number of rows after outlier removal: 124
# Number of outliers detected: 0
# Number of rows before outlier removal: 76
# Number of rows after outlier removal: 76
# Number of outliers detected: 0
# Number of rows before outlier removal: 339
# Number of rows after outlier removal: 339
# Number of outliers detected: 0
# Number of rows before outlier removal: 535
# Number of rows after outlier removal: 535
# Number of outliers detected: 0
# Number of rows before outlier removal: 359
# Number of rows after outlier removal: 359
# Number of outliers detected: 0
# Number of rows before outlier removal: 224
# Number of rows after outlier removal: 224
# Number of outliers detected: 0
# Number of rows before outlier removal: 134
# Number of rows after outlier removal: 134
# Number of outliers detected: 0
# Number of rows before outlier removal: 328
# Number of rows after outlier removal: 328
# Number of outliers detected: 0
# Number of rows before outlier removal: 217
# Number of rows after outlier removal: 217
# Number of outliers detected: 0
# Number of rows before outlier removal: 570
# Number of rows after outlier removal: 570
# Number of outliers detected: 0
# Number of rows before outlier removal: 69
# Number of rows after outlier removal: 69
# Number of outliers detected: 0
# Number of rows before outlier removal: 453
# Number of rows after outlier removal: 453
# Number of outliers detected: 1
# Number of rows before outlier removal: 233
# Number of rows after outlier removal: 232
# Number of outliers detected: 0
# Number of rows before outlier removal: 108
# Number of rows after outlier removal: 108
# Number of outliers detected: 0
# Number of rows before outlier removal: 222
# Number of rows after outlier removal: 222
# Number of outliers detected: 0
# Number of rows before outlier removal: 530
# Number of rows after outlier removal: 530
# Number of outliers detected: 1
# Number of rows before outlier removal: 331
# Number of rows after outlier removal: 330
# Number of outliers detected: 0
# Number of rows before outlier removal: 292
# Number of rows after outlier removal: 292
# Number of outliers detected: 0
# Number of rows before outlier removal: 452
# Number of rows after outlier removal: 452
# Number of outliers detected: 2
# Number of rows before outlier removal: 372
# Number of rows after outlier removal: 370
# Number of outliers detected: 0
# Number of rows before outlier removal: 81
# Number of rows after outlier removal: 81
# Number of outliers detected: 1
# Number of rows before outlier removal: 199
# Number of rows after outlier removal: 198
# Number of outliers detected: 0
# Number of rows before outlier removal: 139
# Number of rows after outlier removal: 139
# Number of outliers detected: 0
# Number of rows before outlier removal: 104
# Number of rows after outlier removal: 104
# Number of outliers detected: 0
# Number of rows before outlier removal: 243
# Number of rows after outlier removal: 243
# Number of outliers detected: 0
# Number of rows before outlier removal: 434
# Number of rows after outlier removal: 434
# Number of outliers detected: 0
# Number of rows before outlier removal: 26
# Number of rows after outlier removal: 26
# Number of outliers detected: 0
# Number of rows before outlier removal: 64
# Number of rows after outlier removal: 64
# Number of outliers detected: 1
# Number of rows before outlier removal: 389
# Number of rows after outlier removal: 388
# Number of outliers detected: 0
# Number of rows before outlier removal: 307
# Number of rows after outlier removal: 307
# Number of outliers detected: 0
# Number of rows before outlier removal: 457
# Number of rows after outlier removal: 457
# Number of outliers detected: 1
# Number of rows before outlier removal: 292
# Number of rows after outlier removal: 291
# Number of outliers detected: 1
# Number of rows before outlier removal: 291
# Number of rows after outlier removal: 290
# Number of outliers detected: 1
# Number of rows before outlier removal: 74
# Number of rows after outlier removal: 73
# Number of outliers detected: 1
# Number of rows before outlier removal: 85
# Number of rows after outlier removal: 84
# Number of outliers detected: 0
# Number of rows before outlier removal: 223
# Number of rows after outlier removal: 223

# %%
data_cleaned
# Out:
#                  SE_Number FarmName_Pseudo       Date  DailyYield  \
# 0         SE-064c0cec-1189        a624fb9a 2022-05-28       15.22
# 1         SE-064c0cec-1189        a624fb9a 2022-05-29       18.96
# 2         SE-064c0cec-1189        a624fb9a 2022-05-30       22.64
# 3         SE-064c0cec-1189        a624fb9a 2022-05-31       26.49
# 4         SE-064c0cec-1189        a624fb9a 2022-06-01       33.61
# ...                    ...             ...        ...         ...
# 465315  SE-fcdf259d-0044-0        f454e660 2023-06-08       15.14
# 465316  SE-fcdf259d-0044-0        f454e660 2023-06-09        7.47
# 465317  SE-fcdf259d-0044-0        f454e660 2023-06-10       14.73
# 465318  SE-fcdf259d-0044-0        f454e660 2023-06-12       12.27
# 465319  SE-fcdf259d-0044-0        f454e660 2023-06-13        7.96
#
#         PreviousDailyYield  DailyYieldChange  HW  MeanTemperature  \
# 0                   0.0000            0.0000   0         9.912500
# 1                  15.2200            1.8700   0        10.066667
# 2                  17.0900            1.8500   0        10.466667
# 3                  18.9400            1.8875   0        11.183333
# 4                  20.8275            2.5565   0        12.704167
# ...                    ...               ...  ..              ...
# 465315             13.2520            0.4940   0        15.570833
# 465316             13.7460           -2.9680   0        13.254167
# 465317             10.7780            0.3780   0        13.258333
# 465318             11.1560            0.5600   0        15.820833
# 465319             11.7160           -0.2020   0        16.341667
#
#         MeanTHI_adj  DaysInMilk  ...   Age   BreedName  LactationNumber  \
# 0         50.478673           3  ...  3242      02 SLB                8
# 1         53.841648           4  ...  3243      02 SLB                8
# 2         52.935959           5  ...  3244      02 SLB                8
# 3         52.872112           6  ...  3245      02 SLB                8
# 4         56.056547           7  ...  3246      02 SLB                8
# ...             ...         ...  ...   ...         ...              ...
# 465315    59.383267         352  ...  4155  41 Fjällko               10
# 465316    54.534255         353  ...  4156  41 Fjällko               10
# 465317    54.082367         354  ...  4157  41 Fjällko               10
# 465318    62.015093         356  ...  4159  41 Fjällko               10
# 465319    63.457792         357  ...  4160  41 Fjällko               10
#
#          HeatLoad CumulativeHeatLoad  HeatStress  ExpectedYield  \
# 0      -12.521327           0.000000           0      13.399562
# 1       -9.158352           0.000000           0      17.370255
# 2      -10.064041           0.000000           0      20.745402
# 3      -10.127888           0.000000           0      23.612557
# 4       -6.943453           0.000000           0      26.046402
# ...           ...                ...         ...            ...
# 465315  -3.616733           0.000000           0      12.479001
# 465316  -8.465745           0.000000           0      12.383706
# 465317  -8.917633           0.000000           0      12.288410
# 465318  -0.984907           0.000000           0      12.097818
# 465319   0.457792           0.457792           0      12.002521
#
#         NormalizedDailyYield  NormalizedDailyYieldChange  Residuals
# 0                   1.135858                    0.000000   1.820438
# 1                   1.091521                    0.107655   1.589745
# 2                   1.091326                    0.089176   1.894598
# 3                   1.121861                    0.079936   2.877443
# 4                   1.290389                    0.098152   7.563598
# ...                      ...                         ...        ...
# 465315              1.213238                    0.039587   2.660999
# 465316              0.603212                   -0.239670  -4.913706
# 465317              1.198690                    0.030761   2.441590
# 465318              1.014232                    0.046289   0.172182
# 465319              0.663194                   -0.016830  -4.042521
#
# [465320 rows x 23 columns]

# %%
# Reorder columns
new_order = [
    "Date", "FarmName_Pseudo", "SE_Number", "Age", "BreedName", "LactationNumber", "DaysInMilk",'YearSeason', "DailyYield", "PreviousDailyYield", 
    "DailyYieldChange", "ExpectedYield", "NormalizedDailyYield", 
    "NormalizedDailyYieldChange", "Residuals", "HeatStress", "Temp15Threshold", "HW", 
    "cum_HW", "MeanTemperature", "MeanTHI_adj", "HeatLoad", "CumulativeHeatLoad"
]
data_cleaned = data_cleaned[new_order]
data_cleaned.head()
# Out:
#         Date FarmName_Pseudo         SE_Number   Age BreedName  \
# 0 2022-05-28        a624fb9a  SE-064c0cec-1189  3242    02 SLB
# 1 2022-05-29        a624fb9a  SE-064c0cec-1189  3243    02 SLB
# 2 2022-05-30        a624fb9a  SE-064c0cec-1189  3244    02 SLB
# 3 2022-05-31        a624fb9a  SE-064c0cec-1189  3245    02 SLB
# 4 2022-06-01        a624fb9a  SE-064c0cec-1189  3246    02 SLB
#
#    LactationNumber  DaysInMilk YearSeason  DailyYield  PreviousDailyYield  \
# 0                8           3     2022-2       15.22              0.0000
# 1                8           4     2022-2       18.96             15.2200
# 2                8           5     2022-2       22.64             17.0900
# 3                8           6     2022-2       26.49             18.9400
# 4                8           7     2022-3       33.61             20.8275
#
#    ...  NormalizedDailyYieldChange  Residuals  HeatStress  Temp15Threshold  \
# 0  ...                    0.000000   1.820438           0                0
# 1  ...                    0.107655   1.589745           0                0
# 2  ...                    0.089176   1.894598           0                1
# 3  ...                    0.079936   2.877443           0                0
# 4  ...                    0.098152   7.563598           0                1
#
#    HW  cum_HW  MeanTemperature  MeanTHI_adj   HeatLoad  CumulativeHeatLoad
# 0   0       0         9.912500    50.478673 -12.521327                 0.0
# 1   0       0        10.066667    53.841648  -9.158352                 0.0
# 2   0       0        10.466667    52.935959 -10.064041                 0.0
# 3   0       0        11.183333    52.872112 -10.127888                 0.0
# 4   0       0        12.704167    56.056547  -6.943453                 0.0
#
# [5 rows x 23 columns]

# %%
# Check if NormalizedDailyYield is centered around 1 for each unique farm
print("Mean of NormalizedDailyYield:", data_cleaned.groupby('FarmName_Pseudo')['NormalizedDailyYield'].mean())
print("Standard Deviation of NormalizedDailyYield:", data_cleaned.groupby('FarmName_Pseudo')['NormalizedDailyYield'].std())
# Out:
# Mean of NormalizedDailyYield: FarmName_Pseudo
# 5c06d92d    1.002293
# 752efd72    1.003195
# a624fb9a    1.000694
# f454e660    1.000827
# Name: NormalizedDailyYield, dtype: float64
# Standard Deviation of NormalizedDailyYield: FarmName_Pseudo
# 5c06d92d    0.128028
# 752efd72    0.109442
# a624fb9a    0.171171
# f454e660    0.229254
# Name: NormalizedDailyYield, dtype: float64

# %%
# Save the reordered DataFrame to a CSV file
data_cleaned.to_csv('../Data/MergedData/HeatApproachYieldDataTest.csv', index=False)
